# %% [markdown]
# # Compare Autodiff speed with explicit formulas

# %%
using Revise
using DataFrames, Random, GLM, QuasiCopula
using ForwardDiff, Test, LinearAlgebra
using LinearAlgebra: BlasReal, copytri!
using ToeplitzMatrices
using BenchmarkTools
using SnpArrays
using MendelPlots
ENV["COLUMNS"] = 240

BLAS.set_num_threads(1)
Threads.nthreads()

function A_mul_b!(c::AbstractVector{T}, A::AbstractMatrix, b::AbstractVector) where T
    n, p = size(A)
    fill!(c, zero(T))
    for j in 1:p, i in 1:n
        c[i] += A[i, j] * b[j]
    end
    return c
end
# Out:
# A_mul_b! (generic function with 1 method)

# %% [markdown]
# ## $f(\beta) = \frac{1}{2}(y - X\beta)^t(y - X\beta)$
#
# The closed form gradient is clearly
# \begin{align*}
# \nabla f(\beta) &= -X^t(y - X\beta)\\
# \nabla^2 f(\beta) &= X^tX
# \end{align*}
# Lets check how fast autodiff can compute them, compared to evaluating them directly.

# %%
# closed for obj, grad, and hessians
function f(β::AbstractVector{T}, X::AbstractMatrix, y::AbstractVector) where T
    r = zeros(T, size(X, 1))
    μ = zeros(T, size(X, 1))
    A_mul_b!(μ, X, β)
    r .= y .- μ
    return 0.5 * dot(r, r)
end
function ∇f(β, X, y, r = zeros(size(X, 1)), μ=zeros(size(X, 1)))
    A_mul_b!(μ, X, β)
    r .= y .- μ
    return -X'*r
end
function ∇²f(β, X, y, r = zeros(size(X, 1)), μ=zeros(size(X, 1)))
    return X'*X
end

# autodiff objective, grad, and hessian
eval_f(β) = f(β, X, y)
∇f_auto = x -> ForwardDiff.gradient(eval_f, x)
∇²f_auto = x -> ForwardDiff.hessian(eval_f, x)
# Out:
# #15 (generic function with 1 method)

# %% [markdown]
# ### First check answer

# %%
n = 100
p = 100
X = randn(n, p)
β = randn(p)
y = X * β

# check obj
@show f(β, X, y)
@show eval_f(β);
# Out:
# f(β, X, y) = 9.944023118618397e-28
# eval_f(β) = 9.944023118618397e-28

# %%
# check grad
[∇f(β, X, y) ∇f_auto(β)]
# Out:
# 100×2 Matrix{Float64}:
#  -5.57678e-15  -5.57678e-15
#  -4.21966e-16  -4.21966e-16
#  -7.64662e-15  -7.64662e-15
#   1.41683e-14   1.41683e-14
#  -2.55724e-14  -2.55724e-14
#   2.42931e-14   2.42931e-14
#  -7.69064e-14  -7.69064e-14
#   4.65141e-15   4.65141e-15
#  -4.19809e-14  -4.19809e-14
#  -1.1506e-13   -1.1506e-13
#  -2.85472e-15  -2.85472e-15
#   5.84794e-14   5.84794e-14
#   1.7187e-14    1.7187e-14
#   ⋮
#   5.682e-14     5.682e-14
#  -4.10495e-16  -4.10495e-16
#  -1.3364e-14   -1.3364e-14
#   6.61287e-14   6.61287e-14
#  -2.73213e-14  -2.73213e-14
#   7.21895e-14   7.21895e-14
#  -4.25375e-14  -4.25375e-14
#  -3.66414e-14  -3.66414e-14
#   9.92626e-15   9.92626e-15
#   5.08299e-14   5.08299e-14
#   2.62754e-15   2.62754e-15
#   2.87784e-14   2.87784e-14

# %%
# check Hessian 
H = ∇²f(β, X, y)
autoH = ∇²f_auto(β)
[vec(H) vec(autoH)]
# Out:
# 10000×2 Matrix{Float64}:
#  119.745    119.745
#   -5.80716   -5.80716
#   -8.9997    -8.9997
#   -1.18796   -1.18796
#    8.67201    8.67201
#   -6.17836   -6.17836
#    8.38473    8.38473
#   -4.179     -4.179
#   -1.93365   -1.93365
#  -13.9399   -13.9399
#   -4.32774   -4.32774
#   -7.95671   -7.95671
#   -1.08977   -1.08977
#    ⋮
#    5.32354    5.32354
#   -7.45453   -7.45453
#   12.4775    12.4775
#    9.09656    9.09656
#    5.32017    5.32017
#    4.39292    4.39292
#  -11.9773   -11.9773
#    4.00896    4.00896
#   -4.62155   -4.62155
#   11.8331    11.8331
#    9.78392    9.78392
#  114.875    114.875

# %% [markdown]
# ### Check timings

# %%
# gradient time
@btime ∇f(β, X, y)
@btime ∇f_auto(β)
# Out:
#   878.542 μs (5 allocations: 7.65 MiB)
#   220.715 ms (467 allocations: 16.79 MiB)
# 1000-element Vector{Float64}:
#   1.6321954038222625e-12
#   9.900029849635103e-14
#   6.60467264998852e-13
#   5.639302364233724e-13
#  -2.3336143099206565e-13
#  -1.0876015923364764e-12
#   2.4145508108254525e-12
#   8.560196882186117e-13
#   5.085072934970569e-13
#  -4.5327238892708e-13
#  -4.640575089703949e-13
#   1.3870106707262891e-12
#  -8.35149769034771e-13
#   ⋮
#   7.034051691074424e-13
#   1.1818353356712639e-12
#   1.3742213659241252e-12
#  -6.055607261938495e-14
#   2.1541920639901834e-12
#  -7.47081478866019e-13
#  -9.880517612907145e-13
#  -9.45421841784405e-13
#  -6.952139919132923e-13
#   2.8041203485439603e-12
#  -9.797590957048214e-13
#  -6.39786389009473e-13

# %%
# hessian time
@btime ∇²f(β, X, y)
@btime ∇²f_auto(β)
# Out:
#   64.791 μs (4 allocations: 79.92 KiB)
#   122.520 ms (424 allocations: 21.36 MiB)
# 100×100 Matrix{Float64}:
#  119.745      -5.80716    -8.9997     -1.18796     8.67201    -6.17836     8.38473    -4.179      -1.93365   …  -13.4517     -1.73344   -14.5646      5.89816  -10.4461     -6.01242    9.94028    19.9976     -7.95113    0.273596
#   -5.80716    91.3398    -20.0309      5.92322    22.855      -8.80886    -1.78752     2.38875    -1.43369       -2.7677     -0.795893    8.46903     4.31334   -8.12187    -3.21821   -6.97315   -11.0662    -10.6633   -10.9916
#   -8.9997    -20.0309    118.199      -3.04363     0.709349   -4.69749    12.6706      0.170084   -3.44246        7.72426     0.502916    1.27746    11.8372    -5.32281    -8.02232   -2.39394    15.6116      4.06819    5.18208
#   -1.18796     5.92322    -3.04363    77.3565     -4.62705    -4.12856     6.03224    11.3983     10.1077         7.62058    12.4171    -10.0888     -6.02778  -12.0567     11.3324    12.9987      2.0455     -3.26302    1.36018
#    8.67201    22.855       0.709349   -4.62705    95.369     -15.7657      3.36941    -5.87109     5.69472        0.997558    0.949379    6.76176     5.86906   -4.48395    -1.26306  -16.9476    -14.895      -4.03273  -22.0606
#   -6.17836    -8.80886    -4.69749    -4.12856   -15.7657    101.158       3.65203   -13.9569      6.59752   …   -3.73701     0.912378  -27.3966     16.2225    -1.35873    -7.73416    3.47436    -4.48566    16.717     -7.37694
#    8.38473    -1.78752    12.6706      6.03224     3.36941     3.65203   108.908       1.06182    13.6294        -7.47785    12.5775      4.26531    -9.88151   -7.78297   -15.9234     6.8217     -0.100552    3.20159   16.2016
#   -4.179       2.38875     0.170084   11.3983     -5.87109   -13.9569      1.06182    80.1503      9.91478       -7.56288    10.1318      4.00374     4.81635   -7.29584    12.953     -1.86264     7.46026   -12.4254    -6.46419
#   -1.93365    -1.43369    -3.44246    10.1077      5.69472     6.59752    13.6294      9.91478    73.5238        -2.69758    15.4315     -9.45105    -5.76549    1.6847      8.44645    0.442177   -7.63245    -5.50267  -14.3779
#  -13.9399     -2.0404     -6.15203    -7.90137     9.11956    -5.64542    -4.73483     3.32496     7.72597        8.28594    -6.13494   -14.6801     10.8159     2.40035     6.58276   -7.31996    -9.02472     3.58515   -4.39762
#   -4.32774    -1.59593     5.48978    11.7549     -4.97698    -5.19422    -5.02664     1.44788    -4.70039   …   12.8774     18.5479     -5.8161      2.30491   15.7185     14.645     24.5067     14.1576     12.9313     8.78672
#   -7.95671     2.62999   -13.0834      0.622282   -6.08907     8.39999   -11.1364    -19.5436     -0.666157      -5.46125    -0.309796    5.11645     1.28191   10.0005     -3.28182   10.5012     -1.77726     3.3795    10.7961
#   -1.08977    -1.50875   -15.6348     -1.8799    -13.9354      2.91924     5.73719    -6.1471      6.73975       -6.86861    16.8314     -5.40648    -3.5058    10.6134      5.74843   10.1649      0.30387     7.72615   13.5358
#    ⋮                                                           ⋮                                             ⋱    ⋮                                                          ⋮
#  -10.3339      1.99398    -7.4726     -2.15993     1.56588    22.2758      0.743826   20.7498      2.95973      -12.2833      2.41475     0.273977   18.9659   -10.4943     11.129      7.72106    -4.68874     4.77349    5.32354
#    8.56224    -0.649421   14.0567     -0.509997    5.09164    13.8732      8.54333    10.4008     -7.11496      -26.9507     -0.346652   10.4308    -10.1633     0.769786  -13.8381    -6.74231    10.4566      8.19089   -7.45453
#  -13.4517     -2.7677      7.72426     7.62058     0.997558   -3.73701    -7.47785    -7.56288    -2.69758   …   96.2657     10.8034      1.74406     3.69982    3.2225     13.5042    -7.25284    -5.67294   -10.0966    12.4775
#   -1.73344    -0.795893    0.502916   12.4171      0.949379    0.912378   12.5775     10.1318     15.4315        10.8034     97.0335      6.32683    -2.22113  -12.7704     -2.41541   -6.48647     0.505781   -3.2098     9.09656
#  -14.5646      8.46903     1.27746   -10.0888      6.76176   -27.3966      4.26531     4.00374    -9.45105        1.74406     6.32683   118.207       7.68577   -6.20816    14.837      0.18729    19.9418      4.31652    5.32017
#    5.89816     4.31334    11.8372     -6.02778     5.86906    16.2225     -9.88151     4.81635    -5.76549        3.69982    -2.22113     7.68577    82.2546    -4.09629     8.31067   -9.78928     5.44849     3.81629    4.39292
#  -10.4461     -8.12187    -5.32281   -12.0567     -4.48395    -1.35873    -7.78297    -7.29584     1.6847         3.2225    -12.7704     -6.20816    -4.09629   89.4634    -12.1611     8.51945   -14.9859      9.4199   -11.9773
#   -6.01242    -3.21821    -8.02232    11.3324     -1.26306    -7.73416   -15.9234     12.953       8.44645   …   13.5042     -2.41541    14.837       8.31067  -12.1611     81.5264     6.79223     3.25127    -4.7743     4.00896
#    9.94028    -6.97315    -2.39394    12.9987    -16.9476      3.47436     6.8217     -1.86264     0.442177      -7.25284    -6.48647     0.18729    -9.78928    8.51945     6.79223  110.299      -8.96179   -16.1255    -4.62155
#   19.9976    -11.0662     15.6116      2.0455    -14.895      -4.48566    -0.100552    7.46026    -7.63245       -5.67294     0.505781   19.9418      5.44849  -14.9859      3.25127   -8.96179    87.2365      5.03021   11.8331
#   -7.95113   -10.6633      4.06819    -3.26302    -4.03273    16.717       3.20159   -12.4254     -5.50267      -10.0966     -3.2098      4.31652     3.81629    9.4199     -4.7743   -16.1255      5.03021    81.2011     9.78392
#    0.273596  -10.9916      5.18208     1.36018   -22.0606     -7.37694    16.2016     -6.46419   -14.3779        12.4775      9.09656     5.32017     4.39292  -11.9773      4.00896   -4.62155    11.8331      9.78392  114.875
