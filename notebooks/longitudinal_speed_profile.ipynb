# %% [markdown]
# # Longitudinal GWAS Profiler

# %%
using QuasiCopula
using Random
using GLM
using LinearAlgebra
using Statistics
using StatsBase
using Profile
using ProfileCanvas
# Out:
# [ Info: Precompiling QuasiCopula [c47b6ae2-b804-4668-9957-eb588c99ffbc]
# WARNING: method definition for pmf_copula! at /Users/biona001/.julia/dev/QuasiCopula/src/generate_random_deviates/discrete_rand.jl:86 declares type variable T but does not use it.
# WARNING: method definition for rand at /Users/biona001/.julia/dev/QuasiCopula/src/generate_random_deviates/discrete_rand.jl:128 declares type variable T but does not use it.
# WARNING: method definition for rand at /Users/biona001/.julia/dev/QuasiCopula/src/generate_random_deviates/discrete_rand.jl:149 declares type variable T but does not use it.
# WARNING: Method definition loglikelihood(AbstractArray{T, 1} where T, QuasiCopula.GLMCopulaVCModel{T, D, Link} where Link where D where T<:Union{Float32, Float64}, AbstractArray{T, 1} where T) in module QuasiCopula at /Users/biona001/.julia/dev/QuasiCopula/src/gwas/longitudinal_autodiff.jl:1 overwritten at /Users/biona001/.julia/dev/QuasiCopula/src/gwas/longitudinal_autodiff_fast.jl:6.
#   ** incremental compilation may be fatally broken for this module **

# %%
# simulate data
k = 0 # number of causal SNPs
qc_model, G, βtrue, θtrue, γtrue, τtrue = simulate_longitudinal_traits(
    n = 10000, # sample size
    d_min = 5, # min number of observations per sample
    d_max = 5, # max number of observations per sample
    p = 15, # number of fixed effects, including intercept
    m = 2, # number of variance components
    q = 100, # number of SNPs
    k = k, # number of causal SNPs
    seed = 2022,
    y_distribution = Bernoulli,
    τtrue = 0.5,
    T = Float64,
    maf = 0.3,
    causal_snp_β = 0.2
)

# fit null
optm = QuasiCopula.fit!(qc_model,
    Ipopt.IpoptSolver(
        print_level = 5, 
        tol = 10^-3, 
        max_iter = 1000,
        accept_after_max_steps = 50,
        warm_start_init_point="yes", 
        limited_memory_max_history = 6, # default value
        hessian_approximation = "limited-memory",
        derivative_test="first-order"
    )
);
# Out:
# ┌ Warning: #= /Users/biona001/.julia/dev/QuasiCopula/src/parameter_estimation/update_sigma_and_residuals.jl:65 =#:
# │ `LoopVectorization.check_args` on your inputs failed; running fallback `@inbounds @fastmath` loop instead.
# │ Use `warn_check_args=false`, e.g. `@turbo warn_check_args=false ...`, to disable this warning.
# └ @ QuasiCopula ~/.julia/packages/LoopVectorization/7gWfp/src/condense_loopset.jl:1148
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.13.4, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Starting derivative checker for first derivatives.
#
#
# No errors detected by derivative checker.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       17
#                      variables with only lower bounds:        2
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.8962139e+04 0.00e+00 9.99e+01   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.8232302e+04 0.00e+00 1.20e+02  -3.8 9.99e+01    -  1.00e+00 7.34e-03f  4
#    2  2.7626017e+04 0.00e+00 5.25e+01  -5.2 4.59e-01    -  1.00e+00 7.77e-01f  1
#    3  2.7618561e+04 0.00e+00 5.16e+01  -6.4 2.75e-01    -  1.00e+00 2.75e-02f  1
#    4  2.7403401e+04 0.00e+00 2.71e+01  -7.8 4.37e-01    -  1.00e+00 7.06e-01f  1
#    5  2.7301632e+04 0.00e+00 5.52e+01  -8.6 4.89e-01    -  1.00e+00 1.00e+00f  1
#    6  2.7174222e+04 0.00e+00 9.17e+00 -10.4 5.36e-01    -  1.00e+00 1.00e+00f  1
#    7  2.7155479e+04 0.00e+00 1.88e+01  -7.3 5.83e-01    -  6.92e-01 2.50e-01f  3
#    8  2.7121122e+04 0.00e+00 9.55e+00  -5.8 2.98e-01    -  1.97e-02 1.00e+00f  1
#    9  2.7121058e+04 0.00e+00 1.03e+01  -5.7 1.50e+00    -  1.00e+00 1.25e-01f  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.7079299e+04 0.00e+00 8.94e+00  -6.3 7.40e-01    -  1.00e+00 1.00e+00f  1
#   11  2.7074912e+04 0.00e+00 5.91e+00  -5.0 2.27e+00    -  1.00e+00 6.25e-02f  5
#   12  2.7068732e+04 0.00e+00 5.95e+00  -5.8 5.34e-01    -  1.00e+00 5.00e-01f  2
#   13  2.7062474e+04 0.00e+00 1.41e+01  -5.1 3.77e+00    -  1.00e+00 1.25e-01f  4
#   14  2.7055644e+04 0.00e+00 4.68e+00  -4.5 1.61e+01    -  1.00e+00 3.12e-02f  6
#   15  2.7054799e+04 0.00e+00 6.38e+00  -3.7 5.66e+00    -  1.00e+00 3.12e-02f  6
#   16  2.7052262e+04 0.00e+00 5.79e+00  -4.5 7.53e-01    -  1.00e+00 2.50e-01f  3
#   17  2.7050534e+04 0.00e+00 6.87e+00  -4.2 4.36e+00    -  1.00e+00 2.50e-01f  3
#   18  2.7050305e+04 0.00e+00 6.43e+00  -4.8 7.72e-01    -  1.00e+00 1.56e-02f  7
#   19  2.7047242e+04 0.00e+00 8.56e+00  -6.4 2.44e-01    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  2.7046255e+04 0.00e+00 6.24e+00  -6.4 5.94e-01    -  1.00e+00 2.50e-01f  3
#   21  2.7045218e+04 0.00e+00 3.25e+00  -7.2 9.52e-02    -  1.00e+00 1.25e-01f  4
#   22  2.7042826e+04 0.00e+00 8.34e-01  -9.0 3.96e-02    -  1.00e+00 1.00e+00f  1
#   23  2.7042501e+04 0.00e+00 9.78e-01 -10.0 1.23e-01    -  1.00e+00 1.00e+00f  1
#   24  2.7042362e+04 0.00e+00 1.26e+01  -9.3 3.36e+01    -  1.00e+00 6.25e-02f  5
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
#   25  2.7040901e+04 0.00e+00 5.94e+00  -7.8 1.21e+03    -  2.99e-03 9.77e-04f 11
#   26  2.7040772e+04 0.00e+00 6.04e+00  -9.6 3.44e+01    -  1.00e+00 1.95e-03f 10
#   27  2.7039680e+04 0.00e+00 7.50e+00 -10.4 3.01e-01    -  1.00e+00 2.50e-01f  3
#   28  2.7034841e+04 0.00e+00 7.16e+00 -11.0 2.00e+00    -  1.00e+00 5.00e-01f  2
#   29  2.7034378e+04 0.00e+00 8.28e+00 -11.0 5.01e+01    -  1.00e+00 1.15e-02f  5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  2.7033872e+04 0.00e+00 7.62e+00 -11.0 3.54e+02    -  1.00e+00 3.04e-03f  4
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
#   31  2.7030492e+04 0.00e+00 1.00e+01  -6.7 1.06e+03    -  2.31e-03 9.77e-04f 11
# Warning: Cutting back alpha due to evaluation error
#   32  2.7023357e+04 0.00e+00 1.18e+01  -7.0 8.86e+02    -  1.00e+00 3.91e-03f  9
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
#   33  2.7018756e+04 0.00e+00 9.26e+00  -4.9 1.23e+03    -  6.49e-03 1.95e-03f 10
# Warning: Cutting back alpha due to evaluation error
#   34  2.7018396e+04 0.00e+00 1.44e+01  -7.1 1.87e+02    -  1.00e+00 1.95e-03f 10
#   35  2.7017924e+04 0.00e+00 1.27e+01 -11.0 2.77e+01    -  1.00e+00 9.91e-03f  6
#   36  2.7017556e+04 0.00e+00 1.15e+01  -7.5 5.31e+01    -  1.00e+00 3.91e-03f  9
#   37  2.7017506e+04 0.00e+00 1.77e+01  -6.8 5.33e+01    -  1.00e+00 3.12e-02f  6
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
#   38  2.7013253e+04 0.00e+00 1.03e+01  -5.1 4.06e+03    -  2.56e-03 1.95e-03f 10
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
#   39  2.7008906e+04 0.00e+00 8.47e+00  -5.8 2.17e+04    -  9.29e-04 4.88e-04f 12
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  2.7008731e+04 0.00e+00 4.40e+00  -6.9 4.23e+04    -  6.78e-04 6.10e-05f 15
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
#   41  2.7008705e+04 0.00e+00 4.85e+00  -8.0 3.90e+03    -  1.96e-02 2.44e-04f 13
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
#   42  2.7008572e+04 0.00e+00 4.86e+00  -8.1 1.18e+03    -  1.00e+00 4.88e-04f 12
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
#   43  2.7007737e+04 0.00e+00 6.55e+00  -6.4 1.10e+04    -  3.48e-03 2.44e-04f 13
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
#   44  2.7006329e+04 0.00e+00 5.62e+00  -7.1 5.02e+04    -  7.07e-04 2.44e-04f 13
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
#   45  2.7005811e+04 0.00e+00 4.07e+00  -8.3 9.20e+05    -  5.11e-05 1.53e-05f 17
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
#   46  2.7005545e+04 0.00e+00 5.48e+00  -9.4 3.53e+06    -  1.75e-05 1.91e-06f 20
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
#   47  2.7004856e+04 0.00e+00 3.43e+00 -10.7 2.55e+05    -  2.81e-04 1.53e-05f 17
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
#   48  2.7004680e+04 0.00e+00 2.19e+00 -11.0 1.35e+05    -  1.00e+00 1.53e-05f 17
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
#   49  2.7004660e+04 0.00e+00 2.20e+00  -9.8 5.64e+04    -  1.46e-03 6.10e-05f 15
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  2.7004640e+04 0.00e+00 3.03e+00 -10.9 2.21e+06    -  3.45e-05 9.54e-07f 21
#   51  2.7004564e+04 0.00e+00 2.96e+00 -11.0 9.77e+04    -  1.00e+00 1.25e-05f  7
#   52  2.7004541e+04 0.00e+00 2.36e+00 -11.0 2.61e+04    -  1.00e+00 2.31e-05f  8
#   53  2.7004045e+04 0.00e+00 1.03e+00 -11.0 1.46e+04    -  1.00e+00 8.19e-05f  7
#   54  2.7004042e+04 0.00e+00 9.64e-01 -11.0 4.91e+03    -  1.00e+00 1.20e-04f  8
#   55  2.7004025e+04 0.00e+00 1.21e+00 -10.3 1.89e+04    -  1.00e+00 3.87e-06f 11
#   56  2.7004022e+04 0.00e+00 1.17e+00  -7.9 1.72e+01    -  1.00e+00 7.81e-03f  8
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
#   57  2.7004016e+04 0.00e+00 9.82e-01  -8.6 9.05e+01    -  4.50e-01 6.10e-05f 15
#   58  2.7003897e+04 0.00e+00 1.64e-01  -5.4 4.30e-01    -  1.00e+00 1.00e+00f  1
#   59  2.7003896e+04 0.00e+00 1.86e-02 -11.0 7.92e+02    -  1.00e+00 9.24e-05f 11
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60  2.7003896e+04 0.00e+00 8.76e-02 -10.5 1.16e+03    -  1.00e+00 5.04e-04f  8
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
#   61  2.7003896e+04 0.00e+00 6.65e-02  -9.3 5.28e+02    -  1.00e+00 1.07e-06f 18
#   62  2.7003892e+04 0.00e+00 6.79e-02  -8.5 3.08e+00    -  1.00e+00 1.00e+00f  1
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
#   63  2.7003892e+04 0.00e+00 6.84e-02  -2.8 2.03e+03    -  1.00e+00 6.69e-08f 20
#   64  2.7003886e+04 0.00e+00 4.74e-02  -8.5 1.42e+01    -  1.00e+00 5.00e-01f  2
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
#   65  2.7003886e+04 0.00e+00 6.68e-02  -1.8 8.35e+03    -  1.03e-01 1.19e-07f 24
#   66  2.7003886e+04 0.00e+00 8.30e-02  -3.2 7.62e-02    -  1.00e+00 1.00e+00f  1
#   67  2.7003886e+04 0.00e+00 1.41e-01  -9.2 8.15e+01    -  1.00e+00 9.61e-05f 14
#   68  2.7003886e+04 0.00e+00 7.23e-02  -9.3 1.31e+01    -  1.00e+00 1.56e-02f  7
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
#   69  2.7003885e+04 0.00e+00 1.25e-01  -3.0 8.22e+02    -  1.00e+00 3.05e-05f 16
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70  2.7003862e+04 0.00e+00 5.94e-01 -10.7 2.54e+02    -  1.00e+00 3.15e-02f  4
#   71  2.7003850e+04 0.00e+00 9.80e-01  -2.1 7.76e+04    -  7.27e-04 3.09e-06f  9
#   72  2.7003753e+04 0.00e+00 1.60e+00 -10.1 5.21e+03    -  1.00e+00 2.68e-03f  3
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
#   73  2.7003766e+04 0.00e+00 1.92e+00  -0.9 3.35e+05    -  2.30e-04 3.18e-06f 19
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
#   74  2.7003741e+04 0.00e+00 1.21e+00  -2.4 5.55e+03    -  5.77e-01 6.10e-05f 15
# Warning: Cutting back alpha due to evaluation error
#   75  2.7003739e+04 0.00e+00 1.26e+00  -8.9 3.89e+02    -  1.04e-01 1.22e-04f 14
#   76  2.7003716e+04 0.00e+00 1.43e+00  -2.5 5.40e+03    -  2.17e-02 1.95e-03f 10
#   77  2.7003699e+04 0.00e+00 8.56e-01 -10.7 1.74e+06    -  4.93e-04 2.36e-07f  8
# Warning: Cutting back alpha due to evaluation error
#   78  2.7003689e+04 0.00e+00 1.26e+00  -3.4 7.00e+03    -  1.21e-02 9.77e-04f 11
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
#   79  2.7003661e+04 0.00e+00 9.49e-01  -3.6 4.46e+05    -  2.24e-04 1.91e-06f 20
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80  2.7003619e+04 0.00e+00 1.30e+00 -11.0 4.68e+04    -  1.00e+00 8.13e-05f  5
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
#   81  2.7003616e+04 0.00e+00 1.30e+00  -3.4 4.74e+04    -  1.00e+00 4.37e-06f 17
# Warning: Cutting back alpha due to evaluation error
#   82  2.7003614e+04 0.00e+00 1.32e+00  -4.2 6.57e+02    -  1.00e+00 9.68e-05f 14
#   83  2.7003613e+04 0.00e+00 1.00e+00  -3.6 6.89e+02    -  1.00e+00 9.77e-04f 11
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
# Warning: Cutting back alpha due to evaluation error
#   84  2.7003567e+04 0.00e+00 6.45e-01  -2.5 1.52e+04    -  1.00e+00 3.05e-05f 16
#   85  2.7003551e+04 0.00e+00 8.61e-01  -8.3 1.51e+03    -  7.50e-01 1.51e-04f  9
#   86  2.7003545e+04 0.00e+00 7.30e-01  -3.1 4.19e+02    -  1.00e+00 9.77e-04f 11
#   87  2.7003527e+04 0.00e+00 6.28e-01  -2.0 5.40e+03    -  1.00e+00 6.43e-05f  9
#   88  2.7003526e+04 0.00e+00 6.26e-01  -3.8 2.31e+02    -  1.00e+00 2.20e-04f 13
#   89  2.7003526e+04 0.00e+00 6.36e-01  -4.0 3.70e+01    -  1.00e+00 4.88e-04f 12
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90  2.7003521e+04 0.00e+00 4.60e-01  -3.1 4.66e+02    -  1.00e+00 4.13e-04f 12
#   91  2.7003521e+04 0.00e+00 4.31e-01  -3.7 5.44e+02    -  1.00e+00 4.88e-04f 12
#   92  2.7003506e+04 0.00e+00 1.72e-01  -8.0 2.48e+03    -  7.78e-01 2.30e-05f 11
#   93  2.7003504e+04 0.00e+00 2.12e-01  -4.5 3.76e+01    -  1.00e+00 1.95e-03f 10
#   94  2.7003503e+04 0.00e+00 2.33e-01  -4.6 7.46e+02    -  1.00e+00 3.05e-04f  9
#   95  2.7003503e+04 0.00e+00 2.20e-01  -4.4 1.54e+02    -  1.00e+00 1.84e-04f 12
#   96  2.7003502e+04 0.00e+00 2.38e-01  -4.0 4.81e+01    -  1.00e+00 9.77e-04f 11
#   97  2.7003502e+04 0.00e+00 1.98e-01  -4.0 9.48e+01    -  1.00e+00 1.49e-04f 13
#   98  2.7003502e+04 0.00e+00 2.04e-01  -3.8 3.06e+01    -  1.00e+00 3.91e-03f  9
#   99  2.7003502e+04 0.00e+00 1.85e-01  -4.1 1.02e+02    -  1.00e+00 6.90e-05f 14
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100  2.7003501e+04 0.00e+00 2.57e-01  -3.9 2.13e+01    -  1.00e+00 1.95e-03f 10
# Warning: Cutting back alpha due to evaluation error
#  101  2.7003497e+04 0.00e+00 5.09e-02  -1.7 8.42e+01    -  9.84e-01 1.22e-04f 14
#  102  2.7003497e+04 0.00e+00 7.36e-02  -4.1 1.67e+00    -  9.99e-01 6.25e-02f  5
#  103  2.7003497e+04 0.00e+00 6.20e-02  -3.0 7.78e+02    -  1.00e+00 5.72e-05f 14
#  104  2.7003497e+04 0.00e+00 4.70e-02  -3.9 1.60e+02    -  1.00e+00 3.05e-05f 16
#  105  2.7003497e+04 0.00e+00 3.69e-02  -5.5 1.96e+01    -  1.00e+00 1.95e-03f 10
#  106  2.7003497e+04 0.00e+00 3.23e-02  -5.6 5.56e+01    -  1.00e+00 6.10e-05f 15
#  107  2.7003497e+04 0.00e+00 3.00e-02  -7.5 1.75e+01    -  1.00e+00 9.77e-04f 11
#  108  2.7003497e+04 0.00e+00 1.82e-02  -7.3 3.51e+01    -  1.00e+00 1.22e-04f 14
#  109  2.7003497e+04 0.00e+00 1.57e-02  -9.6 9.45e+00    -  1.00e+00 3.91e-03f  9
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  110  2.7003497e+04 0.00e+00 1.59e-02  -9.8 5.46e+02    -  1.00e+00 5.19e-05f 12
#  111  2.7003497e+04 0.00e+00 1.63e-02 -11.0 2.40e+01    -  1.00e+00 3.05e-05f 16
#  112  2.7003497e+04 0.00e+00 1.37e-02  -7.8 2.32e+01    -  1.00e+00 4.88e-04f 12
#  113  2.7003497e+04 0.00e+00 1.45e-02  -8.9 2.46e+01    -  1.00e+00 6.10e-05f 15
#  114  2.7003497e+04 0.00e+00 7.88e-03  -8.3 3.16e+01    -  1.00e+00 2.44e-04f 13
#  115  2.7003497e+04 0.00e+00 9.07e-03 -10.1 8.09e-01    -  1.00e+00 2.44e-04f 13
#  116  2.7003497e+04 0.00e+00 6.63e-03  -9.9 1.07e-02    -  1.00e+00 1.00e+00f  1
#  117  2.7003497e+04 0.00e+00 5.35e-03 -10.0 4.21e+01    -  1.00e+00 1.22e-04f 14
#  118  2.7003497e+04 0.00e+00 5.10e-03 -10.3 5.87e+00    -  1.00e+00 4.88e-04f 12
#  119  2.7003497e+04 0.00e+00 4.69e-03 -10.3 6.24e+00    -  1.00e+00 6.10e-05f 15
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  120  2.7003497e+04 0.00e+00 5.40e-03 -10.3 9.68e-02    -  1.00e+00 9.77e-04f 11
#  121  2.7003497e+04 0.00e+00 3.98e-03 -10.3 1.12e-01    -  1.00e+00 1.95e-03f 10
#  122  2.7003497e+04 0.00e+00 5.07e-03 -10.3 1.18e+00    -  1.00e+00 9.77e-04f 11
#  123  2.7003497e+04 0.00e+00 6.12e-03 -10.3 1.48e+02    -  1.00e+00 4.84e-05f 14
#  124  2.7003497e+04 0.00e+00 5.07e-03 -10.3 3.56e+01    -  1.00e+00 1.22e-04f 14
#  125  2.7003497e+04 0.00e+00 5.31e-03 -11.0 4.60e+00    -  1.00e+00 4.88e-04f 12
#  126  2.7003497e+04 0.00e+00 5.03e-03 -10.9 4.63e+00    -  1.00e+00 6.10e-05f 15
#  127  2.7003497e+04 0.00e+00 5.49e-03 -10.9 5.62e-02    -  1.00e+00 9.77e-04f 11
#  128  2.7003497e+04 0.00e+00 4.50e-03 -10.9 9.29e-02    -  1.00e+00 1.95e-03f 10
#  129  2.7003497e+04 0.00e+00 5.66e-03 -10.9 6.96e-01    -  1.00e+00 1.95e-03f 10
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  130  2.7003497e+04 0.00e+00 4.56e-03 -10.9 1.46e+02    -  4.03e-01 3.05e-05f 16
#  131  2.7003497e+04 0.00e+00 3.38e-03 -11.0 2.38e+01    -  1.00e+00 1.22e-04f 14
#  132  2.7003497e+04 0.00e+00 2.35e-03 -11.0 3.27e+00    -  1.00e+00 4.88e-04f 12
#  133  2.7003497e+04 0.00e+00 2.33e-03 -11.0 3.26e+00    -  1.00e+00 6.10e-05f 15
#  134  2.7003497e+04 0.00e+00 2.24e-03 -11.0 9.25e-02    -  1.00e+00 2.44e-04f 13
#  135  2.7003497e+04 0.00e+00 2.40e-03 -11.0 2.27e-02    -  1.00e+00 7.81e-03f  8
#  136  2.7003497e+04 0.00e+00 2.73e-03 -11.0 3.19e+00    -  1.00e+00 4.88e-04f 12
#  137  2.7003497e+04 0.00e+00 2.72e-03 -11.0 5.95e+01    -  1.00e+00 3.00e-05f 16
#  138  2.7003497e+04 0.00e+00 1.58e-03 -11.0 9.01e+00    -  1.00e+00 1.22e-04f 14
#  139  2.7003497e+04 0.00e+00 9.76e-04 -11.0 7.71e-01    -  1.00e+00 9.77e-04f 11
#
# Number of Iterations....: 139
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5709394668403863e+03    2.7003496665523991e+04
# Dual infeasibility......:   9.7628521245637565e-04    1.6781750688452668e-02
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   1.0173694669040988e-11    1.7487964104947953e-10
# Overall NLP error.......:   9.7628521245637565e-04    1.6781750688452668e-02
#
#
# Number of objective function evaluations             = 1753
# Number of objective gradient evaluations             = 140
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      1.743
# Total CPU secs in NLP function evaluations           =     18.912
#
# EXIT: Optimal Solution Found.

# %% [markdown]
# Profile 3/13/2024 (inlined tight utility functions)

# %%
@profview QuasiCopula.GWASCopulaVCModel(qc_model, G, check_grad=false)
@profview QuasiCopula.GWASCopulaVCModel(qc_model, G, check_grad=false)

# %%
# 3/13/2024 (inlined)
@profile QuasiCopula.GWASCopulaVCModel(qc_model, G, check_grad=false)
Profile.clear()
@profile QuasiCopula.GWASCopulaVCModel(qc_model, G, check_grad=false)
Profile.print()
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:03
# Wtime = 1.5166416950074502
# Qtime = 0.5367031009998927
# Rtime = 0.19146811399755642
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:02
# Wtime = 1.5212497930063433
# Qtime = 0.5293969789999429
# Rtime = 0.18838202599766987
# Overhead ╎ [+additional indent] Count File:Line; Function
# =========================================================
#    1╎1    @Base/abstractarray.jl:0; copyto_unaliased!(deststyle::I...
#    1╎1    @Base/arraymath.jl:16; +(A::Matrix{Float64}, Bs::Matr...
#    2╎2    @Base/broadcast.jl:811; broadcast(::typeof(*), ::Float...
#     ╎1    ...multidimensional.jl:1003; mightalias(A::SubArray{Float64...
#    1╎ 1    @Base/Base.jl:37; getproperty
#   25╎25   @Base/special/exp.jl:325; exp(x::Float64)
#     ╎1275 @Base/task.jl:514; (::IJulia.var"#15#18")()
#     ╎ 1275 ...lia/src/eventloop.jl:8; eventloop(socket::ZMQ.Socket)
#     ╎  1275 @Base/essentials.jl:813; invokelatest
#     ╎   1275 @Base/essentials.jl:816; #invokelatest#2
#     ╎    1275 ...execute_request.jl:67; execute_request(socket::ZMQ.S...
#     ╎     1275 ...SoftGlobalScope.jl:65; softscope_include_string(m::...
#     ╎    ╎ 1275 @Base/loading.jl:1899; include_string(mapexpr::typ...
#     ╎    ╎  1275 @Base/boot.jl:370; eval
#     ╎    ╎   1275 ...s/longitudinal.jl:58; kwcall(::NamedTuple{(:check...
#     ╎    ╎    138  .../longitudinal.jl:84; GWASCopulaVCModel(qc_mode...
#     ╎    ╎     129  ...longitudinal.jl:260; get_Pinv(qc_model::GLMCop...
#    1╎    ╎    ╎ 1    @Base/simdloop.jl:0; get_Hββ(qc_model::GLMCop...
#     ╎    ╎    ╎ 2    ...longitudinal.jl:444; get_Hββ(qc_model::GLMCop...
#     ╎    ╎    ╎  2    .../src/matmul.jl:1166; *
#     ╎    ╎    ╎   2    .../src/matmul.jl:1170; _tri_matmul
#     ╎    ╎    ╎    2    ...src/matmul.jl:1178; _tri_matmul(A::Transpo...
#     ╎    ╎    ╎     1    ...c/diagonal.jl:256; *
#     ╎    ╎    ╎    ╎ 1    .../transpose.jl:210; copy_similar
#     ╎    ╎    ╎    ╎  1    ...c/adjtrans.jl:335; similar
#     ╎    ╎    ╎    ╎   1    @Base/array.jl:374; similar
#     ╎    ╎    ╎    ╎    1    @Base/boot.jl:487; Array
#    1╎    ╎    ╎    ╎     1    @Base/boot.jl:479; Array
#     ╎    ╎    ╎     1    ...src/matmul.jl:148; *
#     ╎    ╎    ╎    ╎ 1    @Base/array.jl:374; similar
#     ╎    ╎    ╎    ╎  1    @Base/boot.jl:487; Array
#    1╎    ╎    ╎    ╎   1    @Base/boot.jl:479; Array
#     ╎    ╎    ╎ 8    ...longitudinal.jl:448; get_Hββ(qc_model::GLMCop...
#     ╎    ╎    ╎  8    @Base/array.jl:580; zeros
#     ╎    ╎    ╎   8    @Base/array.jl:584; zeros
#     ╎    ╎    ╎    8    @Base/boot.jl:487; Array
#    8╎    ╎    ╎     8    @Base/boot.jl:479; Array
#     ╎    ╎    ╎ 1    ...longitudinal.jl:450; get_Hββ(qc_model::GLMCop...
#     ╎    ╎    ╎  1    @Base/broadcast.jl:881; materialize!
#     ╎    ╎    ╎   1    ...e/broadcast.jl:884; materialize!
#     ╎    ╎    ╎    1    ...e/broadcast.jl:926; copyto!
#     ╎    ╎    ╎     1    .../broadcast.jl:973; copyto!
#     ╎    ╎    ╎    ╎ 1    ...e/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎  1    .../broadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎   1    ...broadcast.jl:610; getindex
#     ╎    ╎    ╎    ╎    1    ...broadcast.jl:655; _broadcast_getindex
#     ╎    ╎    ╎    ╎     1    ...roadcast.jl:679; _getindex
#     ╎    ╎    ╎    ╎    ╎ 1    ...roadcast.jl:680; _getindex
#     ╎    ╎    ╎    ╎    ╎  1    ...roadcast.jl:656; _broadcast_getindex
#     ╎    ╎    ╎    ╎    ╎   1    ...oadcast.jl:683; _broadcast_getind...
#    1╎    ╎    ╎    ╎    ╎    1    ...e/float.jl:410; *
#     ╎    ╎    ╎ 1    ...longitudinal.jl:453; get_Hββ(qc_model::GLMCop...
#     ╎    ╎    ╎  1    @Base/arraymath.jl:24; /(A::Matrix{Float64}, B:...
#     ╎    ╎    ╎   1    ...e/broadcast.jl:862; broadcast_preserving_ze...
#     ╎    ╎    ╎    1    ...e/broadcast.jl:873; materialize
#     ╎    ╎    ╎     1    .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎ 1    .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎  1    .../broadcast.jl:970; copyto!
#     ╎    ╎    ╎    ╎   1    ...broadcast.jl:953; preprocess
#     ╎    ╎    ╎    ╎    1    ...broadcast.jl:956; preprocess_args
#     ╎    ╎    ╎    ╎     1    ...roadcast.jl:954; preprocess
#     ╎    ╎    ╎    ╎    ╎ 1    ...roadcast.jl:650; extrude
#     ╎    ╎    ╎    ╎    ╎  1    ...roadcast.jl:599; newindexer
#     ╎    ╎    ╎    ╎    ╎   1    ...oadcast.jl:600; shapeindexer
#     ╎    ╎    ╎    ╎    ╎    1    ...oadcast.jl:604; _newindexer
#     ╎    ╎    ╎    ╎    ╎     1    ...adcast.jl:605; _newindexer
#     ╎    ╎    ╎    ╎    ╎    ╎ 1    ...rators.jl:269; !=
#    1╎    ╎    ╎    ╎    ╎    ╎  1    ...motion.jl:499; ==
#     ╎    ╎    ╎ 7    ...longitudinal.jl:455; get_Hββ(qc_model::GLMCop...
#     ╎    ╎    ╎  3    ...e/arraymath.jl:16; +(A::Matrix{Float64}, B...
#     ╎    ╎    ╎   3    ...e/broadcast.jl:862; broadcast_preserving_ze...
#     ╎    ╎    ╎    3    ...e/broadcast.jl:873; materialize
#     ╎    ╎    ╎     3    .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎ 3    .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎  3    .../broadcast.jl:973; copyto!
#    1╎    ╎    ╎    ╎   1    ...e/simdloop.jl:75; macro expansion
#     ╎    ╎    ╎    ╎   2    ...e/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎    2    ...broadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎     2    ...ensional.jl:670; setindex!
#    2╎    ╎    ╎    ╎    ╎ 2    @Base/array.jl:971; setindex!
#     ╎    ╎    ╎  1    ...e/arraymath.jl:24; /(A::Matrix{Float64}, B...
#     ╎    ╎    ╎   1    ...e/broadcast.jl:862; broadcast_preserving_ze...
#     ╎    ╎    ╎    1    ...e/broadcast.jl:873; materialize
#     ╎    ╎    ╎     1    .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎ 1    .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎  1    .../broadcast.jl:973; copyto!
#     ╎    ╎    ╎    ╎   1    ...e/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎    1    ...broadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎     1    ...ensional.jl:670; setindex!
#    1╎    ╎    ╎    ╎    ╎ 1    @Base/array.jl:971; setindex!
#     ╎    ╎    ╎  3    .../src/matmul.jl:1166; *
#     ╎    ╎    ╎   3    .../src/matmul.jl:1170; _tri_matmul
#     ╎    ╎    ╎    3    ...src/matmul.jl:1178; _tri_matmul(A::Adjoint...
#     ╎    ╎    ╎     3    ...src/matmul.jl:148; *
#     ╎    ╎    ╎    ╎ 2    @Base/array.jl:374; similar
#     ╎    ╎    ╎    ╎  2    @Base/boot.jl:487; Array
#    2╎    ╎    ╎    ╎   2    @Base/boot.jl:479; Array
#     ╎    ╎    ╎    ╎ 1    ...src/matmul.jl:276; mul!
#     ╎    ╎    ╎    ╎  1    ...src/matmul.jl:425; mul!
#     ╎    ╎    ╎    ╎   1    ...rc/matmul.jl:378; mul!
#     ╎    ╎    ╎    ╎    1    ...rc/matmul.jl:674; gemm_wrapper!(C::Ma...
#    1╎    ╎    ╎    ╎     1    ...src/blas.jl:1524; gemm!(transA::Char...
#     ╎    ╎    ╎ 6    ...longitudinal.jl:465; get_Hββ(qc_model::GLMCop...
#     ╎    ╎    ╎  6    ...stractarray.jl:1294; getindex
#     ╎    ╎    ╎   6    ...dimensional.jl:861; _getindex
#     ╎    ╎    ╎    4    ...dimensional.jl:873; _unsafe_getindex
#     ╎    ╎    ╎     4    ...tractarray.jl:836; similar
#     ╎    ╎    ╎    ╎ 4    @Base/array.jl:374; similar
#     ╎    ╎    ╎    ╎  4    @Base/boot.jl:486; Array
#    4╎    ╎    ╎    ╎   4    @Base/boot.jl:477; Array
#     ╎    ╎    ╎    2    ...dimensional.jl:875; _unsafe_getindex
#     ╎    ╎    ╎     2    ...imensional.jl:884; _unsafe_getindex!
#     ╎    ╎    ╎    ╎ 1    .../cartesian.jl:64; macro expansion
#    1╎    ╎    ╎    ╎  1    ...imensional.jl:887; macro expansion
#     ╎    ╎    ╎    ╎ 1    .../cartesian.jl:66; macro expansion
#     ╎    ╎    ╎    ╎  1    @Base/indices.jl:393; iterate
#     ╎    ╎    ╎    ╎   1    @Base/range.jl:891; iterate
#    1╎    ╎    ╎    ╎    1    ...promotion.jl:499; ==
#     ╎    ╎    ╎ 103  ...longitudinal.jl:468; get_Hββ(qc_model::GLMCop...
#    1╎    ╎    ╎  1    @Base/arraymath.jl:12; +(A::Matrix{Float64}, Bs...
#     ╎    ╎    ╎  10   @Base/arraymath.jl:16; +(A::Matrix{Float64}, Bs...
#     ╎    ╎    ╎   10   ...e/broadcast.jl:862; broadcast_preserving_ze...
#     ╎    ╎    ╎    10   ...e/broadcast.jl:873; materialize
#     ╎    ╎    ╎     10   .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎ 6    .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎  1    .../broadcast.jl:970; copyto!
#     ╎    ╎    ╎    ╎   1    ...broadcast.jl:953; preprocess
#     ╎    ╎    ╎    ╎    1    ...broadcast.jl:956; preprocess_args
#     ╎    ╎    ╎    ╎     1    ...roadcast.jl:957; preprocess_args
#     ╎    ╎    ╎    ╎    ╎ 1    ...roadcast.jl:954; preprocess
#     ╎    ╎    ╎    ╎    ╎  1    ...roadcast.jl:650; extrude
#     ╎    ╎    ╎    ╎    ╎   1    ...oadcast.jl:599; newindexer
#     ╎    ╎    ╎    ╎    ╎    1    ...oadcast.jl:600; shapeindexer
#     ╎    ╎    ╎    ╎    ╎     1    ...adcast.jl:604; _newindexer
#     ╎    ╎    ╎    ╎    ╎    ╎ 1    ...adcast.jl:605; _newindexer
#     ╎    ╎    ╎    ╎    ╎    ╎  1    ...rators.jl:269; !=
#    1╎    ╎    ╎    ╎    ╎    ╎   1    ...motion.jl:499; ==
#     ╎    ╎    ╎    ╎  5    .../broadcast.jl:973; copyto!
#    1╎    ╎    ╎    ╎   1    ...e/simdloop.jl:0; macro expansion
#    2╎    ╎    ╎    ╎   2    ...e/simdloop.jl:75; macro expansion
#     ╎    ╎    ╎    ╎   2    ...e/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎    2    ...broadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎     2    ...ensional.jl:670; setindex!
#    2╎    ╎    ╎    ╎    ╎ 2    @Base/array.jl:971; setindex!
#     ╎    ╎    ╎    ╎ 4    .../broadcast.jl:211; similar
#     ╎    ╎    ╎    ╎  4    .../broadcast.jl:212; similar
#     ╎    ╎    ╎    ╎   4    ...ractarray.jl:881; similar
#     ╎    ╎    ╎    ╎    4    ...ractarray.jl:882; similar
#     ╎    ╎    ╎    ╎     4    @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎ 4    @Base/boot.jl:487; Array
#    4╎    ╎    ╎    ╎    ╎  4    @Base/boot.jl:479; Array
#     ╎    ╎    ╎  6    @Base/arraymath.jl:24; /(A::Matrix{Float64}, B:...
#     ╎    ╎    ╎   6    ...e/broadcast.jl:862; broadcast_preserving_ze...
#     ╎    ╎    ╎    6    ...e/broadcast.jl:873; materialize
#     ╎    ╎    ╎     6    .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎ 2    .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎  2    .../broadcast.jl:973; copyto!
#     ╎    ╎    ╎    ╎   2    ...e/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎    2    ...broadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎     2    ...ensional.jl:670; setindex!
#    2╎    ╎    ╎    ╎    ╎ 2    @Base/array.jl:971; setindex!
#     ╎    ╎    ╎    ╎ 4    .../broadcast.jl:211; similar
#     ╎    ╎    ╎    ╎  4    .../broadcast.jl:212; similar
#     ╎    ╎    ╎    ╎   4    ...ractarray.jl:881; similar
#     ╎    ╎    ╎    ╎    4    ...ractarray.jl:882; similar
#     ╎    ╎    ╎    ╎     4    @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎ 4    @Base/boot.jl:487; Array
#    4╎    ╎    ╎    ╎    ╎  4    @Base/boot.jl:479; Array
#     ╎    ╎    ╎  10   @Base/operators.jl:578; *
#     ╎    ╎    ╎   6    ...e/operators.jl:535; afoldl
#    1╎    ╎    ╎    6    ...e/arraymath.jl:21; *(A::Float64, B::Matrix...
#     ╎    ╎    ╎     5    .../broadcast.jl:862; broadcast_preserving_z...
#     ╎    ╎    ╎    ╎ 5    .../broadcast.jl:873; materialize
#     ╎    ╎    ╎    ╎  5    .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎   3    ...broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎    3    ...broadcast.jl:973; copyto!
#     ╎    ╎    ╎    ╎     1    .../simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎    ╎ 1    ...roadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎    ╎  1    ...ensional.jl:670; setindex!
#    1╎    ╎    ╎    ╎    ╎   1    ...e/array.jl:971; setindex!
#     ╎    ╎    ╎    ╎     1    .../simdloop.jl:78; macro expansion
#    1╎    ╎    ╎    ╎    ╎ 1    @Base/int.jl:87; +
#    1╎    ╎    ╎    ╎     1    .../simdloop.jl:84; macro expansion
#     ╎    ╎    ╎    ╎   2    ...broadcast.jl:211; similar
#     ╎    ╎    ╎    ╎    2    ...broadcast.jl:212; similar
#     ╎    ╎    ╎    ╎     2    ...actarray.jl:881; similar
#     ╎    ╎    ╎    ╎    ╎ 2    ...actarray.jl:882; similar
#     ╎    ╎    ╎    ╎    ╎  2    @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎   2    @Base/boot.jl:487; Array
#    2╎    ╎    ╎    ╎    ╎    2    @Base/boot.jl:479; Array
#     ╎    ╎    ╎   4    .../src/matmul.jl:119; *
#     ╎    ╎    ╎    4    .../src/matmul.jl:101; *
#     ╎    ╎    ╎     3    ...tractarray.jl:838; similar
#     ╎    ╎    ╎    ╎ 3    @Base/array.jl:374; similar
#     ╎    ╎    ╎    ╎  3    @Base/boot.jl:486; Array
#    3╎    ╎    ╎    ╎   3    @Base/boot.jl:477; Array
#     ╎    ╎    ╎     1    ...src/matmul.jl:276; mul!
#     ╎    ╎    ╎    ╎ 1    ...src/matmul.jl:109; mul!
#    1╎    ╎    ╎    ╎  1    ...src/matmul.jl:93; mul!
#    1╎    ╎    ╎  1    @Base/simdloop.jl:0; /(A::Matrix{Float64}, B:...
#     ╎    ╎    ╎  1    ...as/utilities.jl:132; dβdβ_res_ij
#     ╎    ╎    ╎   1    ...e/operators.jl:578; *
#     ╎    ╎    ╎    1    ...e/arraymath.jl:21; *(A::Float64, B::Vector...
#     ╎    ╎    ╎     1    .../broadcast.jl:862; broadcast_preserving_z...
#     ╎    ╎    ╎    ╎ 1    .../broadcast.jl:873; materialize
#     ╎    ╎    ╎    ╎  1    .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎   1    ...broadcast.jl:211; similar
#     ╎    ╎    ╎    ╎    1    ...broadcast.jl:212; similar
#     ╎    ╎    ╎    ╎     1    ...actarray.jl:881; similar
#     ╎    ╎    ╎    ╎    ╎ 1    ...actarray.jl:882; similar
#     ╎    ╎    ╎    ╎    ╎  1    @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎   1    @Base/boot.jl:486; Array
#    1╎    ╎    ╎    ╎    ╎    1    @Base/boot.jl:477; Array
#     ╎    ╎    ╎  13   ...as/utilities.jl:135; dβdβ_res_ij
#     ╎    ╎    ╎   5    @Base/arraymath.jl:21; *(A::Float64, B::Matrix{...
#     ╎    ╎    ╎    5    ...e/broadcast.jl:862; broadcast_preserving_z...
#     ╎    ╎    ╎     5    .../broadcast.jl:873; materialize
#     ╎    ╎    ╎    ╎ 5    .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎  4    .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎   4    ...broadcast.jl:973; copyto!
#     ╎    ╎    ╎    ╎    3    .../simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎     3    ...roadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎    ╎ 3    ...ensional.jl:670; setindex!
#    3╎    ╎    ╎    ╎    ╎  3    @Base/array.jl:971; setindex!
#    1╎    ╎    ╎    ╎    1    .../simdloop.jl:84; macro expansion
#     ╎    ╎    ╎    ╎  1    .../broadcast.jl:211; similar
#     ╎    ╎    ╎    ╎   1    ...broadcast.jl:212; similar
#     ╎    ╎    ╎    ╎    1    ...ractarray.jl:881; similar
#     ╎    ╎    ╎    ╎     1    ...actarray.jl:882; similar
#     ╎    ╎    ╎    ╎    ╎ 1    @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎  1    @Base/boot.jl:487; Array
#    1╎    ╎    ╎    ╎    ╎   1    @Base/boot.jl:479; Array
#     ╎    ╎    ╎   8    ...as/utilities.jl:55; ∇²μ_j
#     ╎    ╎    ╎    8    ...src/matmul.jl:1162; *
#     ╎    ╎    ╎     8    .../broadcast.jl:811; broadcast(::typeof(*),...
#     ╎    ╎    ╎    ╎ 8    .../broadcast.jl:873; materialize
#     ╎    ╎    ╎    ╎  8    .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎   7    ...broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎    7    ...broadcast.jl:973; copyto!
#    2╎    ╎    ╎    ╎     2    .../simdloop.jl:75; macro expansion
#     ╎    ╎    ╎    ╎     1    .../simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎    ╎ 1    ...roadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎    ╎  1    ...ensional.jl:670; setindex!
#    1╎    ╎    ╎    ╎    ╎   1    ...e/array.jl:971; setindex!
#     ╎    ╎    ╎    ╎     2    .../simdloop.jl:78; macro expansion
#    2╎    ╎    ╎    ╎    ╎ 2    @Base/int.jl:87; +
#     ╎    ╎    ╎    ╎     2    .../simdloop.jl:84; macro expansion
#     ╎    ╎    ╎    ╎    ╎ 2    ...ensional.jl:402; iterate
#     ╎    ╎    ╎    ╎    ╎  2    ...ensional.jl:420; __inc
#    2╎    ╎    ╎    ╎    ╎   2    @Base/int.jl:87; +
#     ╎    ╎    ╎    ╎   1    ...broadcast.jl:211; similar
#     ╎    ╎    ╎    ╎    1    ...broadcast.jl:212; similar
#     ╎    ╎    ╎    ╎     1    ...actarray.jl:881; similar
#     ╎    ╎    ╎    ╎    ╎ 1    ...actarray.jl:882; similar
#     ╎    ╎    ╎    ╎    ╎  1    @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎   1    @Base/boot.jl:487; Array
#    1╎    ╎    ╎    ╎    ╎    1    @Base/boot.jl:479; Array
#     ╎    ╎    ╎  16   ...as/utilities.jl:136; dβdβ_res_ij
#     ╎    ╎    ╎   16   .../src/matmul.jl:1162; *
#     ╎    ╎    ╎    16   ...e/broadcast.jl:811; broadcast(::typeof(*),...
#     ╎    ╎    ╎     16   .../broadcast.jl:873; materialize
#     ╎    ╎    ╎    ╎ 16   .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎  4    .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎   4    ...broadcast.jl:973; copyto!
#    1╎    ╎    ╎    ╎    1    .../simdloop.jl:75; macro expansion
#     ╎    ╎    ╎    ╎    1    .../simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎     1    ...roadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎    ╎ 1    ...ensional.jl:670; setindex!
#    1╎    ╎    ╎    ╎    ╎  1    @Base/array.jl:971; setindex!
#     ╎    ╎    ╎    ╎    2    .../simdloop.jl:84; macro expansion
#     ╎    ╎    ╎    ╎     2    ...ensional.jl:402; iterate
#     ╎    ╎    ╎    ╎    ╎ 2    ...ensional.jl:420; __inc
#    2╎    ╎    ╎    ╎    ╎  2    @Base/int.jl:87; +
#     ╎    ╎    ╎    ╎  12   .../broadcast.jl:211; similar
#     ╎    ╎    ╎    ╎   12   ...broadcast.jl:212; similar
#     ╎    ╎    ╎    ╎    12   ...ractarray.jl:881; similar
#     ╎    ╎    ╎    ╎     12   ...actarray.jl:882; similar
#     ╎    ╎    ╎    ╎    ╎ 12   @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎  12   @Base/boot.jl:487; Array
#   11╎    ╎    ╎    ╎    ╎   12   @Base/boot.jl:479; Array
#     ╎    ╎    ╎  22   ...as/utilities.jl:137; dβdβ_res_ij
#     ╎    ╎    ╎   4    ...e/operators.jl:578; *
#     ╎    ╎    ╎    4    ...e/operators.jl:535; afoldl
#     ╎    ╎    ╎     4    ...e/arraymath.jl:21; *(A::Float64, B::Matri...
#     ╎    ╎    ╎    ╎ 4    .../broadcast.jl:862; broadcast_preserving_...
#     ╎    ╎    ╎    ╎  4    .../broadcast.jl:873; materialize
#     ╎    ╎    ╎    ╎   4    ...broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎    2    ...broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎     2    ...roadcast.jl:973; copyto!
#    2╎    ╎    ╎    ╎    ╎ 2    ...simdloop.jl:75; macro expansion
#     ╎    ╎    ╎    ╎    2    ...broadcast.jl:211; similar
#     ╎    ╎    ╎    ╎     2    ...roadcast.jl:212; similar
#     ╎    ╎    ╎    ╎    ╎ 2    ...actarray.jl:881; similar
#     ╎    ╎    ╎    ╎    ╎  2    ...actarray.jl:882; similar
#     ╎    ╎    ╎    ╎    ╎   2    @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎    2    @Base/boot.jl:487; Array
#    2╎    ╎    ╎    ╎    ╎     2    ...e/boot.jl:479; Array
#     ╎    ╎    ╎   18   ...s/utilities.jl:14; ∇²σ²_j
#     ╎    ╎    ╎    18   ...src/matmul.jl:1162; *
#     ╎    ╎    ╎     17   .../broadcast.jl:811; broadcast(::typeof(*),...
#     ╎    ╎    ╎    ╎ 17   .../broadcast.jl:873; materialize
#     ╎    ╎    ╎    ╎  17   .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎   7    ...broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎    7    ...broadcast.jl:973; copyto!
#    2╎    ╎    ╎    ╎     2    .../simdloop.jl:75; macro expansion
#     ╎    ╎    ╎    ╎     5    .../simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎    ╎ 5    ...roadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎    ╎  5    ...ensional.jl:670; setindex!
#    5╎    ╎    ╎    ╎    ╎   5    ...e/array.jl:971; setindex!
#     ╎    ╎    ╎    ╎   10   ...broadcast.jl:211; similar
#     ╎    ╎    ╎    ╎    10   ...broadcast.jl:212; similar
#     ╎    ╎    ╎    ╎     10   ...actarray.jl:881; similar
#     ╎    ╎    ╎    ╎    ╎ 10   ...actarray.jl:882; similar
#     ╎    ╎    ╎    ╎    ╎  10   @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎   10   @Base/boot.jl:487; Array
#   10╎    ╎    ╎    ╎    ╎    10   @Base/boot.jl:479; Array
#    1╎    ╎    ╎     1    ...e/simdloop.jl:0; broadcast(::typeof(*),...
#     ╎    ╎    ╎  4    ...as/utilities.jl:138; dβdβ_res_ij
#     ╎    ╎    ╎   4    .../src/matmul.jl:1162; *
#     ╎    ╎    ╎    4    ...e/broadcast.jl:811; broadcast(::typeof(*),...
#     ╎    ╎    ╎     4    .../broadcast.jl:873; materialize
#     ╎    ╎    ╎    ╎ 4    .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎  1    .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎   1    ...broadcast.jl:973; copyto!
#    1╎    ╎    ╎    ╎    1    .../simdloop.jl:75; macro expansion
#     ╎    ╎    ╎    ╎  3    .../broadcast.jl:211; similar
#     ╎    ╎    ╎    ╎   3    ...broadcast.jl:212; similar
#     ╎    ╎    ╎    ╎    3    ...ractarray.jl:881; similar
#     ╎    ╎    ╎    ╎     3    ...actarray.jl:882; similar
#     ╎    ╎    ╎    ╎    ╎ 3    @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎  3    @Base/boot.jl:487; Array
#    3╎    ╎    ╎    ╎    ╎   3    @Base/boot.jl:479; Array
#     ╎    ╎    ╎  9    ...as/utilities.jl:139; dβdβ_res_ij
#     ╎    ╎    ╎   9    ...e/operators.jl:578; *
#     ╎    ╎    ╎    4    ...e/arraymath.jl:21; *(A::Float64, B::Vecto...
#     ╎    ╎    ╎     4    .../broadcast.jl:862; broadcast_preserving_z...
#     ╎    ╎    ╎    ╎ 4    .../broadcast.jl:873; materialize
#     ╎    ╎    ╎    ╎  4    .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎   1    ...broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎    1    ...broadcast.jl:962; copyto!
#     ╎    ╎    ╎    ╎     1    ...ractarray.jl:98; axes
#    1╎    ╎    ╎    ╎    ╎ 1    @Base/array.jl:149; size
#     ╎    ╎    ╎    ╎   3    ...broadcast.jl:211; similar
#     ╎    ╎    ╎    ╎    3    ...broadcast.jl:212; similar
#     ╎    ╎    ╎    ╎     3    ...actarray.jl:881; similar
#     ╎    ╎    ╎    ╎    ╎ 3    ...actarray.jl:882; similar
#     ╎    ╎    ╎    ╎    ╎  3    @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎   3    @Base/boot.jl:486; Array
#    3╎    ╎    ╎    ╎    ╎    3    @Base/boot.jl:477; Array
#    1╎    ╎    ╎    1    @Base/float.jl:410; *
#     ╎    ╎    ╎    4    ...e/operators.jl:535; afoldl
#    2╎    ╎    ╎     4    ...c/adjtrans.jl:439; *
#     ╎    ╎    ╎    ╎ 2    .../broadcast.jl:811; broadcast(::typeof(*)...
#     ╎    ╎    ╎    ╎  2    .../broadcast.jl:873; materialize
#     ╎    ╎    ╎    ╎   2    ...broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎    2    ...broadcast.jl:211; similar
#     ╎    ╎    ╎    ╎     2    ...roadcast.jl:212; similar
#     ╎    ╎    ╎    ╎    ╎ 2    ...actarray.jl:881; similar
#     ╎    ╎    ╎    ╎    ╎  2    ...actarray.jl:882; similar
#     ╎    ╎    ╎    ╎    ╎   2    @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎    2    @Base/boot.jl:487; Array
#    2╎    ╎    ╎    ╎    ╎     2    ...e/boot.jl:479; Array
#     ╎    ╎    ╎  10   ...as/utilities.jl:140; dβdβ_res_ij
#     ╎    ╎    ╎   10   @Base/arraymath.jl:16; +(::Matrix{Float64}, ::M...
#     ╎    ╎    ╎    10   ...e/broadcast.jl:862; broadcast_preserving_z...
#     ╎    ╎    ╎     10   .../broadcast.jl:873; materialize
#     ╎    ╎    ╎    ╎ 10   .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎  4    .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎   4    ...broadcast.jl:973; copyto!
#    1╎    ╎    ╎    ╎    1    .../simdloop.jl:75; macro expansion
#     ╎    ╎    ╎    ╎    2    .../simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎     2    ...roadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎    ╎ 2    ...ensional.jl:670; setindex!
#    2╎    ╎    ╎    ╎    ╎  2    @Base/array.jl:971; setindex!
#    1╎    ╎    ╎    ╎    1    .../simdloop.jl:84; macro expansion
#     ╎    ╎    ╎    ╎  6    .../broadcast.jl:211; similar
#     ╎    ╎    ╎    ╎   6    ...broadcast.jl:212; similar
#     ╎    ╎    ╎    ╎    6    ...ractarray.jl:881; similar
#     ╎    ╎    ╎    ╎     6    ...actarray.jl:882; similar
#     ╎    ╎    ╎    ╎    ╎ 6    @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎  6    @Base/boot.jl:487; Array
#    6╎    ╎    ╎    ╎    ╎   6    @Base/boot.jl:479; Array
#     ╎    ╎     3    ...longitudinal.jl:261; get_Pinv(qc_model::GLMCop...
#     ╎    ╎    ╎ 3    ...longitudinal.jl:283; get_Hθθ
#     ╎    ╎    ╎  1    ...ation/GLM_VC.jl:264; loglikelihood!(gcm::GLMC...
#     ╎    ╎    ╎   1    ...gconstructs.jl:168; macro expansion
#     ╎    ╎    ╎    1    ...gconstructs.jl:115; threading_run(fun::Qua...
#     ╎    ╎    ╎     1    @Base/task.jl:308; _wait(t::Task)
#     ╎    ╎    ╎    ╎ 1    .../condition.jl:125; wait(c::Base.GenericC...
#     ╎    ╎    ╎    ╎  1    .../condition.jl:130; wait(c::Base.GenericC...
#     ╎    ╎    ╎    ╎   1    @Base/task.jl:985; wait()
#    1╎    ╎    ╎    ╎    1    @Base/libuv.jl:107; process_events
#     ╎    ╎    ╎  2    ...ation/GLM_VC.jl:274; loglikelihood!(gcm::GLMC...
#     ╎    ╎    ╎   2    ...e/broadcast.jl:881; materialize!
#     ╎    ╎    ╎    2    ...e/broadcast.jl:884; materialize!
#     ╎    ╎    ╎     2    .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎ 2    .../broadcast.jl:973; copyto!
#     ╎    ╎    ╎    ╎  2    ...e/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎   2    ...broadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎    2    ...mensional.jl:670; setindex!
#    2╎    ╎    ╎    ╎     2    @Base/array.jl:971; setindex!
#    1╎    ╎     6    ...longitudinal.jl:262; get_Pinv(qc_model::GLMCop...
#     ╎    ╎    ╎ 1    ...longitudinal.jl:306; get_Hβθ(qc_model::GLMCop...
#     ╎    ╎    ╎  1    @Base/array.jl:782; collect(itr::Base.Genera...
#     ╎    ╎    ╎   1    @Base/generator.jl:47; iterate
#     ╎    ╎    ╎    1    ...e/essentials.jl:0; #126
#     ╎    ╎    ╎     1    ...src/matmul.jl:1152; *(tu::Adjoint{Float64...
#     ╎    ╎    ╎    ╎ 1    ...src/matmul.jl:119; *
#     ╎    ╎    ╎    ╎  1    ...src/matmul.jl:101; *
#     ╎    ╎    ╎    ╎   1    ...ractarray.jl:838; similar
#     ╎    ╎    ╎    ╎    1    @Base/array.jl:374; similar
#     ╎    ╎    ╎    ╎     1    @Base/boot.jl:486; Array
#    1╎    ╎    ╎    ╎    ╎ 1    @Base/boot.jl:477; Array
#    1╎    ╎    ╎ 2    ...longitudinal.jl:307; get_Hβθ(qc_model::GLMCop...
#     ╎    ╎    ╎  1    @Base/array.jl:1931; hcat(::Vector{Float64},...
#     ╎    ╎    ╎   1    @Base/array.jl:792; collect(itr::Base.Gener...
#     ╎    ╎    ╎    1    @Base/array.jl:818; collect_to_with_first!
#     ╎    ╎    ╎     1    @Base/array.jl:840; collect_to!
#     ╎    ╎    ╎    ╎ 1    .../generator.jl:47; iterate
#     ╎    ╎    ╎    ╎  1    none:0; #116
#    1╎    ╎    ╎    ╎   1    ...essentials.jl:13; getindex
#    1╎    ╎    ╎ 2    ...longitudinal.jl:308; get_Hβθ(qc_model::GLMCop...
#     ╎    ╎    ╎  1    @Base/arraymath.jl:8; -(A::Matrix{Float64}, B::...
#     ╎    ╎    ╎   1    ...e/broadcast.jl:862; broadcast_preserving_ze...
#     ╎    ╎    ╎    1    ...e/broadcast.jl:873; materialize
#     ╎    ╎    ╎     1    .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎ 1    .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎  1    .../broadcast.jl:973; copyto!
#    1╎    ╎    ╎    ╎   1    ...e/simdloop.jl:0; macro expansion
#     ╎    ╎    1130 .../longitudinal.jl:89; GWASCopulaVCModel(qc_mode...
#     ╎    ╎     1130 ...rogressMeter.jl:1010; macro expansion
#     ╎    ╎    ╎ 7    ...longitudinal.jl:91; macro expansion
#     ╎    ╎    ╎  7    ...src/snparray.jl:327; copyto!
#     ╎    ╎    ╎   6    ...rc/snparray.jl:348; copyto!(v::Vector{Float...
#     ╎    ╎    ╎    6    @Base/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎     2    ...c/snparray.jl:349; macro expansion
#    2╎    ╎    ╎    ╎ 2    ...c/snparray.jl:305; convert
#     ╎    ╎    ╎     2    ...c/snparray.jl:350; macro expansion
#    2╎    ╎    ╎    ╎ 2    @Base/array.jl:971; setindex!
#     ╎    ╎    ╎     2    ...c/snparray.jl:351; macro expansion
#     ╎    ╎    ╎    ╎ 2    @Base/float.jl:619; isnan
#    2╎    ╎    ╎    ╎  2    @Base/float.jl:534; !=
#     ╎    ╎    ╎   1    ...rc/snparray.jl:356; copyto!(v::Vector{Float...
#     ╎    ╎    ╎    1    @Base/simdloop.jl:78; macro expansion
#    1╎    ╎    ╎     1    @Base/int.jl:87; +
#     ╎    ╎    ╎ 3    ...longitudinal.jl:102; macro expansion
#     ╎    ╎    ╎  3    @Base/subarray.jl:177; view
#    1╎    ╎    ╎   1    ...stractarray.jl:707; checkbounds
#     ╎    ╎    ╎   2    ...stractarray.jl:709; checkbounds
#     ╎    ╎    ╎    2    ...stractarray.jl:694; checkbounds
#     ╎    ╎    ╎     2    ...tractarray.jl:773; checkindex
#     ╎    ╎    ╎    ╎ 2    @Base/range.jl:662; isempty
#     ╎    ╎    ╎    ╎  2    .../operators.jl:369; >
#    2╎    ╎    ╎    ╎   2    @Base/int.jl:83; <
#    1╎    ╎    ╎ 11   ...longitudinal.jl:104; macro expansion
# WARNING: both Distributions and Convex export "entropy"; uses of it in module QuasiCopula must be qualified
#     ╎    ╎    ╎  1    ...longitudinal.jl:230; get_∇resγ!(∇resγ::SubArr...
#    1╎    ╎    ╎   1    ...e/essentials.jl:13; getindex
#     ╎    ╎    ╎  6    ...longitudinal.jl:233; get_∇resγ!(∇resγ::SubArr...
#    4╎    ╎    ╎   4    .../essentials.jl:13; getindex
#     ╎    ╎    ╎   1    @Base/subarray.jl:350; setindex!
#     ╎    ╎    ╎    1    ...stractarray.jl:709; checkbounds
#     ╎    ╎    ╎     1    ...tractarray.jl:694; checkbounds
#     ╎    ╎    ╎    ╎ 1    ...tractarray.jl:768; checkindex
#    1╎    ╎    ╎    ╎  1    @Base/int.jl:488; <=
#     ╎    ╎    ╎   1    @Base/subarray.jl:351; setindex!
#    1╎    ╎    ╎    1    @Base/array.jl:969; setindex!
#     ╎    ╎    ╎  1    ...longitudinal.jl:234; get_∇resγ!(∇resγ::SubArr...
#     ╎    ╎    ╎   1    @Base/range.jl:891; iterate
#    1╎    ╎    ╎    1    ...e/promotion.jl:499; ==
#    2╎    ╎    ╎  2    ...longitudinal.jl:235; get_∇resγ!(∇resγ::SubArr...
#     ╎    ╎    ╎ 140  ...longitudinal.jl:105; macro expansion
#    1╎    ╎    ╎  1    ...longitudinal.jl:251; get_∇resβ!(∇resβ::SubArr...
#     ╎    ╎    ╎  139  ...longitudinal.jl:252; get_∇resβ!(∇resβ::SubArr...
#    1╎    ╎    ╎   1    @Base/Base.jl:37; getproperty
#     ╎    ╎    ╎   138  ...e/broadcast.jl:881; materialize!
#     ╎    ╎    ╎    138  ...e/broadcast.jl:884; materialize!
#     ╎    ╎    ╎     137  .../broadcast.jl:926; copyto!
#    1╎    ╎    ╎    ╎ 1    .../broadcast.jl:966; copyto!
#     ╎    ╎    ╎    ╎ 136  .../broadcast.jl:967; copyto!
#     ╎    ╎    ╎    ╎  136  ...ractarray.jl:1071; copyto!
#    4╎    ╎    ╎    ╎   4    ...ractarray.jl:0; copyto_unaliased!(d...
#    3╎    ╎    ╎    ╎   3    ...ractarray.jl:1080; copyto_unaliased!(d...
#    1╎    ╎    ╎    ╎   1    ...ractarray.jl:1111; copyto_unaliased!(d...
#     ╎    ╎    ╎    ╎   25   ...ractarray.jl:1112; copyto_unaliased!(d...
#     ╎    ╎    ╎    ╎    25   ...actarray.jl:1397; setindex!
#     ╎    ╎    ╎    ╎     25   ...actarray.jl:1427; _setindex!
#     ╎    ╎    ╎    ╎    ╎ 25   ...subarray.jl:327; setindex!
#   25╎    ╎    ╎    ╎    ╎  25   @Base/array.jl:971; setindex!
#     ╎    ╎    ╎    ╎   63   ...ractarray.jl:1113; copyto_unaliased!(d...
#     ╎    ╎    ╎    ╎    63   ...mensional.jl:402; iterate
#   36╎    ╎    ╎    ╎     36   ...ensional.jl:0; __inc
#   10╎    ╎    ╎    ╎     10   ...ensional.jl:427; __inc
#     ╎    ╎    ╎    ╎     17   ...ensional.jl:430; __inc
#     ╎    ╎    ╎    ╎    ╎ 5    ...ensional.jl:420; __inc
#    5╎    ╎    ╎    ╎    ╎  5    @Base/int.jl:87; +
#   12╎    ╎    ╎    ╎    ╎ 12   ...ensional.jl:421; __inc
#     ╎    ╎    ╎    ╎   7    ...ractarray.jl:1114; copyto_unaliased!(d...
#     ╎    ╎    ╎    ╎    7    @Base/array.jl:893; iterate
#     ╎    ╎    ╎    ╎     7    @Base/int.jl:494; <
#    7╎    ╎    ╎    ╎    ╎ 7    @Base/int.jl:487; <
#   16╎    ╎    ╎    ╎   16   @Base/array.jl:0; copyto_unaliased!(d...
#   17╎    ╎    ╎    ╎   17   ...mensional.jl:0; copyto_unaliased!(d...
#     ╎    ╎    ╎     1    .../broadcast.jl:297; instantiate
#     ╎    ╎    ╎    ╎ 1    .../broadcast.jl:556; check_broadcast_axes
#     ╎    ╎    ╎    ╎  1    ...tractarray.jl:98; axes
#    1╎    ╎    ╎    ╎   1    @Base/array.jl:150; size
#     ╎    ╎    ╎ 12   ...longitudinal.jl:108; macro expansion
#     ╎    ╎    ╎  12   @Base/broadcast.jl:881; materialize!
#     ╎    ╎    ╎   12   ...e/broadcast.jl:884; materialize!
#     ╎    ╎    ╎    12   ...e/broadcast.jl:934; copyto!
#     ╎    ╎    ╎     5    ...imensional.jl:1086; fill!
#     ╎    ╎    ╎    ╎ 5    ...tractarray.jl:1397; setindex!
#     ╎    ╎    ╎    ╎  5    ...ractarray.jl:1427; _setindex!
#     ╎    ╎    ╎    ╎   5    .../subarray.jl:327; setindex!
#    5╎    ╎    ╎    ╎    5    @Base/array.jl:971; setindex!
#    1╎    ╎    ╎     7    ...imensional.jl:1087; fill!
#     ╎    ╎    ╎    ╎ 6    ...imensional.jl:402; iterate
#    6╎    ╎    ╎    ╎  6    ...imensional.jl:0; __inc
#   16╎    ╎    ╎ 46   ...longitudinal.jl:110; macro expansion
#    2╎    ╎    ╎  2    ...e/essentials.jl:13; getindex
#    5╎    ╎    ╎  5    ...bra/src/blas.jl:518; axpy!(alpha::Float64, x:...
#     ╎    ╎    ╎  2    ...bra/src/blas.jl:519; axpy!(alpha::Float64, x:...
#     ╎    ╎    ╎   2    ...stractarray.jl:308; length
#     ╎    ╎    ╎    2    @Base/subarray.jl:63; size
#     ╎    ╎    ╎     2    ...e/subarray.jl:455; axes
#     ╎    ╎    ╎    ╎ 2    ...e/subarray.jl:460; _indices_sub
#     ╎    ╎    ╎    ╎  2    ...e/subarray.jl:460; _indices_sub
#     ╎    ╎    ╎    ╎   2    @Base/range.jl:696; axes
#     ╎    ╎    ╎    ╎    2    @Base/range.jl:751; length
#    2╎    ╎    ╎    ╎     2    @Base/int.jl:86; -
#    2╎    ╎    ╎  20   ...bra/src/blas.jl:522; axpy!(alpha::Float64, x:...
#    4╎    ╎    ╎   4    @Base/boot.jl:327; ArgumentError(msg::String)
#   14╎    ╎    ╎   14   ...ra/src/blas.jl:510; axpy!(n::Int64, alpha::...
#    1╎    ╎    ╎  1    ...bra/src/blas.jl:524; axpy!(alpha::Float64, x:...
#     ╎    ╎    ╎ 6    ...longitudinal.jl:113; macro expansion
#     ╎    ╎    ╎  6    ...a/src/matmul.jl:14; dot
#     ╎    ╎    ╎   6    ...ra/src/blas.jl:395; dot
#    6╎    ╎    ╎    6    ...ra/src/blas.jl:345; dot
#     ╎    ╎    ╎ 1    ...longitudinal.jl:115; macro expansion
#    1╎    ╎    ╎  1    @Base/array.jl:969; setindex!
#     ╎    ╎    ╎ 1    ...longitudinal.jl:116; macro expansion
#    1╎    ╎    ╎  1    @Base/array.jl:969; setindex!
#     ╎    ╎    ╎ 654  ...longitudinal.jl:118; macro expansion
#     ╎    ╎    ╎  48   @Base/timing.jl:392; macro expansion
#   48╎    ╎    ╎   48   @Base/Base.jl:94; time_ns
#     ╎    ╎    ╎  586  @Base/timing.jl:393; macro expansion
#     ╎    ╎    ╎   1    @Base/subarray.jl:177; view
#    1╎    ╎    ╎    1    ...stractarray.jl:709; checkbounds
#     ╎    ╎    ╎   501  ...ongitudinal.jl:143; update_W!
#    2╎    ╎    ╎    2    ...ongitudinal.jl:388; get_Hβγ_i!(W::SubArray...
#     ╎    ╎    ╎    2    ...ongitudinal.jl:396; get_Hβγ_i!(W::SubArray...
#     ╎    ╎    ╎     2    ...e/subarray.jl:177; view
#    1╎    ╎    ╎    ╎ 1    ...tractarray.jl:707; checkbounds
#    1╎    ╎    ╎    ╎ 1    ...tractarray.jl:709; checkbounds
#     ╎    ╎    ╎    10   ...ongitudinal.jl:399; get_Hβγ_i!(W::SubArray...
#     ╎    ╎    ╎     10   .../broadcast.jl:881; materialize!
#     ╎    ╎    ╎    ╎ 10   .../broadcast.jl:884; materialize!
#     ╎    ╎    ╎    ╎  10   .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎   7    ...broadcast.jl:970; copyto!
#     ╎    ╎    ╎    ╎    7    ...broadcast.jl:953; preprocess
#     ╎    ╎    ╎    ╎     7    ...roadcast.jl:956; preprocess_args
#     ╎    ╎    ╎    ╎    ╎ 7    ...roadcast.jl:957; preprocess_args
#     ╎    ╎    ╎    ╎    ╎  7    ...roadcast.jl:954; preprocess
#    3╎    ╎    ╎    ╎    ╎   7    ...oadcast.jl:947; broadcast_unalias
#    1╎    ╎    ╎    ╎    ╎    4    ...tarray.jl:1480; unalias
#    3╎    ╎    ╎    ╎    ╎     3    ...nsional.jl:0; mightalias(A::Sub...
#     ╎    ╎    ╎    ╎   3    ...broadcast.jl:973; copyto!
#    1╎    ╎    ╎    ╎    1    .../simdloop.jl:75; macro expansion
#     ╎    ╎    ╎    ╎    2    .../simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎     2    ...roadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎    ╎ 2    ...subarray.jl:351; setindex!
#    2╎    ╎    ╎    ╎    ╎  2    @Base/array.jl:969; setindex!
#     ╎    ╎    ╎    5    ...ongitudinal.jl:400; get_Hβγ_i!(W::SubArray...
#     ╎    ╎    ╎     5    ...src/matmul.jl:276; mul!
#    1╎    ╎    ╎    ╎ 5    ...src/matmul.jl:93; mul!
#     ╎    ╎    ╎    ╎  1    ...src/matmul.jl:499; gemv!(y::Vector{Float...
#     ╎    ╎    ╎    ╎   1    ...promotion.jl:387; promote
#     ╎    ╎    ╎    ╎    1    ...promotion.jl:365; _promote
#     ╎    ╎    ╎    ╎     1    @Base/number.jl:7; convert
#    1╎    ╎    ╎    ╎    ╎ 1    @Base/float.jl:165; Float64
#     ╎    ╎    ╎    ╎  3    ...src/matmul.jl:503; gemv!(y::Vector{Float...
#    1╎    ╎    ╎    ╎   1    .../src/blas.jl:643; gemv!(trans::Char, a...
#     ╎    ╎    ╎    ╎   1    .../src/blas.jl:647; gemv!(trans::Char, a...
#    1╎    ╎    ╎    ╎    1    @Base/array.jl:148; size
#    1╎    ╎    ╎    ╎   1    .../src/blas.jl:667; gemv!(trans::Char, a...
#     ╎    ╎    ╎    11   ...ongitudinal.jl:401; get_Hβγ_i!(W::SubArray...
#     ╎    ╎    ╎     11   .../broadcast.jl:881; materialize!
#     ╎    ╎    ╎    ╎ 11   .../broadcast.jl:884; materialize!
#     ╎    ╎    ╎    ╎  11   .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎   3    ...broadcast.jl:970; copyto!
#     ╎    ╎    ╎    ╎    3    ...broadcast.jl:953; preprocess
#     ╎    ╎    ╎    ╎     3    ...roadcast.jl:956; preprocess_args
#     ╎    ╎    ╎    ╎    ╎ 3    ...roadcast.jl:957; preprocess_args
#     ╎    ╎    ╎    ╎    ╎  3    ...roadcast.jl:954; preprocess
#     ╎    ╎    ╎    ╎    ╎   2    ...oadcast.jl:947; broadcast_unalias
#     ╎    ╎    ╎    ╎    ╎    2    ...tarray.jl:1480; unalias
#     ╎    ╎    ╎    ╎    ╎     2    ...tarray.jl:1515; mightalias
#     ╎    ╎    ╎    ╎    ╎    ╎ 2    ...barray.jl:102; dataids
#    2╎    ╎    ╎    ╎    ╎    ╎  2    ...e/Base.jl:37; getproperty
#     ╎    ╎    ╎    ╎    ╎   1    ...oadcast.jl:650; extrude
#     ╎    ╎    ╎    ╎    ╎    1    ...oadcast.jl:599; newindexer
#     ╎    ╎    ╎    ╎    ╎     1    ...adcast.jl:600; shapeindexer
#     ╎    ╎    ╎    ╎    ╎    ╎ 1    ...adcast.jl:605; _newindexer
#     ╎    ╎    ╎    ╎    ╎    ╎  1    ...rators.jl:269; !=
#    1╎    ╎    ╎    ╎    ╎    ╎   1    ...motion.jl:499; ==
#     ╎    ╎    ╎    ╎   8    ...broadcast.jl:973; copyto!
#    1╎    ╎    ╎    ╎    1    .../simdloop.jl:75; macro expansion
#     ╎    ╎    ╎    ╎    3    .../simdloop.jl:76; macro expansion
#     ╎    ╎    ╎    ╎     3    .../simdloop.jl:54; simd_index
#    3╎    ╎    ╎    ╎    ╎ 3    @Base/int.jl:87; +
#     ╎    ╎    ╎    ╎    4    .../simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎     4    ...roadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎    ╎ 4    ...subarray.jl:351; setindex!
#    4╎    ╎    ╎    ╎    ╎  4    @Base/array.jl:969; setindex!
#     ╎    ╎    ╎    8    ...ongitudinal.jl:403; get_Hβγ_i!(W::SubArray...
#     ╎    ╎    ╎     8    ...src/matmul.jl:276; mul!
#    1╎    ╎    ╎    ╎ 8    ...src/matmul.jl:65; mul!
#    1╎    ╎    ╎    ╎  1    @Base/array.jl:0; gemv!(y::SubArray{Flo...
#    3╎    ╎    ╎    ╎  3    ...src/matmul.jl:490; gemv!(y::SubArray{Flo...
#    1╎    ╎    ╎    ╎  3    ...src/matmul.jl:503; gemv!(y::SubArray{Flo...
#     ╎    ╎    ╎    ╎   1    .../src/blas.jl:647; gemv!(trans::Char, a...
#     ╎    ╎    ╎    ╎    1    ...ractarray.jl:42; size
#     ╎    ╎    ╎    ╎     1    .../subarray.jl:63; size
#     ╎    ╎    ╎    ╎    ╎ 1    ...subarray.jl:455; axes
#     ╎    ╎    ╎    ╎    ╎  1    ...subarray.jl:460; _indices_sub
#     ╎    ╎    ╎    ╎    ╎   1    ...e/range.jl:696; axes
#     ╎    ╎    ╎    ╎    ╎    1    ...e/range.jl:748; length
#     ╎    ╎    ╎    ╎    ╎     1    .../range.jl:824; first
#    1╎    ╎    ╎    ╎    ╎    ╎ 1    ...e/Base.jl:37; getproperty
#    1╎    ╎    ╎    ╎   1    .../src/blas.jl:674; gemv!(trans::Char, a...
#     ╎    ╎    ╎    8    ...ongitudinal.jl:404; get_Hβγ_i!(W::SubArray...
#    1╎    ╎    ╎     8    .../src/matmul.jl:14; dot
#    2╎    ╎    ╎    ╎ 2    ...a/src/blas.jl:392; dot(x::SubArray{Float...
#     ╎    ╎    ╎    ╎ 1    ...a/src/blas.jl:393; dot(x::SubArray{Float...
#     ╎    ╎    ╎    ╎  1    ...tractarray.jl:308; length
#     ╎    ╎    ╎    ╎   1    ...e/subarray.jl:63; size
#     ╎    ╎    ╎    ╎    1    .../subarray.jl:455; axes
#     ╎    ╎    ╎    ╎     1    ...subarray.jl:460; _indices_sub
#     ╎    ╎    ╎    ╎    ╎ 1    @Base/range.jl:696; axes
#     ╎    ╎    ╎    ╎    ╎  1    @Base/range.jl:459; oneto
#     ╎    ╎    ╎    ╎    ╎   1    ...e/range.jl:457; OneTo
#     ╎    ╎    ╎    ╎    ╎    1    ...e/range.jl:444; OneTo
#     ╎    ╎    ╎    ╎    ╎     1    ...motion.jl:510; max
#    1╎    ╎    ╎    ╎    ╎    ╎ 1    ...ntials.jl:575; ifelse
#     ╎    ╎    ╎    ╎ 4    ...a/src/blas.jl:395; dot(x::SubArray{Float...
#    4╎    ╎    ╎    ╎  4    ...a/src/blas.jl:345; dot
#     ╎    ╎    ╎    7    ...ongitudinal.jl:405; get_Hβγ_i!(W::SubArray...
#     ╎    ╎    ╎     7    ...src/matmul.jl:276; mul!
#    2╎    ╎    ╎    ╎ 7    ...src/matmul.jl:93; mul!
#    1╎    ╎    ╎    ╎  1    ...src/matmul.jl:490; gemv!(y::Vector{Float...
#     ╎    ╎    ╎    ╎  2    ...src/matmul.jl:499; gemv!(y::Vector{Float...
#     ╎    ╎    ╎    ╎   2    ...promotion.jl:387; promote
#     ╎    ╎    ╎    ╎    2    ...promotion.jl:365; _promote
#     ╎    ╎    ╎    ╎     2    @Base/number.jl:7; convert
#    2╎    ╎    ╎    ╎    ╎ 2    @Base/float.jl:165; Float64
#     ╎    ╎    ╎    ╎  2    ...src/matmul.jl:503; gemv!(y::Vector{Float...
#    2╎    ╎    ╎    ╎   2    .../src/blas.jl:643; gemv!(trans::Char, a...
#     ╎    ╎    ╎    2    ...ongitudinal.jl:406; get_Hβγ_i!(W::SubArray...
#     ╎    ╎    ╎     2    .../broadcast.jl:881; materialize!
#     ╎    ╎    ╎    ╎ 2    .../broadcast.jl:884; materialize!
#     ╎    ╎    ╎    ╎  1    .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎   1    ...broadcast.jl:973; copyto!
#    1╎    ╎    ╎    ╎    1    .../simdloop.jl:75; macro expansion
#     ╎    ╎    ╎    ╎  1    .../broadcast.jl:297; instantiate
#     ╎    ╎    ╎    ╎   1    ...broadcast.jl:559; check_broadcast_axes
#     ╎    ╎    ╎    ╎    1    ...broadcast.jl:556; check_broadcast_axes
#    1╎    ╎    ╎    ╎     1    ...roadcast.jl:553; check_broadcast_shape
#     ╎    ╎    ╎    8    ...ongitudinal.jl:408; get_Hβγ_i!(W::SubArray...
#     ╎    ╎    ╎     8    ...src/matmul.jl:276; mul!
#     ╎    ╎    ╎    ╎ 8    ...src/matmul.jl:65; mul!
#     ╎    ╎    ╎    ╎  1    ...src/matmul.jl:495; gemv!(y::SubArray{Flo...
#     ╎    ╎    ╎    ╎   1    ...operators.jl:269; !=
#    1╎    ╎    ╎    ╎    1    ...promotion.jl:499; ==
#     ╎    ╎    ╎    ╎  1    ...src/matmul.jl:499; gemv!(y::SubArray{Flo...
#     ╎    ╎    ╎    ╎   1    ...promotion.jl:387; promote
#     ╎    ╎    ╎    ╎    1    ...promotion.jl:365; _promote
#     ╎    ╎    ╎    ╎     1    @Base/number.jl:7; convert
#    1╎    ╎    ╎    ╎    ╎ 1    @Base/float.jl:165; Float64
#    1╎    ╎    ╎    ╎  6    ...src/matmul.jl:503; gemv!(y::SubArray{Flo...
#    1╎    ╎    ╎    ╎   1    .../src/blas.jl:643; gemv!(trans::Char, a...
#    1╎    ╎    ╎    ╎   3    .../src/blas.jl:648; gemv!(trans::Char, a...
#     ╎    ╎    ╎    ╎    2    ...operators.jl:269; !=
#    2╎    ╎    ╎    ╎     2    ...romotion.jl:499; ==
#     ╎    ╎    ╎    ╎   1    .../src/blas.jl:667; gemv!(trans::Char, a...
#     ╎    ╎    ╎    ╎    1    ...ssentials.jl:492; cconvert
#     ╎    ╎    ╎    ╎     1    ...fpointer.jl:104; convert
#    1╎    ╎    ╎    ╎    ╎ 1    .../refvalue.jl:8; RefValue
#     ╎    ╎    ╎    10   ...ongitudinal.jl:409; get_Hβγ_i!(W::SubArray...
#     ╎    ╎    ╎     10   ...src/matmul.jl:276; mul!
#     ╎    ╎    ╎    ╎ 10   ...src/matmul.jl:93; mul!
#    1╎    ╎    ╎    ╎  1    ...src/matmul.jl:490; gemv!(y::Vector{Float...
#     ╎    ╎    ╎    ╎  1    ...src/matmul.jl:498; gemv!(y::Vector{Float...
#    1╎    ╎    ╎    ╎   1    ...promotion.jl:499; ==
#     ╎    ╎    ╎    ╎  8    ...src/matmul.jl:503; gemv!(y::Vector{Float...
#    1╎    ╎    ╎    ╎   1    .../src/blas.jl:643; gemv!(trans::Char, a...
#     ╎    ╎    ╎    ╎   1    .../src/blas.jl:658; gemv!(trans::Char, a...
#     ╎    ╎    ╎    ╎    1    .../src/blas.jl:177; vec_pointer_stride
#     ╎    ╎    ╎    ╎     1    ...actarray.jl:1240; pointer
#    1╎    ╎    ╎    ╎    ╎ 1    .../pointer.jl:65; unsafe_convert
#    6╎    ╎    ╎    ╎   6    .../src/blas.jl:667; gemv!(trans::Char, a...
#     ╎    ╎    ╎    6    ...ongitudinal.jl:410; get_Hβγ_i!(W::SubArray...
#     ╎    ╎    ╎     6    .../broadcast.jl:881; materialize!
#     ╎    ╎    ╎    ╎ 6    .../broadcast.jl:884; materialize!
#     ╎    ╎    ╎    ╎  6    .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎   2    ...broadcast.jl:970; copyto!
#     ╎    ╎    ╎    ╎    2    ...broadcast.jl:953; preprocess
#     ╎    ╎    ╎    ╎     2    ...roadcast.jl:956; preprocess_args
#     ╎    ╎    ╎    ╎    ╎ 1    ...roadcast.jl:954; preprocess
#     ╎    ╎    ╎    ╎    ╎  1    ...roadcast.jl:650; extrude
#     ╎    ╎    ╎    ╎    ╎   1    ...oadcast.jl:599; newindexer
#     ╎    ╎    ╎    ╎    ╎    1    ...oadcast.jl:600; shapeindexer
#     ╎    ╎    ╎    ╎    ╎     1    ...adcast.jl:605; _newindexer
#     ╎    ╎    ╎    ╎    ╎    ╎ 1    ...rators.jl:269; !=
#    1╎    ╎    ╎    ╎    ╎    ╎  1    ...motion.jl:499; ==
#     ╎    ╎    ╎    ╎    ╎ 1    ...roadcast.jl:957; preprocess_args
#     ╎    ╎    ╎    ╎    ╎  1    ...roadcast.jl:953; preprocess
#     ╎    ╎    ╎    ╎    ╎   1    ...oadcast.jl:956; preprocess_args
#     ╎    ╎    ╎    ╎    ╎    1    ...oadcast.jl:954; preprocess
#     ╎    ╎    ╎    ╎    ╎     1    ...adcast.jl:650; extrude
#     ╎    ╎    ╎    ╎    ╎    ╎ 1    ...adcast.jl:599; newindexer
#     ╎    ╎    ╎    ╎    ╎    ╎  1    ...adcast.jl:600; shapeindexer
#     ╎    ╎    ╎    ╎    ╎    ╎   1    ...adcast.jl:605; _newindexer
#     ╎    ╎    ╎    ╎    ╎    ╎    1    ...rators.jl:269; !=
#    1╎    ╎    ╎    ╎    ╎    ╎     1    ...motion.jl:499; ==
#     ╎    ╎    ╎    ╎   4    ...broadcast.jl:973; copyto!
#     ╎    ╎    ╎    ╎    4    .../simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎     4    ...roadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎    ╎ 4    ...subarray.jl:351; setindex!
#    4╎    ╎    ╎    ╎    ╎  4    @Base/array.jl:969; setindex!
#     ╎    ╎    ╎    19   ...ongitudinal.jl:412; get_Hβγ_i!(W::SubArray...
#     ╎    ╎    ╎     19   ...src/matmul.jl:276; mul!
#    3╎    ╎    ╎    ╎ 19   ...src/matmul.jl:65; mul!
#    2╎    ╎    ╎    ╎  2    ...src/matmul.jl:490; gemv!(y::SubArray{Flo...
#    3╎    ╎    ╎    ╎  14   ...src/matmul.jl:503; gemv!(y::SubArray{Flo...
#    4╎    ╎    ╎    ╎   4    .../src/blas.jl:643; gemv!(trans::Char, a...
#     ╎    ╎    ╎    ╎   1    .../src/blas.jl:647; gemv!(trans::Char, a...
#     ╎    ╎    ╎    ╎    1    ...ractarray.jl:42; size
#     ╎    ╎    ╎    ╎     1    .../subarray.jl:63; size
#     ╎    ╎    ╎    ╎    ╎ 1    ...subarray.jl:455; axes
#     ╎    ╎    ╎    ╎    ╎  1    ...subarray.jl:460; _indices_sub
#     ╎    ╎    ╎    ╎    ╎   1    ...e/range.jl:696; axes
#     ╎    ╎    ╎    ╎    ╎    1    ...e/range.jl:748; length
#     ╎    ╎    ╎    ╎    ╎     1    .../range.jl:824; first
#    1╎    ╎    ╎    ╎    ╎    ╎ 1    ...e/Base.jl:37; getproperty
#     ╎    ╎    ╎    ╎   1    .../src/blas.jl:648; gemv!(trans::Char, a...
#     ╎    ╎    ╎    ╎    1    ...ractarray.jl:308; length
#     ╎    ╎    ╎    ╎     1    .../subarray.jl:63; size
#     ╎    ╎    ╎    ╎    ╎ 1    ...subarray.jl:455; axes
#     ╎    ╎    ╎    ╎    ╎  1    ...subarray.jl:460; _indices_sub
#     ╎    ╎    ╎    ╎    ╎   1    ...e/range.jl:696; axes
#     ╎    ╎    ╎    ╎    ╎    1    ...e/range.jl:751; length
#    1╎    ╎    ╎    ╎    ╎     1    @Base/int.jl:86; -
#     ╎    ╎    ╎    ╎   1    .../src/blas.jl:659; gemv!(trans::Char, a...
#     ╎    ╎    ╎    ╎    1    ...actarray.jl:1240; pointer
#     ╎    ╎    ╎    ╎     1    ...subarray.jl:437; unsafe_convert
#    1╎    ╎    ╎    ╎    ╎ 1    .../pointer.jl:65; unsafe_convert
#    4╎    ╎    ╎    ╎   4    .../src/blas.jl:667; gemv!(trans::Char, a...
#     ╎    ╎    ╎    1    ...ongitudinal.jl:413; get_Hβγ_i!(W::SubArray...
#     ╎    ╎    ╎     1    @Base/range.jl:5; Colon
#     ╎    ╎    ╎    ╎ 1    @Base/range.jl:397; UnitRange
#    1╎    ╎    ╎    ╎  1    @Base/range.jl:404; unitrange_last
#     ╎    ╎    ╎    398  ...ongitudinal.jl:415; get_Hβγ_i!(W::SubArray...
#    9╎    ╎    ╎     9    ...essentials.jl:13; getindex
#    1╎    ╎    ╎     1    @Base/int.jl:0; dγdβresβ_ij!
#    1╎    ╎    ╎     1    ...e/simdloop.jl:0; dγdβresβ_ij!
#    2╎    ╎    ╎     2    ...e/subarray.jl:0; dγdβresβ_ij!
#     ╎    ╎    ╎     1    ...e/subarray.jl:319; getindex
#    1╎    ╎    ╎    ╎ 1    ...essentials.jl:13; getindex
#     ╎    ╎    ╎     2    ...e/subarray.jl:176; view
#     ╎    ╎    ╎    ╎ 2    @Base/indices.jl:344; to_indices
#     ╎    ╎    ╎    ╎  2    ...tractarray.jl:98; axes
#    2╎    ╎    ╎    ╎   2    @Base/array.jl:150; size
#     ╎    ╎    ╎     3    ...e/subarray.jl:182; view
#     ╎    ╎    ╎    ╎ 3    ...e/subarray.jl:219; unsafe_view
#     ╎    ╎    ╎    ╎  3    ...e/subarray.jl:28; SubArray
#     ╎    ╎    ╎    ╎   3    ...e/subarray.jl:37; SubArray
#     ╎    ╎    ╎    ╎    3    .../subarray.jl:371; compute_stride1
#     ╎    ╎    ╎    ╎     3    ...ractarray.jl:98; axes
#    3╎    ╎    ╎    ╎    ╎ 3    @Base/array.jl:150; size
#     ╎    ╎    ╎     9    .../utilities.jl:175; dγdβresβ_ij!
#    1╎    ╎    ╎    ╎ 6    @Base/array.jl:348; fill!
# ...
#     ╎    ╎    ╎    21   ...s/utilities.jl:132; dβdβ_res_ij
#     ╎    ╎    ╎     4    .../operators.jl:578; *
#    4╎    ╎    ╎    ╎ 4    @Base/float.jl:410; *
#     ╎    ╎    ╎     5    .../utilities.jl:103; sigmamu
#    4╎    ╎    ╎    ╎ 4    @Base/float.jl:409; -
#     ╎    ╎    ╎    ╎ 1    .../promotion.jl:411; *
#    1╎    ╎    ╎    ╎  1    @Base/float.jl:410; *
#    2╎    ╎    ╎     9    ...c/glmtools.jl:263; mueta
#    2╎    ╎    ╎    ╎ 7    ...pecial/exp.jl:325; exp(x::Float64)
#     ╎    ╎    ╎    ╎  2    ...pecial/exp.jl:216; exp_impl
#     ╎    ╎    ╎    ╎   2    ...pecial/exp.jl:78; expm1b_kernel
#     ╎    ╎    ╎    ╎    2    @Base/math.jl:177; evalpoly
#     ╎    ╎    ╎    ╎     2    @Base/math.jl:178; macro expansion
#    2╎    ╎    ╎    ╎    ╎ 2    @Base/float.jl:413; muladd
#     ╎    ╎    ╎    ╎  3    ...pecial/exp.jl:218; exp_impl
#    3╎    ╎    ╎    ╎   3    @Base/float.jl:609; abs
#     ╎    ╎    ╎     3    ...c/glmtools.jl:265; mueta
#    3╎    ╎    ╎    ╎ 3    @Base/float.jl:411; /
#     ╎    ╎    ╎    14   ...s/utilities.jl:135; dβdβ_res_ij
#     ╎    ╎    ╎     13   ...s/utilities.jl:54; ∇²μ_j
#     ╎    ╎    ╎    ╎ 13   .../utilities.jl:117; mueta2
#    7╎    ╎    ╎    ╎  13   ...pecial/exp.jl:325; exp(x::Float64)
#     ╎    ╎    ╎    ╎   1    ...ecial/exp.jl:215; exp_impl
#     ╎    ╎    ╎    ╎    1    ...ecial/exp.jl:182; table_unpack
#    1╎    ╎    ╎    ╎     1    ...sentials.jl:513; reinterpret
#     ╎    ╎    ╎    ╎   5    ...ecial/exp.jl:216; exp_impl
#    1╎    ╎    ╎    ╎    1    @Base/float.jl:408; +
#     ╎    ╎    ╎    ╎    4    ...ecial/exp.jl:78; expm1b_kernel
#     ╎    ╎    ╎    ╎     4    @Base/math.jl:177; evalpoly
#     ╎    ╎    ╎    ╎    ╎ 4    @Base/math.jl:178; macro expansion
#    4╎    ╎    ╎    ╎    ╎  4    @Base/float.jl:413; muladd
#     ╎    ╎    ╎     1    ...s/utilities.jl:55; ∇²μ_j
#     ╎    ╎    ╎    ╎ 1    .../operators.jl:578; *
#    1╎    ╎    ╎    ╎  1    @Base/float.jl:410; *
#     ╎    ╎    ╎    3    ...s/utilities.jl:136; dβdβ_res_ij
#     ╎    ╎    ╎     3    ...e/intfuncs.jl:320; literal_pow
#     ╎    ╎    ╎    ╎ 3    .../operators.jl:578; *
#    3╎    ╎    ╎    ╎  3    @Base/float.jl:410; *
#     ╎    ╎    ╎    36   ...s/utilities.jl:137; dβdβ_res_ij
#     ╎    ╎    ╎     32   ...s/utilities.jl:13; ∇²σ²_j
#    1╎    ╎    ╎    ╎ 1    @Base/float.jl:410; *
#    2╎    ╎    ╎    ╎ 8    .../utilities.jl:117; mueta2
#     ╎    ╎    ╎    ╎  6    ...pecial/exp.jl:325; exp(x::Float64)
#     ╎    ╎    ╎    ╎   1    ...ecial/exp.jl:213; exp_impl
#    1╎    ╎    ╎    ╎    1    @Base/float.jl:413; muladd
#     ╎    ╎    ╎    ╎   2    ...ecial/exp.jl:215; exp_impl
#     ╎    ╎    ╎    ╎    1    ...ecial/exp.jl:179; table_unpack
#     ╎    ╎    ╎    ╎     1    @Base/int.jl:1042; &
#    1╎    ╎    ╎    ╎    ╎ 1    @Base/int.jl:347; &
#     ╎    ╎    ╎    ╎    1    ...ecial/exp.jl:181; table_unpack
#    1╎    ╎    ╎    ╎     1    @Base/int.jl:347; &
#     ╎    ╎    ╎    ╎   1    ...ecial/exp.jl:216; exp_impl
#     ╎    ╎    ╎    ╎    1    ...ecial/exp.jl:78; expm1b_kernel
#     ╎    ╎    ╎    ╎     1    @Base/math.jl:177; evalpoly
#     ╎    ╎    ╎    ╎    ╎ 1    @Base/math.jl:178; macro expansion
#    1╎    ╎    ╎    ╎    ╎  1    @Base/float.jl:413; muladd
#     ╎    ╎    ╎    ╎   2    ...ecial/exp.jl:218; exp_impl
#    2╎    ╎    ╎    ╎    2    @Base/float.jl:609; abs
#     ╎    ╎    ╎    ╎ 11   .../utilities.jl:119; mueta2
#    9╎    ╎    ╎    ╎  9    @Base/float.jl:408; +
#     ╎    ╎    ╎    ╎  2    ...e/intfuncs.jl:319; literal_pow
#    2╎    ╎    ╎    ╎   2    @Base/float.jl:410; *
#     ╎    ╎    ╎    ╎ 12   ...c/glmtools.jl:263; mueta
#    1╎    ╎    ╎    ╎  12   ...pecial/exp.jl:325; exp(x::Float64)
#     ╎    ╎    ╎    ╎   3    ...ecial/exp.jl:215; exp_impl
#     ╎    ╎    ╎    ╎    2    ...ecial/exp.jl:181; table_unpack
#    2╎    ╎    ╎    ╎     2    @Base/int.jl:347; &
#     ╎    ╎    ╎    ╎    1    ...ecial/exp.jl:182; table_unpack
#    1╎    ╎    ╎    ╎     1    ...sentials.jl:513; reinterpret
#     ╎    ╎    ╎    ╎   2    ...ecial/exp.jl:216; exp_impl
#     ╎    ╎    ╎    ╎    2    ...ecial/exp.jl:78; expm1b_kernel
#     ╎    ╎    ╎    ╎     2    @Base/math.jl:177; evalpoly
#     ╎    ╎    ╎    ╎    ╎ 2    @Base/math.jl:178; macro expansion
#    2╎    ╎    ╎    ╎    ╎  2    @Base/float.jl:413; muladd
#     ╎    ╎    ╎    ╎   6    ...ecial/exp.jl:218; exp_impl
#    6╎    ╎    ╎    ╎    6    @Base/float.jl:609; abs
#     ╎    ╎    ╎     4    ...s/utilities.jl:14; ∇²σ²_j
#     ╎    ╎    ╎    ╎ 4    .../operators.jl:578; *
#    4╎    ╎    ╎    ╎  4    @Base/float.jl:410; *
#     ╎    ╎    ╎    3    ...s/utilities.jl:138; dβdβ_res_ij
#     ╎    ╎    ╎     3    .../operators.jl:578; *
#    3╎    ╎    ╎    ╎ 3    @Base/float.jl:410; *
#     ╎    ╎    ╎    20   ...s/utilities.jl:139; dβdβ_res_ij
#   18╎    ╎    ╎     18   @Base/float.jl:410; *
#     ╎    ╎    ╎     2    @Base/number.jl:255; inv
#    2╎    ╎    ╎    ╎ 2    @Base/float.jl:411; /
#     ╎    ╎    ╎    1    ...s/utilities.jl:140; dβdβ_res_ij
#     ╎    ╎    ╎     1    .../operators.jl:578; +
#     ╎    ╎    ╎    ╎ 1    .../operators.jl:536; afoldl
#    1╎    ╎    ╎    ╎  1    @Base/float.jl:408; +
#     ╎    ╎    ╎  13   @Base/timing.jl:394; macro expansion
#   13╎    ╎    ╎   13   @Base/Base.jl:94; time_ns
#     ╎    ╎    ╎ 46   ...longitudinal.jl:122; macro expansion
#     ╎    ╎    ╎  1    @Base/timing.jl:392; macro expansion
#    1╎    ╎    ╎   1    @Base/Base.jl:94; time_ns
#    2╎    ╎    ╎  32   @Base/timing.jl:393; macro expansion
#    1╎    ╎    ╎   1    @Base/float.jl:408; +
#     ╎    ╎    ╎   1    ...ongitudinal.jl:176; calculate_Ri(qc_model::...
#     ╎    ╎    ╎    1    @Base/range.jl:5; Colon
#     ╎    ╎    ╎     1    @Base/range.jl:397; UnitRange
#    1╎    ╎    ╎    ╎ 1    @Base/range.jl:404; unitrange_last
#     ╎    ╎    ╎   4    ...ongitudinal.jl:178; calculate_Ri(qc_model::...
#     ╎    ╎    ╎    4    ...e/broadcast.jl:881; materialize!
#     ╎    ╎    ╎     4    .../broadcast.jl:884; materialize!
#     ╎    ╎    ╎    ╎ 4    .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎  2    .../broadcast.jl:970; copyto!
#     ╎    ╎    ╎    ╎   2    ...broadcast.jl:953; preprocess
#     ╎    ╎    ╎    ╎    2    ...broadcast.jl:956; preprocess_args
#    2╎    ╎    ╎    ╎     2    @Base/array.jl:0; size
#     ╎    ╎    ╎    ╎  2    .../broadcast.jl:973; copyto!
#     ╎    ╎    ╎    ╎   1    ...e/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎    1    ...broadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎     1    ...roadcast.jl:610; getindex
#     ╎    ╎    ╎    ╎    ╎ 1    ...roadcast.jl:655; _broadcast_getindex
#     ╎    ╎    ╎    ╎    ╎  1    ...roadcast.jl:679; _getindex
#     ╎    ╎    ╎    ╎    ╎   1    ...oadcast.jl:680; _getindex
#     ╎    ╎    ╎    ╎    ╎    1    ...oadcast.jl:655; _broadcast_getindex
#     ╎    ╎    ╎    ╎    ╎     1    ...adcast.jl:679; _getindex
#     ╎    ╎    ╎    ╎    ╎    ╎ 1    ...adcast.jl:649; _broadcast_geti...
#    1╎    ╎    ╎    ╎    ╎    ╎  1    ...ntials.jl:13; getindex
#     ╎    ╎    ╎    ╎   1    ...e/simdloop.jl:78; macro expansion
#    1╎    ╎    ╎    ╎    1    @Base/int.jl:87; +
#     ╎    ╎    ╎   3    ...ongitudinal.jl:179; calculate_Ri(qc_model::...
#     ╎    ╎    ╎    3    .../src/matmul.jl:14; dot
#    2╎    ╎    ╎     2    ...a/src/blas.jl:392; dot(x::SubArray{Float6...
#     ╎    ╎    ╎     1    ...a/src/blas.jl:395; dot(x::SubArray{Float6...
#    1╎    ╎    ╎    ╎ 1    ...a/src/blas.jl:345; dot
#     ╎    ╎    ╎   17   ...ongitudinal.jl:181; calculate_Ri(qc_model::...
#     ╎    ╎    ╎    17   .../src/matmul.jl:276; mul!
#    2╎    ╎    ╎     17   .../src/matmul.jl:65; mul!
#    3╎    ╎    ╎    ╎ 3    ...src/matmul.jl:490; gemv!(y::SubArray{Flo...
#     ╎    ╎    ╎    ╎ 4    ...src/matmul.jl:492; gemv!(y::SubArray{Flo...
#     ╎    ╎    ╎    ╎  4    ...src/matmul.jl:725; lapack_size
#     ╎    ╎    ╎    ╎   4    ...tractarray.jl:42; size
#     ╎    ╎    ╎    ╎    4    .../subarray.jl:63; size
#    4╎    ╎    ╎    ╎     4    @Base/tuple.jl:274; map
#     ╎    ╎    ╎    ╎ 1    ...src/matmul.jl:499; gemv!(y::SubArray{Flo...
#     ╎    ╎    ╎    ╎  1    .../promotion.jl:387; promote
#     ╎    ╎    ╎    ╎   1    ...promotion.jl:365; _promote
#     ╎    ╎    ╎    ╎    1    @Base/number.jl:7; convert
#    1╎    ╎    ╎    ╎     1    @Base/float.jl:0; Float64
#    4╎    ╎    ╎    ╎ 7    ...src/matmul.jl:503; gemv!(y::SubArray{Flo...
#    2╎    ╎    ╎    ╎  2    ...a/src/blas.jl:643; gemv!(trans::Char, al...
#    1╎    ╎    ╎    ╎  1    ...a/src/blas.jl:648; gemv!(trans::Char, al...
#     ╎    ╎    ╎   4    ...ongitudinal.jl:182; calculate_Ri(qc_model::...
#    1╎    ╎    ╎    4    .../src/matmul.jl:14; dot
#    1╎    ╎    ╎     1    ...a/src/blas.jl:392; dot(x::SubArray{Float6...
#     ╎    ╎    ╎     2    ...a/src/blas.jl:395; dot(x::SubArray{Float6...
#    2╎    ╎    ╎    ╎ 2    ...a/src/blas.jl:345; dot
#     ╎    ╎    ╎  13   @Base/timing.jl:394; macro expansion
#   11╎    ╎    ╎   11   @Base/Base.jl:94; time_ns
#     ╎    ╎    ╎   2    ...e/promotion.jl:413; /
#    2╎    ╎    ╎    2    @Base/float.jl:411; /
#     ╎    ╎    ╎ 1    ...rogressMeter.jl:727; iterate(wrap::ProgressMe...
#     ╎    ╎    ╎  1    ...rogressMeter.jl:545; finish!
#     ╎    ╎    ╎   1    ...ogressMeter.jl:547; #finish!#26
#     ╎    ╎    ╎    1    ...ogressMeter.jl:486; update!
#     ╎    ╎    ╎     1    ...gressMeter.jl:487; #update!#17
#     ╎    ╎    ╎    ╎ 1    ...gressMeter.jl:457; lock_if_threading
#     ╎    ╎    ╎    ╎  1    ...gressMeter.jl:490; #18
#     ╎    ╎    ╎    ╎   1    ...ressMeter.jl:208; updateProgress!
#     ╎    ╎    ╎    ╎    1    ...ressMeter.jl:250; updateProgress!(p::...
#     ╎    ╎    ╎    ╎     1    ...rc/stdio.jl:277; flush(io::IJulia.IJ...
#     ╎    ╎    ╎    ╎    ╎ 1    ...rc/stdio.jl:163; send_stream(name::...
#     ╎    ╎    ╎    ╎    ╎  1    .../src/msg.jl:55; send_ipython(socke...
#     ╎    ╎    ╎    ╎    ╎   1    ...src/hmac.jl:10; hmac(s1::String, s...
#     ╎    ╎    ╎    ╎    ╎    1    ...ings/io.jl:244; write(io::MbedTL...
#     ╎    ╎    ╎    ╎    ╎     1    @Base/io.jl:305; unsafe_write
#     ╎    ╎    ╎    ╎    ╎    ╎ 1    ...src/md.jl:143; write
#     ╎    ╎    ╎    ╎    ╎    ╎  1    ...src/md.jl:128; _write
#    1╎    ╎    ╎    ╎    ╎    ╎   1    .../error.jl:3; macro expansion
#     ╎    ╎    ╎ 5    ...rogressMeter.jl:729; iterate(wrap::ProgressMe...
#     ╎    ╎    ╎  5    ...rogressMeter.jl:470; next!
#     ╎    ╎    ╎   5    ...ogressMeter.jl:471; #next!#14
#     ╎    ╎    ╎    5    ...ogressMeter.jl:457; lock_if_threading
#     ╎    ╎    ╎     5    ...gressMeter.jl:473; #15
#     ╎    ╎    ╎    ╎ 5    ...gressMeter.jl:208; updateProgress!
#     ╎    ╎    ╎    ╎  1    ...gressMeter.jl:259; updateProgress!(p::Pr...
#    1╎    ╎    ╎    ╎   1    ...operators.jl:369; >(x::Float64, y::Flo...
#     ╎    ╎    ╎    ╎  2    ...gressMeter.jl:280; updateProgress!(p::Pr...
#     ╎    ╎    ╎    ╎   2    ...ressMeter.jl:604; printover(io::IJulia...
#     ╎    ╎    ╎    ╎    2    ...trings/io.jl:246; print
#     ╎    ╎    ╎    ╎     2    ...rings/io.jl:244; write
#     ╎    ╎    ╎    ╎    ╎ 2    @Base/io.jl:430; unsafe_write
#     ╎    ╎    ╎    ╎    ╎  2    .../stream.jl:1120; unsafe_write(s::B...
#     ╎    ╎    ╎    ╎    ╎   2    .../stream.jl:1048; uv_write(s::Base...
#     ╎    ╎    ╎    ╎    ╎    2    @Base/task.jl:985; wait()
#    2╎    ╎    ╎    ╎    ╎     2    .../libuv.jl:107; process_events
#     ╎    ╎    ╎    ╎  2    ...gressMeter.jl:283; updateProgress!(p::Pr...
#     ╎    ╎    ╎    ╎   1    ...src/stdio.jl:275; flush(io::IJulia.IJu...
#     ╎    ╎    ╎    ╎    1    @Base/io.jl:426; flush
#     ╎    ╎    ╎    ╎     1    ...e/stream.jl:1133; flush(s::Base.Pipe...
#     ╎    ╎    ╎    ╎    ╎ 1    ...e/stream.jl:1048; uv_write(s::Base.P...
#     ╎    ╎    ╎    ╎    ╎  1    @Base/task.jl:983; wait()
#    1╎    ╎    ╎    ╎    ╎   1    @Base/task.jl:974; poptask(W::Base.I...
#     ╎    ╎    ╎    ╎   1    ...src/stdio.jl:276; flush(io::IJulia.IJu...
#     ╎    ╎    ╎    ╎    1    ...src/stdio.jl:269; oslibuv_flush
#     ╎    ╎    ╎    ╎     1    @Base/task.jl:864; yield()
#     ╎    ╎    ╎    ╎    ╎ 1    @Base/task.jl:985; wait()
#    1╎    ╎    ╎    ╎    ╎  1    @Base/libuv.jl:107; process_events
#    1╎    ╎    1    .../longitudinal.jl:221; calculate_Qi(qc_model::GL...
#    1╎    ╎    1    .../longitudinal.jl:183; calculate_Ri(qc_model::GL...
#    1╎    ╎    1    .../longitudinal.jl:418; get_Hβγ_i!(W::SubArray{Fl...
#    1╎    ╎    1    .../longitudinal.jl:358; get_neg_Hθγ_i!(W::SubArra...
#    2╎    ╎    2    .../longitudinal.jl:252; get_∇resβ!(∇resβ::SubArra...
#    1╎    ╎    1    .../longitudinal.jl:235; get_∇resγ!(∇resγ::SubArra...
#     ╎1    @Base/task.jl:134; (::Base.var"#702#703"{typeof(I...
#     ╎ 1    @Base/asyncevent.jl:279; macro expansion
#     ╎  1    @Base/asyncevent.jl:138; _trywait(t::Timer)
#     ╎   1    @Base/condition.jl:125; wait
#     ╎    1    @Base/condition.jl:130; wait(c::Base.GenericConditio...
#     ╎     1    @Base/task.jl:985; wait()
#    1╎    ╎ 1    @Base/libuv.jl:107; process_events
#     ╎6    ...eadingconstructs.jl:108; (::Base.Threads.var"#1#2"{Quas...
#     ╎ 6    ...eadingconstructs.jl:130; #135#threadsfor_fun
#     ╎  6    ...eadingconstructs.jl:163; (::QuasiCopula.var"#135#thread...
#     ╎   6    ...timation/GLM_VC.jl:265; macro expansion
#     ╎    6    ...timation/GLM_VC.jl:167; loglikelihood!
#     ╎     1    ...imation/GLM_VC.jl:182; loglikelihood!(gc::GLMCopula...
#     ╎    ╎ 1    ..._and_residuals.jl:65; update_res!(gc::GLMCopulaVCO...
#     ╎    ╎  1    @Base/logging.jl:381; macro expansion
#     ╎    ╎   1    @Base/essentials.jl:813; invokelatest
#     ╎    ╎    1    @Base/essentials.jl:816; #invokelatest#2
#     ╎    ╎     1    ...ConsoleLogger.jl:47; shouldlog(logger::Logging...
#     ╎    ╎    ╎ 1    @Base/dict.jl:510; get
#    1╎    ╎    ╎  1    @Base/dict.jl:261; ht_keyindex(h::Dict{Any,...
#     ╎     1    ...imation/GLM_VC.jl:221; loglikelihood!(gc::GLMCopula...
#     ╎    ╎ 1    ...bra/src/matmul.jl:474; copytri!
#     ╎    ╎  1    ...bra/src/matmul.jl:482; copytri!
#    1╎    ╎   1    @Base/essentials.jl:0; getindex
#     ╎     2    ...imation/GLM_VC.jl:226; loglikelihood!(gc::GLMCopula...
#     ╎    ╎ 2    ...bra/src/matmul.jl:276; mul!
#     ╎    ╎  2    ...bra/src/matmul.jl:161; mul!
#     ╎    ╎   1    ...ra/src/matmul.jl:643; gemm_wrapper!(C::Matrix{Fl...
#     ╎    ╎    1    ...ra/src/matmul.jl:725; lapack_size
#    1╎    ╎     1    @Base/array.jl:148; size
#     ╎    ╎   1    ...ra/src/matmul.jl:674; gemm_wrapper!(C::Matrix{Fl...
#    1╎    ╎    1    ...bra/src/blas.jl:1505; gemm!(transA::Char, trans...
#     ╎     1    ...imation/GLM_VC.jl:230; loglikelihood!(gc::GLMCopula...
#     ╎    ╎ 1    @Base/broadcast.jl:881; materialize!
#     ╎    ╎  1    @Base/broadcast.jl:884; materialize!
#     ╎    ╎   1    @Base/broadcast.jl:926; copyto!
#     ╎    ╎    1    @Base/broadcast.jl:973; copyto!
#     ╎    ╎     1    @Base/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎ 1    @Base/broadcast.jl:974; macro expansion
#     ╎    ╎    ╎  1    ...idimensional.jl:670; setindex!
#    1╎    ╎    ╎   1    @Base/array.jl:971; setindex!
#     ╎     1    ...imation/GLM_VC.jl:231; loglikelihood!(gc::GLMCopula...
#     ╎    ╎ 1    @Base/broadcast.jl:881; materialize!
#     ╎    ╎  1    @Base/broadcast.jl:884; materialize!
#     ╎    ╎   1    @Base/broadcast.jl:926; copyto!
#     ╎    ╎    1    @Base/broadcast.jl:970; copyto!
#     ╎    ╎     1    @Base/broadcast.jl:953; preprocess
#     ╎    ╎    ╎ 1    @Base/broadcast.jl:956; preprocess_args
#     ╎    ╎    ╎  1    @Base/broadcast.jl:957; preprocess_args
#     ╎    ╎    ╎   1    ...e/broadcast.jl:954; preprocess
#    1╎    ╎    ╎    1    ...e/broadcast.jl:947; broadcast_unalias
# 2199╎2199 ...ia/src/heartbeat.jl:22; heartbeat_thread(sock::Ptr{Not...
#    3╎3    ...Algebra/src/blas.jl:524; axpy!(alpha::Float64, x::Matri...
#    4╎4    ...Algebra/src/blas.jl:395; dot(x::SubArray{Float64, 1, Ve...
#    1╎1    ...Algebra/src/blas.jl:643; gemv!(trans::Char, alpha::Floa...
#   12╎12   ...Algebra/src/blas.jl:674; gemv!(trans::Char, alpha::Floa...
#    7╎7    ...gebra/src/matmul.jl:0; gemv!(y::SubArray{Float64, 1, ...
# Total snapshots: 4398. Utilization: 100% across all threads and tasks. Use the `groupby` kwarg to break down by thread and/or task.

# %% [markdown]
# Profile 3/13/2024 (removed allocations)

# %%
# 3/13/2024 (removed allocations)
@profile QuasiCopula.GWASCopulaVCModel(qc_model, G, check_grad=false)
Profile.clear()
@profile QuasiCopula.GWASCopulaVCModel(qc_model, G, check_grad=false)
Profile.print()
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:03
# Wtime = 1.735297679992745
# Qtime = 0.5704354329990938
# Rtime = 0.18151814099770375
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:03
# Wtime = 1.8720003199923396
# Qtime = 0.6215805919971553
# Rtime = 0.19252829099750113
# Overhead ╎ [+additional indent] Count File:Line; Function
# =========================================================
#    2╎2     @Base/abstractarray.jl:0; copyto_unaliased!(deststyle::I...
#     ╎10    ...multidimensional.jl:1003; mightalias(A::SubArray{Float64...
#   10╎ 10    @Base/Base.jl:37; getproperty
#   34╎34    @Base/special/exp.jl:325; exp(x::Float64)
#     ╎2891  @Base/task.jl:514; (::IJulia.var"#15#18")()
#     ╎ 2891  ...ia/src/eventloop.jl:8; eventloop(socket::ZMQ.Socket)
#     ╎  2891  @Base/essentials.jl:813; invokelatest
#     ╎   2891  @Base/essentials.jl:816; #invokelatest#2
#     ╎    2891  ...execute_request.jl:67; execute_request(socket::ZMQ....
#     ╎     2891  ...oftGlobalScope.jl:65; softscope_include_string(m::...
#     ╎    ╎ 2891  @Base/loading.jl:1899; include_string(mapexpr::ty...
#     ╎    ╎  2891  @Base/boot.jl:370; eval
#     ╎    ╎   2891  .../longitudinal.jl:58; kwcall(::NamedTuple{(:chec...
#     ╎    ╎    332   ...longitudinal.jl:84; GWASCopulaVCModel(qc_mode...
#     ╎    ╎     294   ...longitudinal.jl:260; get_Pinv(qc_model::GLMCo...
#    2╎    ╎    ╎ 2     @Base/simdloop.jl:0; get_Hββ(qc_model::GLMCop...
#     ╎    ╎    ╎ 13    ...longitudinal.jl:444; get_Hββ(qc_model::GLMCop...
#     ╎    ╎    ╎  8     ...e/arraymath.jl:8; -(A::Matrix{Float64}, ...
#     ╎    ╎    ╎   8     ...e/broadcast.jl:862; broadcast_preserving_z...
#     ╎    ╎    ╎    8     .../broadcast.jl:873; materialize
#     ╎    ╎    ╎     8     .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎ 4     .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎  2     ...broadcast.jl:970; copyto!
#     ╎    ╎    ╎    ╎   2     ...broadcast.jl:953; preprocess
#     ╎    ╎    ╎    ╎    2     ...roadcast.jl:956; preprocess_args
#     ╎    ╎    ╎    ╎     2     ...roadcast.jl:957; preprocess_args
#     ╎    ╎    ╎    ╎    ╎ 2     ...roadcast.jl:954; preprocess
#    2╎    ╎    ╎    ╎    ╎  2     ...oadcast.jl:947; broadcast_unalias
#     ╎    ╎    ╎    ╎  2     ...broadcast.jl:973; copyto!
#    2╎    ╎    ╎    ╎   2     .../simdloop.jl:75; macro expansion
#     ╎    ╎    ╎    ╎ 4     .../broadcast.jl:211; similar
#     ╎    ╎    ╎    ╎  4     ...broadcast.jl:212; similar
#     ╎    ╎    ╎    ╎   4     ...ractarray.jl:881; similar
#     ╎    ╎    ╎    ╎    4     ...actarray.jl:882; similar
#     ╎    ╎    ╎    ╎     4     @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎ 4     @Base/boot.jl:487; Array
#    4╎    ╎    ╎    ╎    ╎  4     @Base/boot.jl:479; Array
#     ╎    ╎    ╎  5     .../src/matmul.jl:1166; *
#     ╎    ╎    ╎   5     ...src/matmul.jl:1170; _tri_matmul
#     ╎    ╎    ╎    5     ...src/matmul.jl:1178; _tri_matmul(A::Transp...
#     ╎    ╎    ╎     2     ...c/diagonal.jl:256; *
#     ╎    ╎    ╎    ╎ 2     .../transpose.jl:211; copy_similar
#     ╎    ╎    ╎    ╎  2     .../transpose.jl:41; transpose!
#    2╎    ╎    ╎    ╎   2     ...transpose.jl:106; transpose_f!(f::typ...
#     ╎    ╎    ╎     3     ...src/matmul.jl:148; *
#     ╎    ╎    ╎    ╎ 3     @Base/array.jl:374; similar
#     ╎    ╎    ╎    ╎  3     @Base/boot.jl:487; Array
#    3╎    ╎    ╎    ╎   3     @Base/boot.jl:479; Array
#     ╎    ╎    ╎ 12    ...longitudinal.jl:453; get_Hββ(qc_model::GLMCop...
#     ╎    ╎    ╎  2     ...e/arraymath.jl:8; -(A::Matrix{Float64}, ...
#     ╎    ╎    ╎   2     ...e/broadcast.jl:862; broadcast_preserving_z...
#     ╎    ╎    ╎    2     .../broadcast.jl:873; materialize
#     ╎    ╎    ╎     2     .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎ 2     .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎  2     ...broadcast.jl:973; copyto!
#     ╎    ╎    ╎    ╎   2     .../simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎    2     ...roadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎     2     ...ensional.jl:670; setindex!
#    2╎    ╎    ╎    ╎    ╎ 2     @Base/array.jl:971; setindex!
#     ╎    ╎    ╎  2     ...e/arraymath.jl:24; /(A::Matrix{Float64}, ...
#     ╎    ╎    ╎   2     ...e/broadcast.jl:862; broadcast_preserving_z...
#     ╎    ╎    ╎    2     .../broadcast.jl:873; materialize
#     ╎    ╎    ╎     2     .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎ 2     .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎  2     ...broadcast.jl:973; copyto!
#     ╎    ╎    ╎    ╎   2     .../simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎    2     ...roadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎     2     ...ensional.jl:670; setindex!
#    2╎    ╎    ╎    ╎    ╎ 2     @Base/array.jl:971; setindex!
#    2╎    ╎    ╎  2     @Base/simdloop.jl:0; /(A::Matrix{Float64}, ...
#     ╎    ╎    ╎  4     ...rc/adjtrans.jl:439; *
#     ╎    ╎    ╎   4     ...e/broadcast.jl:811; broadcast(::typeof(*),...
#     ╎    ╎    ╎    4     .../broadcast.jl:873; materialize
#     ╎    ╎    ╎     4     .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎ 4     .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎  4     ...broadcast.jl:973; copyto!
#    4╎    ╎    ╎    ╎   4     .../simdloop.jl:75; macro expansion
#     ╎    ╎    ╎  2     .../src/matmul.jl:1150; *
#     ╎    ╎    ╎   2     .../src/matmul.jl:52; *
#     ╎    ╎    ╎    2     ...tractarray.jl:838; similar
#     ╎    ╎    ╎     2     @Base/array.jl:374; similar
#     ╎    ╎    ╎    ╎ 2     @Base/boot.jl:486; Array
#    2╎    ╎    ╎    ╎  2     @Base/boot.jl:477; Array
#     ╎    ╎    ╎ 24    ...longitudinal.jl:455; get_Hββ(qc_model::GLMCop...
#     ╎    ╎    ╎  4     ...e/arraymath.jl:16; +(A::Matrix{Float64}, ...
#     ╎    ╎    ╎   4     ...e/broadcast.jl:862; broadcast_preserving_z...
#     ╎    ╎    ╎    4     .../broadcast.jl:873; materialize
#     ╎    ╎    ╎     4     .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎ 4     .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎  4     ...broadcast.jl:973; copyto!
#    2╎    ╎    ╎    ╎   2     .../simdloop.jl:75; macro expansion
#     ╎    ╎    ╎    ╎   2     .../simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎    2     ...roadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎     2     ...ensional.jl:670; setindex!
#    2╎    ╎    ╎    ╎    ╎ 2     @Base/array.jl:971; setindex!
#     ╎    ╎    ╎  18    ...e/arraymath.jl:24; /(A::Matrix{Float64}, ...
#     ╎    ╎    ╎   18    ...e/broadcast.jl:862; broadcast_preserving_z...
#     ╎    ╎    ╎    18    .../broadcast.jl:873; materialize
#     ╎    ╎    ╎     18    .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎ 2     .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎  2     ...broadcast.jl:973; copyto!
#    2╎    ╎    ╎    ╎   2     .../simdloop.jl:75; macro expansion
#     ╎    ╎    ╎    ╎ 16    .../broadcast.jl:211; similar
#     ╎    ╎    ╎    ╎  16    ...broadcast.jl:212; similar
#     ╎    ╎    ╎    ╎   16    ...ractarray.jl:881; similar
#     ╎    ╎    ╎    ╎    16    ...actarray.jl:882; similar
#     ╎    ╎    ╎    ╎     16    @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎ 16    @Base/boot.jl:487; Array
#   16╎    ╎    ╎    ╎    ╎  16    @Base/boot.jl:479; Array
#     ╎    ╎    ╎  2     .../src/matmul.jl:1166; *
#     ╎    ╎    ╎   2     ...src/matmul.jl:1170; _tri_matmul
#     ╎    ╎    ╎    2     ...src/matmul.jl:1178; _tri_matmul(A::Adjoin...
#     ╎    ╎    ╎     2     ...src/matmul.jl:148; *
#     ╎    ╎    ╎    ╎ 2     @Base/array.jl:374; similar
#     ╎    ╎    ╎    ╎  2     @Base/boot.jl:487; Array
#    2╎    ╎    ╎    ╎   2     @Base/boot.jl:479; Array
#     ╎    ╎    ╎ 10    ...longitudinal.jl:465; get_Hββ(qc_model::GLMCop...
#     ╎    ╎    ╎  10    ...stractarray.jl:1294; getindex
#     ╎    ╎    ╎   10    ...dimensional.jl:861; _getindex
#     ╎    ╎    ╎    10    ...imensional.jl:873; _unsafe_getindex
#     ╎    ╎    ╎     10    ...tractarray.jl:836; similar
#     ╎    ╎    ╎    ╎ 10    @Base/array.jl:374; similar
#     ╎    ╎    ╎    ╎  10    @Base/boot.jl:486; Array
#   10╎    ╎    ╎    ╎   10    @Base/boot.jl:477; Array
#     ╎    ╎    ╎ 233   ...longitudinal.jl:468; get_Hββ(qc_model::GLMCop...
#     ╎    ╎    ╎  13    ...e/arraymath.jl:16; +(A::Matrix{Float64}, B...
#     ╎    ╎    ╎   13    ...e/broadcast.jl:862; broadcast_preserving_z...
#     ╎    ╎    ╎    13    .../broadcast.jl:873; materialize
#     ╎    ╎    ╎     13    .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎ 7     .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎  1     ...broadcast.jl:970; copyto!
#     ╎    ╎    ╎    ╎   1     ...broadcast.jl:953; preprocess
#     ╎    ╎    ╎    ╎    1     ...roadcast.jl:956; preprocess_args
#     ╎    ╎    ╎    ╎     1     ...roadcast.jl:957; preprocess_args
#     ╎    ╎    ╎    ╎    ╎ 1     ...roadcast.jl:954; preprocess
#     ╎    ╎    ╎    ╎    ╎  1     ...oadcast.jl:650; extrude
#     ╎    ╎    ╎    ╎    ╎   1     ...oadcast.jl:599; newindexer
#     ╎    ╎    ╎    ╎    ╎    1     ...adcast.jl:600; shapeindexer
#     ╎    ╎    ╎    ╎    ╎     1     ...adcast.jl:604; _newindexer
#     ╎    ╎    ╎    ╎    ╎    ╎ 1     ...adcast.jl:605; _newindexer
#     ╎    ╎    ╎    ╎    ╎    ╎  1     ...rators.jl:269; !=
#    1╎    ╎    ╎    ╎    ╎    ╎   1     ...motion.jl:499; ==
#     ╎    ╎    ╎    ╎  6     ...broadcast.jl:973; copyto!
#     ╎    ╎    ╎    ╎   4     .../simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎    4     ...roadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎     4     ...ensional.jl:670; setindex!
#    4╎    ╎    ╎    ╎    ╎ 4     @Base/array.jl:971; setindex!
#    2╎    ╎    ╎    ╎   2     .../simdloop.jl:84; macro expansion
#     ╎    ╎    ╎    ╎ 6     .../broadcast.jl:211; similar
#     ╎    ╎    ╎    ╎  6     ...broadcast.jl:212; similar
#     ╎    ╎    ╎    ╎   6     ...ractarray.jl:881; similar
#     ╎    ╎    ╎    ╎    6     ...actarray.jl:882; similar
#     ╎    ╎    ╎    ╎     6     @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎ 6     @Base/boot.jl:487; Array
#    6╎    ╎    ╎    ╎    ╎  6     @Base/boot.jl:479; Array
#    2╎    ╎    ╎  9     ...e/arraymath.jl:24; /(A::Matrix{Float64}, B...
#     ╎    ╎    ╎   7     ...e/broadcast.jl:862; broadcast_preserving_z...
#     ╎    ╎    ╎    7     .../broadcast.jl:873; materialize
#     ╎    ╎    ╎     7     .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎ 6     .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎  2     ...broadcast.jl:962; copyto!
#     ╎    ╎    ╎    ╎   2     ...ractarray.jl:98; axes
#    2╎    ╎    ╎    ╎    2     @Base/array.jl:150; size
#     ╎    ╎    ╎    ╎  4     ...broadcast.jl:973; copyto!
#     ╎    ╎    ╎    ╎   4     .../simdloop.jl:84; macro expansion
#     ╎    ╎    ╎    ╎    4     ...ensional.jl:402; iterate
#     ╎    ╎    ╎    ╎     4     ...ensional.jl:420; __inc
#    4╎    ╎    ╎    ╎    ╎ 4     @Base/int.jl:87; +
#     ╎    ╎    ╎    ╎ 1     .../broadcast.jl:211; similar
#     ╎    ╎    ╎    ╎  1     ...broadcast.jl:212; similar
#     ╎    ╎    ╎    ╎   1     ...ractarray.jl:881; similar
#     ╎    ╎    ╎    ╎    1     ...actarray.jl:882; similar
#     ╎    ╎    ╎    ╎     1     @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎ 1     @Base/boot.jl:487; Array
#    1╎    ╎    ╎    ╎    ╎  1     @Base/boot.jl:479; Array
#     ╎    ╎    ╎  29    ...e/operators.jl:578; *
#     ╎    ╎    ╎   14    ...e/operators.jl:535; afoldl
#    2╎    ╎    ╎    14    ...e/arraymath.jl:21; *(A::Float64, B::Matri...
#     ╎    ╎    ╎     12    .../broadcast.jl:862; broadcast_preserving_...
#     ╎    ╎    ╎    ╎ 12    .../broadcast.jl:873; materialize
#     ╎    ╎    ╎    ╎  12    ...broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎   6     ...broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎    2     ...roadcast.jl:962; copyto!
#     ╎    ╎    ╎    ╎     2     @Base/tuple.jl:458; ==
#    2╎    ╎    ╎    ╎    ╎ 2     @Base/tuple.jl:463; _eq
#     ╎    ╎    ╎    ╎    4     ...roadcast.jl:973; copyto!
#     ╎    ╎    ╎    ╎     4     ...simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎    ╎ 4     ...roadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎    ╎  4     ...nsional.jl:670; setindex!
#    4╎    ╎    ╎    ╎    ╎   4     ...e/array.jl:971; setindex!
#     ╎    ╎    ╎    ╎   6     ...broadcast.jl:211; similar
#     ╎    ╎    ╎    ╎    6     ...roadcast.jl:212; similar
#     ╎    ╎    ╎    ╎     6     ...actarray.jl:881; similar
#     ╎    ╎    ╎    ╎    ╎ 6     ...actarray.jl:882; similar
#     ╎    ╎    ╎    ╎    ╎  6     @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎   6     @Base/boot.jl:487; Array
#    6╎    ╎    ╎    ╎    ╎    6     ...e/boot.jl:479; Array
#     ╎    ╎    ╎   15    .../src/matmul.jl:119; *
#     ╎    ╎    ╎    15    ...src/matmul.jl:101; *
#     ╎    ╎    ╎     13    ...tractarray.jl:838; similar
#     ╎    ╎    ╎    ╎ 13    @Base/array.jl:374; similar
#     ╎    ╎    ╎    ╎  13    @Base/boot.jl:486; Array
#   13╎    ╎    ╎    ╎   13    @Base/boot.jl:477; Array
#     ╎    ╎    ╎     2     ...src/matmul.jl:276; mul!
#     ╎    ╎    ╎    ╎ 2     ...src/matmul.jl:109; mul!
#     ╎    ╎    ╎    ╎  2     ...src/matmul.jl:93; mul!
#    2╎    ╎    ╎    ╎   2     ...rc/matmul.jl:490; gemv!(y::Vector{Flo...
#     ╎    ╎    ╎  2     ...s/utilities.jl:131; dβdβ_res_ij(dist::Berno...
#     ╎    ╎    ╎   2     ...e/arraymath.jl:21; *(A::Float64, B::Vector...
#     ╎    ╎    ╎    2     .../broadcast.jl:862; broadcast_preserving_z...
#     ╎    ╎    ╎     2     .../broadcast.jl:873; materialize
#     ╎    ╎    ╎    ╎ 2     .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎  2     ...broadcast.jl:211; similar
#     ╎    ╎    ╎    ╎   2     ...broadcast.jl:212; similar
#     ╎    ╎    ╎    ╎    2     ...actarray.jl:881; similar
#     ╎    ╎    ╎    ╎     2     ...actarray.jl:882; similar
#     ╎    ╎    ╎    ╎    ╎ 2     @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎  2     @Base/boot.jl:486; Array
#    2╎    ╎    ╎    ╎    ╎   2     @Base/boot.jl:477; Array
#     ╎    ╎    ╎  6     ...s/utilities.jl:132; dβdβ_res_ij(dist::Berno...
#     ╎    ╎    ╎   6     ...e/operators.jl:578; *
#     ╎    ╎    ╎    6     ...e/arraymath.jl:21; *(A::Float64, B::Vecto...
#     ╎    ╎    ╎     6     .../broadcast.jl:862; broadcast_preserving_...
#     ╎    ╎    ╎    ╎ 6     .../broadcast.jl:873; materialize
#     ╎    ╎    ╎    ╎  6     ...broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎   2     ...broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎    2     ...roadcast.jl:973; copyto!
#     ╎    ╎    ╎    ╎     2     ...simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎    ╎ 2     ...roadcast.jl:974; macro expansion
#    2╎    ╎    ╎    ╎    ╎  2     ...e/array.jl:969; setindex!
#     ╎    ╎    ╎    ╎   4     ...broadcast.jl:211; similar
#     ╎    ╎    ╎    ╎    4     ...roadcast.jl:212; similar
#     ╎    ╎    ╎    ╎     4     ...actarray.jl:881; similar
#     ╎    ╎    ╎    ╎    ╎ 4     ...actarray.jl:882; similar
#     ╎    ╎    ╎    ╎    ╎  4     @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎   4     @Base/boot.jl:486; Array
#    4╎    ╎    ╎    ╎    ╎    4     ...e/boot.jl:477; Array
#     ╎    ╎    ╎  31    ...s/utilities.jl:135; dβdβ_res_ij(dist::Berno...
#     ╎    ╎    ╎   12    ...e/arraymath.jl:21; *(A::Float64, B::Matrix...
#     ╎    ╎    ╎    12    .../broadcast.jl:862; broadcast_preserving_z...
#     ╎    ╎    ╎     12    .../broadcast.jl:873; materialize
#     ╎    ╎    ╎    ╎ 12    .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎  8     ...broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎   2     ...broadcast.jl:962; copyto!
#     ╎    ╎    ╎    ╎    2     ...ractarray.jl:98; axes
#    2╎    ╎    ╎    ╎     2     @Base/array.jl:150; size
#     ╎    ╎    ╎    ╎   6     ...broadcast.jl:973; copyto!
#    4╎    ╎    ╎    ╎    4     .../simdloop.jl:75; macro expansion
#     ╎    ╎    ╎    ╎    2     .../simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎     2     ...roadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎    ╎ 2     ...ensional.jl:670; setindex!
#    2╎    ╎    ╎    ╎    ╎  2     ...e/array.jl:971; setindex!
#     ╎    ╎    ╎    ╎  4     ...broadcast.jl:211; similar
#     ╎    ╎    ╎    ╎   4     ...broadcast.jl:212; similar
#     ╎    ╎    ╎    ╎    4     ...actarray.jl:881; similar
#     ╎    ╎    ╎    ╎     4     ...actarray.jl:882; similar
#     ╎    ╎    ╎    ╎    ╎ 4     @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎  4     @Base/boot.jl:487; Array
#    4╎    ╎    ╎    ╎    ╎   4     @Base/boot.jl:479; Array
#    1╎    ╎    ╎   1     ...s/utilities.jl:53; ∇²μ_j(l::LogitLink, ηj:...
#     ╎    ╎    ╎   18    ...s/utilities.jl:55; ∇²μ_j(l::LogitLink, ηj:...
#    2╎    ╎    ╎    18    ...src/matmul.jl:1162; *
#    2╎    ╎    ╎     16    .../broadcast.jl:811; broadcast(::typeof(*)...
#     ╎    ╎    ╎    ╎ 14    .../broadcast.jl:873; materialize
#     ╎    ╎    ╎    ╎  14    ...broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎   10    ...broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎    10    ...roadcast.jl:973; copyto!
#   10╎    ╎    ╎    ╎     10    ...simdloop.jl:75; macro expansion
#     ╎    ╎    ╎    ╎   4     ...broadcast.jl:211; similar
#     ╎    ╎    ╎    ╎    4     ...roadcast.jl:212; similar
#     ╎    ╎    ╎    ╎     4     ...actarray.jl:881; similar
#     ╎    ╎    ╎    ╎    ╎ 4     ...actarray.jl:882; similar
#     ╎    ╎    ╎    ╎    ╎  4     @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎   4     @Base/boot.jl:487; Array
#    4╎    ╎    ╎    ╎    ╎    4     ...e/boot.jl:479; Array
#     ╎    ╎    ╎  21    ...s/utilities.jl:136; dβdβ_res_ij(dist::Berno...
#    2╎    ╎    ╎   21    ...src/matmul.jl:1162; *
#     ╎    ╎    ╎    19    .../broadcast.jl:811; broadcast(::typeof(*),...
#     ╎    ╎    ╎     19    .../broadcast.jl:873; materialize
#     ╎    ╎    ╎    ╎ 19    .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎  7     ...broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎   2     ...broadcast.jl:970; copyto!
#     ╎    ╎    ╎    ╎    2     ...roadcast.jl:953; preprocess
#     ╎    ╎    ╎    ╎     2     ...roadcast.jl:956; preprocess_args
#     ╎    ╎    ╎    ╎    ╎ 2     ...roadcast.jl:956; preprocess_args
#     ╎    ╎    ╎    ╎    ╎  2     ...oadcast.jl:954; preprocess
#     ╎    ╎    ╎    ╎    ╎   2     ...oadcast.jl:947; broadcast_unalias
#     ╎    ╎    ╎    ╎    ╎    2     ...tarray.jl:1480; unalias
#     ╎    ╎    ╎    ╎    ╎     2     ...tarray.jl:1515; mightalias
#     ╎    ╎    ╎    ╎    ╎    ╎ 2     ...tarray.jl:1522; _isdisjoint
#     ╎    ╎    ╎    ╎    ╎    ╎  2     ...rators.jl:269; !=
#    2╎    ╎    ╎    ╎    ╎    ╎   2     ...motion.jl:499; ==
#     ╎    ╎    ╎    ╎   5     ...broadcast.jl:973; copyto!
#    3╎    ╎    ╎    ╎    3     .../simdloop.jl:75; macro expansion
#     ╎    ╎    ╎    ╎    2     .../simdloop.jl:78; macro expansion
#    2╎    ╎    ╎    ╎     2     @Base/int.jl:87; +
#     ╎    ╎    ╎    ╎  12    ...broadcast.jl:211; similar
#     ╎    ╎    ╎    ╎   12    ...broadcast.jl:212; similar
#     ╎    ╎    ╎    ╎    12    ...actarray.jl:881; similar
#     ╎    ╎    ╎    ╎     12    ...actarray.jl:882; similar
#     ╎    ╎    ╎    ╎    ╎ 12    @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎  12    @Base/boot.jl:487; Array
#   12╎    ╎    ╎    ╎    ╎   12    @Base/boot.jl:479; Array
#     ╎    ╎    ╎  39    ...s/utilities.jl:137; dβdβ_res_ij(dist::Berno...
#     ╎    ╎    ╎   4     ...e/operators.jl:578; *
#     ╎    ╎    ╎    4     .../operators.jl:535; afoldl
#     ╎    ╎    ╎     4     .../arraymath.jl:21; *(A::Float64, B::Matri...
#     ╎    ╎    ╎    ╎ 4     .../broadcast.jl:862; broadcast_preserving_...
#     ╎    ╎    ╎    ╎  4     ...broadcast.jl:873; materialize
#     ╎    ╎    ╎    ╎   4     ...broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎    4     ...roadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎     2     ...roadcast.jl:962; copyto!
#     ╎    ╎    ╎    ╎    ╎ 2     ...actarray.jl:98; axes
#    2╎    ╎    ╎    ╎    ╎  2     ...e/array.jl:150; size
#     ╎    ╎    ╎    ╎     2     ...roadcast.jl:973; copyto!
#     ╎    ╎    ╎    ╎    ╎ 2     ...simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎    ╎  2     ...oadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎    ╎   2     ...nsional.jl:670; setindex!
#    2╎    ╎    ╎    ╎    ╎    2     .../array.jl:971; setindex!
#     ╎    ╎    ╎   35    ...s/utilities.jl:14; ∇²σ²_j(d::Bernoulli{Fl...
#     ╎    ╎    ╎    35    ...src/matmul.jl:1162; *
#     ╎    ╎    ╎     35    .../broadcast.jl:811; broadcast(::typeof(*)...
#     ╎    ╎    ╎    ╎ 35    .../broadcast.jl:873; materialize
#     ╎    ╎    ╎    ╎  35    ...broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎   5     ...broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎    1     ...roadcast.jl:970; copyto!
#     ╎    ╎    ╎    ╎     1     ...roadcast.jl:953; preprocess
#     ╎    ╎    ╎    ╎    ╎ 1     ...roadcast.jl:956; preprocess_args
#     ╎    ╎    ╎    ╎    ╎  1     ...oadcast.jl:956; preprocess_args
#     ╎    ╎    ╎    ╎    ╎   1     ...oadcast.jl:954; preprocess
#     ╎    ╎    ╎    ╎    ╎    1     ...adcast.jl:650; extrude
#     ╎    ╎    ╎    ╎    ╎     1     ...adcast.jl:599; newindexer
#     ╎    ╎    ╎    ╎    ╎    ╎ 1     ...adcast.jl:600; shapeindexer
#     ╎    ╎    ╎    ╎    ╎    ╎  1     ...adcast.jl:605; _newindexer
#     ╎    ╎    ╎    ╎    ╎    ╎   1     ...rators.jl:269; !=
#    1╎    ╎    ╎    ╎    ╎    ╎    1     ...motion.jl:499; ==
#     ╎    ╎    ╎    ╎    4     ...roadcast.jl:973; copyto!
#    2╎    ╎    ╎    ╎     2     ...simdloop.jl:75; macro expansion
#     ╎    ╎    ╎    ╎     2     ...simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎    ╎ 2     ...roadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎    ╎  2     ...nsional.jl:670; setindex!
#    2╎    ╎    ╎    ╎    ╎   2     ...e/array.jl:971; setindex!
#     ╎    ╎    ╎    ╎   30    ...broadcast.jl:211; similar
#     ╎    ╎    ╎    ╎    30    ...roadcast.jl:212; similar
#     ╎    ╎    ╎    ╎     30    ...actarray.jl:881; similar
#     ╎    ╎    ╎    ╎    ╎ 30    ...actarray.jl:882; similar
#     ╎    ╎    ╎    ╎    ╎  30    @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎   30    @Base/boot.jl:487; Array
#   30╎    ╎    ╎    ╎    ╎    30    ...e/boot.jl:479; Array
#     ╎    ╎    ╎  28    ...s/utilities.jl:138; dβdβ_res_ij(dist::Berno...
#     ╎    ╎    ╎   28    ...src/matmul.jl:1162; *
#     ╎    ╎    ╎    28    .../broadcast.jl:811; broadcast(::typeof(*),...
#     ╎    ╎    ╎     28    .../broadcast.jl:873; materialize
#     ╎    ╎    ╎    ╎ 28    .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎  8     ...broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎   8     ...broadcast.jl:973; copyto!
#    4╎    ╎    ╎    ╎    4     .../simdloop.jl:75; macro expansion
#     ╎    ╎    ╎    ╎    2     .../simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎     2     ...roadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎    ╎ 2     ...roadcast.jl:610; getindex
#     ╎    ╎    ╎    ╎    ╎  2     ...oadcast.jl:655; _broadcast_getindex
#     ╎    ╎    ╎    ╎    ╎   2     ...oadcast.jl:679; _getindex
#     ╎    ╎    ╎    ╎    ╎    2     ...adcast.jl:679; _getindex
#     ╎    ╎    ╎    ╎    ╎     2     ...adcast.jl:649; _broadcast_geti...
#     ╎    ╎    ╎    ╎    ╎    ╎ 2     ...sional.jl:668; getindex
#    2╎    ╎    ╎    ╎    ╎    ╎  2     ...ntials.jl:13; getindex
#    2╎    ╎    ╎    ╎    2     .../simdloop.jl:84; macro expansion
#     ╎    ╎    ╎    ╎  20    ...broadcast.jl:211; similar
#     ╎    ╎    ╎    ╎   20    ...broadcast.jl:212; similar
#     ╎    ╎    ╎    ╎    20    ...actarray.jl:881; similar
#     ╎    ╎    ╎    ╎     20    ...actarray.jl:882; similar
#     ╎    ╎    ╎    ╎    ╎ 20    @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎  20    @Base/boot.jl:487; Array
#   20╎    ╎    ╎    ╎    ╎   20    @Base/boot.jl:479; Array
#     ╎    ╎    ╎  30    ...s/utilities.jl:139; dβdβ_res_ij(dist::Berno...
#     ╎    ╎    ╎   30    ...e/operators.jl:578; *
#     ╎    ╎    ╎    16    .../arraymath.jl:21; *(A::Float64, B::Vecto...
#     ╎    ╎    ╎     16    .../broadcast.jl:862; broadcast_preserving_...
#     ╎    ╎    ╎    ╎ 16    .../broadcast.jl:873; materialize
#     ╎    ╎    ╎    ╎  16    ...broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎   16    ...broadcast.jl:211; similar
#     ╎    ╎    ╎    ╎    16    ...roadcast.jl:212; similar
#     ╎    ╎    ╎    ╎     16    ...actarray.jl:881; similar
#     ╎    ╎    ╎    ╎    ╎ 16    ...actarray.jl:882; similar
#     ╎    ╎    ╎    ╎    ╎  16    @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎   16    @Base/boot.jl:486; Array
#   16╎    ╎    ╎    ╎    ╎    16    ...e/boot.jl:477; Array
#     ╎    ╎    ╎    14    .../operators.jl:535; afoldl
#     ╎    ╎    ╎     14    ...c/adjtrans.jl:439; *
#    2╎    ╎    ╎    ╎ 14    .../broadcast.jl:811; broadcast(::typeof(*)...
# WARNING: both Distributions and Convex export "entropy"; uses of it in module QuasiCopula must be qualified
#     ╎    ╎    ╎    ╎  12    ...broadcast.jl:873; materialize
#     ╎    ╎    ╎    ╎   12    ...broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎    8     ...roadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎     8     ...roadcast.jl:973; copyto!
#    2╎    ╎    ╎    ╎    ╎ 2     ...simdloop.jl:75; macro expansion
#     ╎    ╎    ╎    ╎    ╎ 2     ...simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎    ╎  2     ...oadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎    ╎   2     ...nsional.jl:670; setindex!
#    2╎    ╎    ╎    ╎    ╎    2     .../array.jl:971; setindex!
#     ╎    ╎    ╎    ╎    ╎ 2     ...simdloop.jl:78; macro expansion
#    2╎    ╎    ╎    ╎    ╎  2     @Base/int.jl:87; +
#    2╎    ╎    ╎    ╎    ╎ 2     ...simdloop.jl:84; macro expansion
#     ╎    ╎    ╎    ╎    4     ...roadcast.jl:211; similar
#     ╎    ╎    ╎    ╎     4     ...roadcast.jl:212; similar
#     ╎    ╎    ╎    ╎    ╎ 4     ...actarray.jl:881; similar
#     ╎    ╎    ╎    ╎    ╎  4     ...ctarray.jl:882; similar
#     ╎    ╎    ╎    ╎    ╎   4     @Base/boot.jl:494; Array
#     ╎    ╎    ╎    ╎    ╎    4     ...e/boot.jl:487; Array
#    4╎    ╎    ╎    ╎    ╎     4     ...e/boot.jl:479; Array
#     ╎    ╎    ╎  25    ...s/utilities.jl:140; dβdβ_res_ij(dist::Berno...
#     ╎    ╎    ╎   25    ...e/arraymath.jl:16; +(::Matrix{Float64}, ::...
#     ╎    ╎    ╎    23    .../broadcast.jl:862; broadcast_preserving_z...
#     ╎    ╎    ╎     23    .../broadcast.jl:873; materialize
#     ╎    ╎    ╎    ╎ 23    .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎  23    ...broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎   2     ...broadcast.jl:962; copyto!
#     ╎    ╎    ╎    ╎    2     ...ractarray.jl:98; axes
#    2╎    ╎    ╎    ╎     2     @Base/array.jl:150; size
#     ╎    ╎    ╎    ╎   4     ...broadcast.jl:970; copyto!
#     ╎    ╎    ╎    ╎    4     ...roadcast.jl:953; preprocess
#     ╎    ╎    ╎    ╎     4     ...roadcast.jl:956; preprocess_args
#     ╎    ╎    ╎    ╎    ╎ 2     ...roadcast.jl:954; preprocess
#     ╎    ╎    ╎    ╎    ╎  2     ...oadcast.jl:650; extrude
#     ╎    ╎    ╎    ╎    ╎   2     ...oadcast.jl:599; newindexer
#     ╎    ╎    ╎    ╎    ╎    2     ...adcast.jl:600; shapeindexer
#     ╎    ╎    ╎    ╎    ╎     2     ...adcast.jl:605; _newindexer
#     ╎    ╎    ╎    ╎    ╎    ╎ 2     ...rators.jl:269; !=
#    2╎    ╎    ╎    ╎    ╎    ╎  2     ...motion.jl:499; ==
#     ╎    ╎    ╎    ╎    ╎ 2     ...roadcast.jl:956; preprocess_args
#     ╎    ╎    ╎    ╎    ╎  2     ...oadcast.jl:956; preprocess_args
#     ╎    ╎    ╎    ╎    ╎   2     ...oadcast.jl:956; preprocess_args
#     ╎    ╎    ╎    ╎    ╎    2     ...adcast.jl:957; preprocess_args
#     ╎    ╎    ╎    ╎    ╎     2     ...adcast.jl:954; preprocess
#     ╎    ╎    ╎    ╎    ╎    ╎ 2     ...adcast.jl:650; extrude
#     ╎    ╎    ╎    ╎    ╎    ╎  2     ...adcast.jl:599; newindexer
#     ╎    ╎    ╎    ╎    ╎    ╎   2     ...adcast.jl:600; shapeindexer
#     ╎    ╎    ╎    ╎    ╎    ╎    2     ...adcast.jl:604; _newindexer
#     ╎    ╎    ╎    ╎    ╎    ╎     2     ...adcast.jl:605; _newindexer
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎ 2     ...rators.jl:269; !=
#    2╎    ╎    ╎    ╎    ╎    ╎    ╎  2     ...motion.jl:499; ==
#     ╎    ╎    ╎    ╎   17    ...broadcast.jl:973; copyto!
#     ╎    ╎    ╎    ╎    15    .../simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎     15    ...roadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎    ╎ 2     ...roadcast.jl:610; getindex
#     ╎    ╎    ╎    ╎    ╎  2     ...oadcast.jl:656; _broadcast_getindex
#     ╎    ╎    ╎    ╎    ╎   2     ...oadcast.jl:683; _broadcast_getin...
#     ╎    ╎    ╎    ╎    ╎    2     ...rators.jl:578; +
#     ╎    ╎    ╎    ╎    ╎     2     ...rators.jl:536; afoldl
#    2╎    ╎    ╎    ╎    ╎    ╎ 2     .../float.jl:408; +
#     ╎    ╎    ╎    ╎    ╎ 13    ...ensional.jl:670; setindex!
#   13╎    ╎    ╎    ╎    ╎  13    ...e/array.jl:971; setindex!
#     ╎    ╎    ╎    ╎    2     .../simdloop.jl:78; macro expansion
#    2╎    ╎    ╎    ╎     2     @Base/int.jl:87; +
#     ╎    ╎    ╎    2     .../broadcast.jl:863; broadcast_preserving_z...
#     ╎    ╎    ╎     2     .../broadcast.jl:222; axes
#     ╎    ╎    ╎    ╎ 2     .../broadcast.jl:224; _axes
#     ╎    ╎    ╎    ╎  2     ...broadcast.jl:511; combine_axes
#     ╎    ╎    ╎    ╎   2     ...broadcast.jl:511; combine_axes
#     ╎    ╎    ╎    ╎    2     ...roadcast.jl:511; combine_axes
#     ╎    ╎    ╎    ╎     2     ...roadcast.jl:512; combine_axes
#     ╎    ╎    ╎    ╎    ╎ 2     ...roadcast.jl:517; broadcast_shape
#     ╎    ╎    ╎    ╎    ╎  2     ...oadcast.jl:523; _bcs
#    2╎    ╎    ╎    ╎    ╎   2     ...oadcast.jl:529; _bcs1
#     ╎    ╎     8     ...longitudinal.jl:261; get_Pinv(qc_model::GLMCo...
#     ╎    ╎    ╎ 8     ...longitudinal.jl:283; get_Hθθ
#     ╎    ╎    ╎  8     ...tion/GLM_VC.jl:274; loglikelihood!(gcm::GLM...
#     ╎    ╎    ╎   8     ...e/broadcast.jl:881; materialize!
#     ╎    ╎    ╎    8     .../broadcast.jl:884; materialize!
#     ╎    ╎    ╎     6     .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎ 1     .../broadcast.jl:970; copyto!
#     ╎    ╎    ╎    ╎  1     ...broadcast.jl:953; preprocess
#     ╎    ╎    ╎    ╎   1     ...broadcast.jl:956; preprocess_args
#     ╎    ╎    ╎    ╎    1     ...roadcast.jl:957; preprocess_args
#     ╎    ╎    ╎    ╎     1     ...roadcast.jl:954; preprocess
#     ╎    ╎    ╎    ╎    ╎ 1     ...roadcast.jl:650; extrude
#     ╎    ╎    ╎    ╎    ╎  1     ...oadcast.jl:599; newindexer
#     ╎    ╎    ╎    ╎    ╎   1     ...oadcast.jl:600; shapeindexer
#     ╎    ╎    ╎    ╎    ╎    1     ...adcast.jl:604; _newindexer
#     ╎    ╎    ╎    ╎    ╎     1     ...adcast.jl:605; _newindexer
#     ╎    ╎    ╎    ╎    ╎    ╎ 1     ...rators.jl:269; !=
#    1╎    ╎    ╎    ╎    ╎    ╎  1     ...motion.jl:499; ==
#     ╎    ╎    ╎    ╎ 5     .../broadcast.jl:973; copyto!
#     ╎    ╎    ╎    ╎  5     ...e/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎   5     ...broadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎    2     ...roadcast.jl:610; getindex
#     ╎    ╎    ╎    ╎     2     ...roadcast.jl:656; _broadcast_getindex
#     ╎    ╎    ╎    ╎    ╎ 2     ...roadcast.jl:683; _broadcast_getinde...
#    2╎    ╎    ╎    ╎    ╎  2     ...e/float.jl:408; +
#     ╎    ╎    ╎    ╎    3     ...ensional.jl:670; setindex!
#    3╎    ╎    ╎    ╎     3     @Base/array.jl:971; setindex!
#     ╎    ╎    ╎     2     .../broadcast.jl:297; instantiate
#     ╎    ╎    ╎    ╎ 2     .../broadcast.jl:560; check_broadcast_axes
#     ╎    ╎    ╎    ╎  2     ...broadcast.jl:556; check_broadcast_axes
#     ╎    ╎    ╎    ╎   2     ...ractarray.jl:98; axes
#    2╎    ╎    ╎    ╎    2     @Base/array.jl:150; size
#    2╎    ╎     30    ...longitudinal.jl:262; get_Pinv(qc_model::GLMCo...
#     ╎    ╎    ╎ 6     ...longitudinal.jl:306; get_Hβθ(qc_model::GLMCop...
#     ╎    ╎    ╎  6     @Base/array.jl:792; collect(itr::Base.Gener...
#     ╎    ╎    ╎   6     @Base/array.jl:818; collect_to_with_first!
#     ╎    ╎    ╎    6     @Base/array.jl:840; collect_to!
#    2╎    ╎    ╎     2     .../generator.jl:0; iterate
#     ╎    ╎    ╎     4     .../generator.jl:47; iterate
#     ╎    ╎    ╎    ╎ 4     .../generator.jl:0; #126
#     ╎    ╎    ╎    ╎  4     ...rc/matmul.jl:1152; *(tu::Adjoint{Float...
#     ╎    ╎    ╎    ╎   4     ...rc/matmul.jl:119; *
#     ╎    ╎    ╎    ╎    4     ...c/matmul.jl:101; *
#     ╎    ╎    ╎    ╎     2     ...actarray.jl:838; similar
#     ╎    ╎    ╎    ╎    ╎ 2     @Base/array.jl:374; similar
#     ╎    ╎    ╎    ╎    ╎  2     @Base/boot.jl:486; Array
#    2╎    ╎    ╎    ╎    ╎   2     @Base/boot.jl:477; Array
#     ╎    ╎    ╎    ╎     2     ...c/matmul.jl:276; mul!
#     ╎    ╎    ╎    ╎    ╎ 2     ...c/matmul.jl:109; mul!
#     ╎    ╎    ╎    ╎    ╎  2     ...c/matmul.jl:93; mul!
#     ╎    ╎    ╎    ╎    ╎   2     .../matmul.jl:503; gemv!(y::Vector{...
#    2╎    ╎    ╎    ╎    ╎    2     ...c/blas.jl:667; gemv!(trans::Cha...
#     ╎    ╎    ╎ 2     ...longitudinal.jl:307; get_Hβθ(qc_model::GLMCop...
#     ╎    ╎    ╎  2     @Base/array.jl:792; collect(itr::Base.Gener...
#     ╎    ╎    ╎   2     @Base/array.jl:818; collect_to_with_first!
#     ╎    ╎    ╎    2     @Base/array.jl:840; collect_to!(dest::Vect...
#     ╎    ╎    ╎     2     .../generator.jl:47; iterate
#     ╎    ╎    ╎    ╎ 2     none:0; #127
#     ╎    ╎    ╎    ╎  2     ...rc/matmul.jl:1150; *
#     ╎    ╎    ╎    ╎   2     ...rc/matmul.jl:101; *
#     ╎    ╎    ╎    ╎    2     ...actarray.jl:838; similar
#     ╎    ╎    ╎    ╎     2     @Base/array.jl:374; similar
#     ╎    ╎    ╎    ╎    ╎ 2     @Base/boot.jl:486; Array
#    2╎    ╎    ╎    ╎    ╎  2     @Base/boot.jl:477; Array
#   10╎    ╎    ╎ 20    ...longitudinal.jl:308; get_Hβθ(qc_model::GLMCop...
#     ╎    ╎    ╎  2     ...e/arraymath.jl:8; -(A::Matrix{Float64}, ...
#     ╎    ╎    ╎   2     ...e/broadcast.jl:862; broadcast_preserving_z...
#     ╎    ╎    ╎    2     .../broadcast.jl:873; materialize
#     ╎    ╎    ╎     2     .../broadcast.jl:294; instantiate
#     ╎    ╎    ╎    ╎ 2     .../broadcast.jl:512; combine_axes
#     ╎    ╎    ╎    ╎  2     ...broadcast.jl:517; broadcast_shape
#     ╎    ╎    ╎    ╎   2     ...broadcast.jl:523; _bcs
#     ╎    ╎    ╎    ╎    2     ...roadcast.jl:523; _bcs
#    2╎    ╎    ╎    ╎     2     ...roadcast.jl:529; _bcs1
#    2╎    ╎    ╎  2     ...e/broadcast.jl:1313; broadcasted(::Function...
#     ╎    ╎    ╎  2     ...e/broadcast.jl:1317; broadcasted
#    2╎    ╎    ╎   2     .../broadcast.jl:1319; broadcasted
#     ╎    ╎    ╎  2     ...e/broadcast.jl:1317; broadcasted(::Function...
#    2╎    ╎    ╎   2     .../broadcast.jl:1319; broadcasted
#     ╎    ╎    ╎  2     ...rc/adjtrans.jl:439; *(u::Vector{Float64}, ...
#     ╎    ╎    ╎   2     ...e/broadcast.jl:811; broadcast(::typeof(*),...
#     ╎    ╎    ╎    2     .../broadcast.jl:873; materialize
#     ╎    ╎    ╎     2     .../broadcast.jl:898; copy
#     ╎    ╎    ╎    ╎ 2     .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎  2     ...broadcast.jl:973; copyto!
#    2╎    ╎    ╎    ╎   2     .../simdloop.jl:75; macro expansion
#     ╎    ╎    2543  ...longitudinal.jl:89; GWASCopulaVCModel(qc_mode...
#     ╎    ╎     2543  ...rogressMeter.jl:1010; macro expansion
#    2╎    ╎    ╎ 2     ...longitudinal.jl:0; macro expansion
#     ╎    ╎    ╎ 14    ...longitudinal.jl:91; macro expansion
#     ╎    ╎    ╎  14    ...rc/snparray.jl:327; copyto!
#     ╎    ╎    ╎   14    ...rc/snparray.jl:348; copyto!(v::Vector{Floa...
#     ╎    ╎    ╎    2     @Base/simdloop.jl:75; macro expansion
#    2╎    ╎    ╎     2     @Base/int.jl:83; <
#     ╎    ╎    ╎    12    @Base/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎     6     ...c/snparray.jl:349; macro expansion
#    6╎    ╎    ╎    ╎ 6     ...c/snparray.jl:305; convert
#     ╎    ╎    ╎     6     ...c/snparray.jl:350; macro expansion
#    6╎    ╎    ╎    ╎ 6     @Base/array.jl:971; setindex!
#     ╎    ╎    ╎ 2     ...longitudinal.jl:100; macro expansion
#     ╎    ╎    ╎  2     @Base/array.jl:350; fill!
#    2╎    ╎    ╎   2     @Base/range.jl:891; iterate
#     ╎    ╎    ╎ 28    ...longitudinal.jl:104; macro expansion
#    2╎    ╎    ╎  2     ...ongitudinal.jl:0; get_∇resγ!(∇resγ::SubAr...
#     ╎    ╎    ╎  18    ...ongitudinal.jl:233; get_∇resγ!(∇resγ::SubAr...
#    4╎    ╎    ╎   4     .../essentials.jl:13; getindex
#     ╎    ╎    ╎   4     @Base/subarray.jl:318; getindex
#     ╎    ╎    ╎    4     ...tractarray.jl:709; checkbounds
#     ╎    ╎    ╎     4     ...tractarray.jl:694; checkbounds
#     ╎    ╎    ╎    ╎ 4     ...tractarray.jl:768; checkindex
#    4╎    ╎    ╎    ╎  4     @Base/int.jl:488; <=
#     ╎    ╎    ╎   8     @Base/subarray.jl:351; setindex!
#    8╎    ╎    ╎    8     @Base/array.jl:969; setindex!
#     ╎    ╎    ╎   2     ...s/utilities.jl:209; update_∇res_ij
#    2╎    ╎    ╎    2     @Base/float.jl:410; *
#     ╎    ╎    ╎  4     ...ongitudinal.jl:234; get_∇resγ!(∇resγ::SubAr...
#     ╎    ╎    ╎   4     @Base/range.jl:891; iterate
#    4╎    ╎    ╎    4     .../promotion.jl:499; ==
#    4╎    ╎    ╎  4     ...ongitudinal.jl:235; get_∇resγ!(∇resγ::SubAr...
#    2╎    ╎    ╎ 296   ...longitudinal.jl:105; macro expansion
#    4╎    ╎    ╎  4     ...ongitudinal.jl:251; get_∇resβ!(∇resβ::SubAr...
#    2╎    ╎    ╎  290   ...ongitudinal.jl:252; get_∇resβ!(∇resβ::SubAr...
#    2╎    ╎    ╎   2     @Base/Base.jl:37; getproperty
#     ╎    ╎    ╎   286   ...e/broadcast.jl:881; materialize!
#     ╎    ╎    ╎    286   .../broadcast.jl:884; materialize!
#     ╎    ╎    ╎     286   .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎ 286   .../broadcast.jl:967; copyto!
#     ╎    ╎    ╎    ╎  286   ...ractarray.jl:1071; copyto!
#   22╎    ╎    ╎    ╎   22    ...actarray.jl:0; copyto_unaliased!(d...
#     ╎    ╎    ╎    ╎   4     ...actarray.jl:1082; copyto_unaliased!(d...
#     ╎    ╎    ╎    ╎    4     .../indices.jl:486; LinearIndices
#     ╎    ╎    ╎    ╎     4     ...actarray.jl:98; axes
#    4╎    ╎    ╎    ╎    ╎ 4     @Base/array.jl:150; size
#   12╎    ╎    ╎    ╎   12    ...actarray.jl:1111; copyto_unaliased!(d...
#     ╎    ╎    ╎    ╎   21    ...actarray.jl:1112; copyto_unaliased!(d...
#     ╎    ╎    ╎    ╎    21    ...actarray.jl:1397; setindex!
#     ╎    ╎    ╎    ╎     21    ...actarray.jl:1427; _setindex!
#     ╎    ╎    ╎    ╎    ╎ 21    ...subarray.jl:327; setindex!
#   21╎    ╎    ╎    ╎    ╎  21    ...e/array.jl:971; setindex!
#     ╎    ╎    ╎    ╎   100   ...actarray.jl:1113; copyto_unaliased!(d...
#     ╎    ╎    ╎    ╎    100   ...ensional.jl:402; iterate
#   66╎    ╎    ╎    ╎     66    ...ensional.jl:0; __inc
#   16╎    ╎    ╎    ╎     16    ...ensional.jl:427; __inc
#     ╎    ╎    ╎    ╎     18    ...ensional.jl:430; __inc
#     ╎    ╎    ╎    ╎    ╎ 2     ...ensional.jl:420; __inc
#    2╎    ╎    ╎    ╎    ╎  2     @Base/int.jl:87; +
#   16╎    ╎    ╎    ╎    ╎ 16    ...ensional.jl:421; __inc
#     ╎    ╎    ╎    ╎   7     ...actarray.jl:1114; copyto_unaliased!(d...
#     ╎    ╎    ╎    ╎    7     @Base/array.jl:893; iterate
#     ╎    ╎    ╎    ╎     7     @Base/int.jl:494; <
#    7╎    ╎    ╎    ╎    ╎ 7     @Base/int.jl:487; <
#   32╎    ╎    ╎    ╎   32    @Base/array.jl:0; copyto_unaliased!(d...
#   88╎    ╎    ╎    ╎   88    ...ensional.jl:0; copyto_unaliased!(d...
#     ╎    ╎    ╎ 18    ...longitudinal.jl:108; macro expansion
#     ╎    ╎    ╎  18    ...e/broadcast.jl:881; materialize!
#     ╎    ╎    ╎   18    ...e/broadcast.jl:884; materialize!
#     ╎    ╎    ╎    18    .../broadcast.jl:934; copyto!
#     ╎    ╎    ╎     8     ...imensional.jl:1086; fill!
#     ╎    ╎    ╎    ╎ 8     ...ractarray.jl:1397; setindex!
#     ╎    ╎    ╎    ╎  8     ...ractarray.jl:1427; _setindex!
#     ╎    ╎    ╎    ╎   8     .../subarray.jl:327; setindex!
#    8╎    ╎    ╎    ╎    8     @Base/array.jl:971; setindex!
#    2╎    ╎    ╎     10    ...imensional.jl:1087; fill!
#     ╎    ╎    ╎    ╎ 8     ...imensional.jl:402; iterate
#    8╎    ╎    ╎    ╎  8     ...imensional.jl:0; __inc
#    6╎    ╎    ╎ 84    ...longitudinal.jl:110; macro expansion
#    4╎    ╎    ╎  4     .../essentials.jl:13; getindex
#   28╎    ╎    ╎  28    ...ra/src/blas.jl:518; axpy!(alpha::Float64, x...
#     ╎    ╎    ╎  6     ...ra/src/blas.jl:519; axpy!(alpha::Float64, x...
#     ╎    ╎    ╎   4     ...stractarray.jl:308; length
#     ╎    ╎    ╎    4     @Base/subarray.jl:63; size
#     ╎    ╎    ╎     4     ...e/subarray.jl:455; axes
#     ╎    ╎    ╎    ╎ 4     ...e/subarray.jl:460; _indices_sub
#     ╎    ╎    ╎    ╎  4     .../subarray.jl:460; _indices_sub
#     ╎    ╎    ╎    ╎   4     @Base/range.jl:696; axes
#     ╎    ╎    ╎    ╎    4     @Base/range.jl:751; length
#    4╎    ╎    ╎    ╎     4     @Base/int.jl:86; -
#    2╎    ╎    ╎   2     .../essentials.jl:10; length
#    4╎    ╎    ╎  16    ...ra/src/blas.jl:522; axpy!(alpha::Float64, x...
#    2╎    ╎    ╎   2     ...ra/src/blas.jl:509; axpy!(n::Int64, alpha:...
#    6╎    ╎    ╎   6     ...ra/src/blas.jl:510; axpy!(n::Int64, alpha:...
#    2╎    ╎    ╎   2     ...ra/src/blas.jl:0; vec_pointer_stride
#     ╎    ╎    ╎   2     ...ra/src/blas.jl:178; vec_pointer_stride
#     ╎    ╎    ╎    2     ...a/src/blas.jl:185; checkedstride
#     ╎    ╎    ╎     2     ...e/subarray.jl:360; strides
#     ╎    ╎    ╎    ╎ 2     ...rpretarray.jl:173; strides
#    2╎    ╎    ╎    ╎  2     @Base/array.jl:150; size
#   24╎    ╎    ╎  24    ...ra/src/blas.jl:524; axpy!(alpha::Float64, x...
#     ╎    ╎    ╎ 8     ...longitudinal.jl:113; macro expansion
#     ╎    ╎    ╎  8     ...a/src/matmul.jl:14; dot
#     ╎    ╎    ╎   8     ...ra/src/blas.jl:395; dot
#    8╎    ╎    ╎    8     ...a/src/blas.jl:345; dot
#     ╎    ╎    ╎ 2     ...longitudinal.jl:115; macro expansion
#    2╎    ╎    ╎  2     @Base/array.jl:969; setindex!
#     ╎    ╎    ╎ 4     ...longitudinal.jl:116; macro expansion
#    4╎    ╎    ╎  4     @Base/array.jl:969; setindex!
#     ╎    ╎    ╎ 1423  ...longitudinal.jl:118; macro expansion
#     ╎    ╎    ╎  149   @Base/timing.jl:392; macro expansion
#  149╎    ╎    ╎   149   @Base/Base.jl:94; time_ns
#     ╎    ╎    ╎  1236  @Base/timing.jl:393; macro expansion
#    2╎    ╎    ╎   2     .../essentials.jl:0; update_W!
#    2╎    ╎    ╎   1104  ...ongitudinal.jl:143; update_W!
#    2╎    ╎    ╎    2     ...e/simdloop.jl:0; get_Hβγ_i!(W::SubArray...
#     ╎    ╎    ╎    2     ...ngitudinal.jl:391; get_Hβγ_i!(W::SubArray...
#     ╎    ╎    ╎     2     ...tractarray.jl:308; length
#     ╎    ╎    ╎    ╎ 2     ...e/subarray.jl:63; size
#     ╎    ╎    ╎    ╎  2     .../subarray.jl:455; axes
#     ╎    ╎    ╎    ╎   2     .../subarray.jl:460; _indices_sub
#     ╎    ╎    ╎    ╎    2     @Base/range.jl:696; axes
#     ╎    ╎    ╎    ╎     2     @Base/range.jl:748; length
#     ╎    ╎    ╎    ╎    ╎ 2     @Base/range.jl:824; first
#    2╎    ╎    ╎    ╎    ╎  2     @Base/Base.jl:37; getproperty
#     ╎    ╎    ╎    15    ...ngitudinal.jl:399; get_Hβγ_i!(W::SubArray...
#     ╎    ╎    ╎     15    .../broadcast.jl:881; materialize!
#     ╎    ╎    ╎    ╎ 15    .../broadcast.jl:884; materialize!
#     ╎    ╎    ╎    ╎  15    ...broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎   12    ...broadcast.jl:970; copyto!
#     ╎    ╎    ╎    ╎    12    ...roadcast.jl:953; preprocess
#     ╎    ╎    ╎    ╎     12    ...roadcast.jl:956; preprocess_args
#     ╎    ╎    ╎    ╎    ╎ 12    ...roadcast.jl:957; preprocess_args
#     ╎    ╎    ╎    ╎    ╎  12    ...oadcast.jl:954; preprocess
#     ╎    ╎    ╎    ╎    ╎   12    ...oadcast.jl:947; broadcast_unalias
#    4╎    ╎    ╎    ╎    ╎    12    ...tarray.jl:1480; unalias
#    8╎    ╎    ╎    ╎    ╎     8     ...nsional.jl:0; mightalias(A::Su...
#     ╎    ╎    ╎    ╎   3     ...broadcast.jl:973; copyto!
#    3╎    ╎    ╎    ╎    3     .../simdloop.jl:75; macro expansion
#     ╎    ╎    ╎    45    ...ngitudinal.jl:400; get_Hβγ_i!(W::SubArray...
#     ╎    ╎    ╎     45    ...src/matmul.jl:276; mul!
#    8╎    ╎    ╎    ╎ 45    ...src/matmul.jl:93; mul!
#    3╎    ╎    ╎    ╎  3     ...rc/matmul.jl:490; gemv!(y::Vector{Floa...
#    4╎    ╎    ╎    ╎  34    ...rc/matmul.jl:503; gemv!(y::Vector{Floa...
#    4╎    ╎    ╎    ╎   4     .../src/blas.jl:643; gemv!(trans::Char, ...
#   26╎    ╎    ╎    ╎   26    .../src/blas.jl:667; gemv!(trans::Char, ...
#     ╎    ╎    ╎    10    ...ngitudinal.jl:401; get_Hβγ_i!(W::SubArray...
#     ╎    ╎    ╎     10    .../broadcast.jl:881; materialize!
#     ╎    ╎    ╎    ╎ 10    .../broadcast.jl:884; materialize!
#     ╎    ╎    ╎    ╎  8     ...broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎   8     ...broadcast.jl:973; copyto!
#     ╎    ╎    ╎    ╎    8     .../simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎     8     ...roadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎    ╎ 8     ...subarray.jl:351; setindex!
#    8╎    ╎    ╎    ╎    ╎  8     ...e/array.jl:969; setindex!
#     ╎    ╎    ╎    ╎  2     ...broadcast.jl:297; instantiate
#     ╎    ╎    ╎    ╎   2     ...broadcast.jl:560; check_broadcast_axes
#     ╎    ╎    ╎    ╎    2     ...roadcast.jl:556; check_broadcast_axes
#     ╎    ╎    ╎    ╎     2     ...actarray.jl:98; axes
#    2╎    ╎    ╎    ╎    ╎ 2     @Base/array.jl:149; size
#     ╎    ╎    ╎    34    ...ngitudinal.jl:403; get_Hβγ_i!(W::SubArray...
#     ╎    ╎    ╎     34    ...src/matmul.jl:276; mul!
#    2╎    ╎    ╎    ╎ 34    ...src/matmul.jl:65; mul!
#     ╎    ╎    ╎    ╎  2     ...rc/matmul.jl:495; gemv!(y::SubArray{Fl...
#     ╎    ╎    ╎    ╎   2     ...operators.jl:269; !=
#    2╎    ╎    ╎    ╎    2     ...romotion.jl:499; ==
#     ╎    ╎    ╎    ╎  2     ...rc/matmul.jl:499; gemv!(y::SubArray{Fl...
#     ╎    ╎    ╎    ╎   2     ...promotion.jl:387; promote
#     ╎    ╎    ╎    ╎    2     ...romotion.jl:365; _promote
#     ╎    ╎    ╎    ╎     2     @Base/number.jl:7; convert
#    2╎    ╎    ╎    ╎    ╎ 2     @Base/float.jl:0; Float64
#   14╎    ╎    ╎    ╎  28    ...rc/matmul.jl:503; gemv!(y::SubArray{Fl...
#    4╎    ╎    ╎    ╎   4     .../src/blas.jl:643; gemv!(trans::Char, ...
#     ╎    ╎    ╎    ╎   2     .../src/blas.jl:647; gemv!(trans::Char, ...
#     ╎    ╎    ╎    ╎    2     ...ractarray.jl:42; size
#     ╎    ╎    ╎    ╎     2     ...subarray.jl:63; size
#     ╎    ╎    ╎    ╎    ╎ 2     ...subarray.jl:455; axes
#     ╎    ╎    ╎    ╎    ╎  2     ...ubarray.jl:460; _indices_sub
#     ╎    ╎    ╎    ╎    ╎   2     ...e/range.jl:696; axes
#     ╎    ╎    ╎    ╎    ╎    2     .../range.jl:748; length
#     ╎    ╎    ╎    ╎    ╎     2     .../range.jl:824; first
#    2╎    ╎    ╎    ╎    ╎    ╎ 2     ...e/Base.jl:37; getproperty
#    2╎    ╎    ╎    ╎   2     .../src/blas.jl:648; gemv!(trans::Char, ...
#    6╎    ╎    ╎    ╎   6     .../src/blas.jl:667; gemv!(trans::Char, ...
#     ╎    ╎    ╎    26    ...ngitudinal.jl:405; get_Hβγ_i!(W::SubArray...
#     ╎    ╎    ╎     26    ...src/matmul.jl:276; mul!
#    4╎    ╎    ╎    ╎ 26    ...src/matmul.jl:93; mul!
#     ╎    ╎    ╎    ╎  22    ...rc/matmul.jl:503; gemv!(y::Vector{Floa...
#    4╎    ╎    ╎    ╎   4     .../src/blas.jl:0; gemv!(trans::Char, ...
#    6╎    ╎    ╎    ╎   6     .../src/blas.jl:643; gemv!(trans::Char, ...
#   12╎    ╎    ╎    ╎   12    .../src/blas.jl:667; gemv!(trans::Char, ...
#     ╎    ╎    ╎    14    ...ngitudinal.jl:406; get_Hβγ_i!(W::SubArray...
#     ╎    ╎    ╎     14    .../broadcast.jl:881; materialize!
#     ╎    ╎    ╎    ╎ 14    .../broadcast.jl:884; materialize!
#     ╎    ╎    ╎    ╎  12    ...broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎   2     ...broadcast.jl:970; copyto!
#     ╎    ╎    ╎    ╎    2     ...roadcast.jl:953; preprocess
#     ╎    ╎    ╎    ╎     2     ...roadcast.jl:956; preprocess_args
#     ╎    ╎    ╎    ╎    ╎ 2     ...roadcast.jl:954; preprocess
#     ╎    ╎    ╎    ╎    ╎  2     ...oadcast.jl:650; extrude
#     ╎    ╎    ╎    ╎    ╎   2     ...oadcast.jl:599; newindexer
#     ╎    ╎    ╎    ╎    ╎    2     ...adcast.jl:600; shapeindexer
#     ╎    ╎    ╎    ╎    ╎     2     ...adcast.jl:605; _newindexer
#     ╎    ╎    ╎    ╎    ╎    ╎ 2     ...rators.jl:269; !=
#    2╎    ╎    ╎    ╎    ╎    ╎  2     ...motion.jl:499; ==
#     ╎    ╎    ╎    ╎   10    ...broadcast.jl:973; copyto!
#    2╎    ╎    ╎    ╎    2     .../simdloop.jl:72; macro expansion
#     ╎    ╎    ╎    ╎    2     .../simdloop.jl:76; macro expansion
#     ╎    ╎    ╎    ╎     2     ...simdloop.jl:54; simd_index
#    2╎    ╎    ╎    ╎    ╎ 2     @Base/int.jl:87; +
#     ╎    ╎    ╎    ╎    6     .../simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎     6     ...roadcast.jl:974; macro expansion
#     ╎    ╎    ╎    ╎    ╎ 6     ...subarray.jl:351; setindex!
#    6╎    ╎    ╎    ╎    ╎  6     ...e/array.jl:969; setindex!
#     ╎    ╎    ╎    ╎  2     .../subarray.jl:455; axes
#     ╎    ╎    ╎    ╎   2     .../subarray.jl:460; _indices_sub
#    2╎    ╎    ╎    ╎    2     @Base/range.jl:696; axes
#     ╎    ╎    ╎    25    ...ngitudinal.jl:408; get_Hβγ_i!(W::SubArray...
#     ╎    ╎    ╎     25    ...src/matmul.jl:276; mul!
#    2╎    ╎    ╎    ╎ 25    ...src/matmul.jl:65; mul!
#    8╎    ╎    ╎    ╎  8     ...rc/matmul.jl:490; gemv!(y::SubArray{Fl...
#     ╎    ╎    ╎    ╎  4     ...rc/matmul.jl:497; gemv!(y::SubArray{Fl...
#    4╎    ╎    ╎    ╎   4     ...promotion.jl:499; ==
# ...
#     ╎    ╎    ╎     32    .../utilities.jl:54; ∇²μ_j
#     ╎    ╎    ╎    ╎ 32    .../utilities.jl:117; mueta2
#    4╎    ╎    ╎    ╎  4     @Base/float.jl:406; -
#    4╎    ╎    ╎    ╎  28    ...ecial/exp.jl:325; exp(x::Float64)
#     ╎    ╎    ╎    ╎   8     ...ecial/exp.jl:215; exp_impl
#     ╎    ╎    ╎    ╎    8     ...cial/exp.jl:181; table_unpack
#    8╎    ╎    ╎    ╎     8     @Base/int.jl:347; &
#     ╎    ╎    ╎    ╎   4     ...ecial/exp.jl:216; exp_impl
#    2╎    ╎    ╎    ╎    2     @Base/float.jl:408; +
#     ╎    ╎    ╎    ╎    2     ...cial/exp.jl:78; expm1b_kernel
#     ╎    ╎    ╎    ╎     2     @Base/math.jl:177; evalpoly
#     ╎    ╎    ╎    ╎    ╎ 2     @Base/math.jl:178; macro expansion
#    2╎    ╎    ╎    ╎    ╎  2     ...e/float.jl:413; muladd
#     ╎    ╎    ╎    ╎   12    ...ecial/exp.jl:218; exp_impl
#   12╎    ╎    ╎    ╎    12    @Base/float.jl:609; abs
#     ╎    ╎    ╎     4     .../utilities.jl:55; ∇²μ_j
#     ╎    ╎    ╎    ╎ 4     .../operators.jl:578; *
#    4╎    ╎    ╎    ╎  4     @Base/float.jl:410; *
#     ╎    ╎    ╎    4     .../utilities.jl:136; dβdβ_res_ij(dist::Bern...
#    2╎    ╎    ╎     2     @Base/float.jl:410; *
#     ╎    ╎    ╎     2     ...e/intfuncs.jl:320; literal_pow
#     ╎    ╎    ╎    ╎ 2     .../operators.jl:578; *
#    2╎    ╎    ╎    ╎  2     @Base/float.jl:410; *
#   35╎    ╎    ╎    214   .../utilities.jl:137; dβdβ_res_ij(dist::Bern...
#    2╎    ╎    ╎     2     .../utilities.jl:11; ∇²σ²_j(d::Bernoulli{Fl...
#     ╎    ╎    ╎     177   .../utilities.jl:13; ∇²σ²_j(d::Bernoulli{Fl...
#     ╎    ╎    ╎    ╎ 6     .../promotion.jl:411; *
#    6╎    ╎    ╎    ╎  6     @Base/float.jl:410; *
#   22╎    ╎    ╎    ╎ 131   .../utilities.jl:117; mueta2
#    4╎    ╎    ╎    ╎  4     @Base/float.jl:406; -
#   10╎    ╎    ╎    ╎  105   ...ecial/exp.jl:325; exp(x::Float64)
#     ╎    ╎    ╎    ╎   8     ...ecial/exp.jl:210; exp_impl
#    8╎    ╎    ╎    ╎    8     ...sentials.jl:513; reinterpret
#     ╎    ╎    ╎    ╎   4     ...ecial/exp.jl:211; exp_impl
#    4╎    ╎    ╎    ╎    4     @Base/float.jl:409; -
#     ╎    ╎    ╎    ╎   2     ...ecial/exp.jl:213; exp_impl
#    2╎    ╎    ╎    ╎    2     @Base/float.jl:413; muladd
#     ╎    ╎    ╎    ╎   69    ...ecial/exp.jl:215; exp_impl
#     ╎    ╎    ╎    ╎    59    ...cial/exp.jl:181; table_unpack
#   53╎    ╎    ╎    ╎     53    ...sentials.jl:513; reinterpret
#    6╎    ╎    ╎    ╎     6     @Base/int.jl:347; &
#     ╎    ╎    ╎    ╎    10    ...cial/exp.jl:182; table_unpack
#   10╎    ╎    ╎    ╎     10    ...sentials.jl:513; reinterpret
#     ╎    ╎    ╎    ╎   4     ...ecial/exp.jl:216; exp_impl
#     ╎    ╎    ╎    ╎    4     ...ecial/exp.jl:78; expm1b_kernel
#     ╎    ╎    ╎    ╎     4     @Base/math.jl:177; evalpoly
#     ╎    ╎    ╎    ╎    ╎ 4     @Base/math.jl:178; macro expansion
#    4╎    ╎    ╎    ╎    ╎  4     ...e/float.jl:413; muladd
#     ╎    ╎    ╎    ╎   8     ...ecial/exp.jl:218; exp_impl
#    8╎    ╎    ╎    ╎    8     @Base/float.jl:609; abs
#    6╎    ╎    ╎    ╎ 40    ...c/glmtools.jl:263; mueta
#    4╎    ╎    ╎    ╎  34    ...ecial/exp.jl:325; exp(x::Float64)
#     ╎    ╎    ╎    ╎   6     ...ecial/exp.jl:215; exp_impl
#     ╎    ╎    ╎    ╎    4     ...cial/exp.jl:181; table_unpack
#    2╎    ╎    ╎    ╎     2     ...sentials.jl:513; reinterpret
#    2╎    ╎    ╎    ╎     2     @Base/int.jl:347; &
#     ╎    ╎    ╎    ╎    2     ...cial/exp.jl:182; table_unpack
#    2╎    ╎    ╎    ╎     2     ...sentials.jl:513; reinterpret
#     ╎    ╎    ╎    ╎   4     ...ecial/exp.jl:216; exp_impl
#     ╎    ╎    ╎    ╎    4     ...ecial/exp.jl:78; expm1b_kernel
#     ╎    ╎    ╎    ╎     4     @Base/math.jl:177; evalpoly
#     ╎    ╎    ╎    ╎    ╎ 4     @Base/math.jl:178; macro expansion
#    4╎    ╎    ╎    ╎    ╎  4     ...e/float.jl:413; muladd
#     ╎    ╎    ╎    ╎   20    ...ecial/exp.jl:218; exp_impl
#   20╎    ╎    ╎    ╎    20    @Base/float.jl:609; abs
#     ╎    ╎    ╎    10    .../utilities.jl:139; dβdβ_res_ij(dist::Bern...
#    2╎    ╎    ╎     2     @Base/float.jl:410; *
#     ╎    ╎    ╎     4     ...e/intfuncs.jl:319; literal_pow
#    4╎    ╎    ╎    ╎ 4     @Base/float.jl:410; *
#     ╎    ╎    ╎     2     @Base/number.jl:255; inv
#    2╎    ╎    ╎    ╎ 2     @Base/float.jl:411; /
#     ╎    ╎    ╎     2     .../operators.jl:578; *
#    2╎    ╎    ╎    ╎ 2     @Base/float.jl:410; *
#     ╎    ╎    ╎    2     .../utilities.jl:140; dβdβ_res_ij(dist::Bern...
#     ╎    ╎    ╎     2     .../operators.jl:578; +
#     ╎    ╎    ╎    ╎ 2     .../operators.jl:536; afoldl
#    2╎    ╎    ╎    ╎  2     @Base/float.jl:408; +
#     ╎    ╎    ╎   6     ...ongitudinal.jl:220; calculate_Qi(qc_model:...
#    6╎    ╎    ╎    6     @Base/range.jl:891; iterate
#     ╎    ╎    ╎  44    @Base/timing.jl:394; macro expansion
#   44╎    ╎    ╎   44    @Base/Base.jl:94; time_ns
#     ╎    ╎    ╎ 115   ...longitudinal.jl:122; macro expansion
#     ╎    ╎    ╎  4     @Base/timing.jl:392; macro expansion
#    4╎    ╎    ╎   4     @Base/Base.jl:94; time_ns
#     ╎    ╎    ╎  72    @Base/timing.jl:393; macro expansion
#    2╎    ╎    ╎   2     ...ongitudinal.jl:171; calculate_Ri(qc_model:...
#     ╎    ╎    ╎   2     ...ongitudinal.jl:176; calculate_Ri(qc_model:...
#     ╎    ╎    ╎    2     @Base/range.jl:5; Colon
#     ╎    ╎    ╎     2     @Base/range.jl:397; UnitRange
#    2╎    ╎    ╎    ╎ 2     @Base/range.jl:404; unitrange_last
#     ╎    ╎    ╎   4     ...ongitudinal.jl:178; calculate_Ri(qc_model:...
#     ╎    ╎    ╎    4     .../broadcast.jl:881; materialize!
#     ╎    ╎    ╎     4     .../broadcast.jl:884; materialize!
#     ╎    ╎    ╎    ╎ 4     .../broadcast.jl:926; copyto!
#     ╎    ╎    ╎    ╎  2     ...broadcast.jl:970; copyto!
#     ╎    ╎    ╎    ╎   2     ...broadcast.jl:953; preprocess
#     ╎    ╎    ╎    ╎    2     ...roadcast.jl:956; preprocess_args
#     ╎    ╎    ╎    ╎     2     ...roadcast.jl:957; preprocess_args
#     ╎    ╎    ╎    ╎    ╎ 2     ...roadcast.jl:953; preprocess
#     ╎    ╎    ╎    ╎    ╎  2     ...oadcast.jl:956; preprocess_args
#     ╎    ╎    ╎    ╎    ╎   2     ...oadcast.jl:957; preprocess_args
#     ╎    ╎    ╎    ╎    ╎    2     ...adcast.jl:954; preprocess
#     ╎    ╎    ╎    ╎    ╎     2     ...adcast.jl:650; extrude
#     ╎    ╎    ╎    ╎    ╎    ╎ 2     ...adcast.jl:599; newindexer
#     ╎    ╎    ╎    ╎    ╎    ╎  2     ...adcast.jl:600; shapeindexer
#     ╎    ╎    ╎    ╎    ╎    ╎   2     ...adcast.jl:605; _newindexer
#     ╎    ╎    ╎    ╎    ╎    ╎    2     ...rators.jl:269; !=
#    2╎    ╎    ╎    ╎    ╎    ╎     2     ...motion.jl:499; ==
#     ╎    ╎    ╎    ╎  2     ...broadcast.jl:973; copyto!
#    2╎    ╎    ╎    ╎   2     ...e/simdloop.jl:0; macro expansion
#     ╎    ╎    ╎   8     ...ongitudinal.jl:179; calculate_Ri(qc_model:...
#     ╎    ╎    ╎    8     .../src/matmul.jl:14; dot
#    2╎    ╎    ╎     2     ...a/src/blas.jl:392; dot(x::SubArray{Float...
#     ╎    ╎    ╎     6     ...a/src/blas.jl:395; dot(x::SubArray{Float...
#    6╎    ╎    ╎    ╎ 6     ...a/src/blas.jl:345; dot
#     ╎    ╎    ╎   48    ...ongitudinal.jl:181; calculate_Ri(qc_model:...
#     ╎    ╎    ╎    48    ...src/matmul.jl:276; mul!
#    4╎    ╎    ╎     48    ...src/matmul.jl:65; mul!
#     ╎    ╎    ╎    ╎ 2     ...src/matmul.jl:492; gemv!(y::SubArray{Flo...
#     ╎    ╎    ╎    ╎  2     ...rc/matmul.jl:725; lapack_size
#     ╎    ╎    ╎    ╎   2     ...ractarray.jl:42; size
#     ╎    ╎    ╎    ╎    2     .../subarray.jl:63; size
#    2╎    ╎    ╎    ╎     2     @Base/tuple.jl:274; map
#     ╎    ╎    ╎    ╎ 2     ...src/matmul.jl:499; gemv!(y::SubArray{Flo...
#     ╎    ╎    ╎    ╎  2     ...promotion.jl:387; promote
#     ╎    ╎    ╎    ╎   2     ...promotion.jl:365; _promote
#     ╎    ╎    ╎    ╎    2     @Base/number.jl:7; convert
#    2╎    ╎    ╎    ╎     2     @Base/float.jl:0; Float64
#   12╎    ╎    ╎    ╎ 40    ...src/matmul.jl:503; gemv!(y::SubArray{Flo...
#    6╎    ╎    ╎    ╎  6     .../src/blas.jl:643; gemv!(trans::Char, a...
#     ╎    ╎    ╎    ╎  4     .../src/blas.jl:647; gemv!(trans::Char, a...
#     ╎    ╎    ╎    ╎   4     ...ractarray.jl:42; size
#     ╎    ╎    ╎    ╎    4     .../subarray.jl:63; size
#     ╎    ╎    ╎    ╎     4     ...subarray.jl:455; axes
#     ╎    ╎    ╎    ╎    ╎ 4     ...subarray.jl:460; _indices_sub
#     ╎    ╎    ╎    ╎    ╎  4     ...e/range.jl:696; axes
#     ╎    ╎    ╎    ╎    ╎   4     ...e/range.jl:748; length
#     ╎    ╎    ╎    ╎    ╎    4     .../range.jl:824; first
#    4╎    ╎    ╎    ╎    ╎     4     ...e/Base.jl:37; getproperty
#   16╎    ╎    ╎    ╎  16    .../src/blas.jl:667; gemv!(trans::Char, a...
#    2╎    ╎    ╎    ╎  2     .../src/blas.jl:674; gemv!(trans::Char, a...
#     ╎    ╎    ╎   8     ...ongitudinal.jl:182; calculate_Ri(qc_model:...
#     ╎    ╎    ╎    8     .../src/matmul.jl:14; dot
#    2╎    ╎    ╎     2     ...a/src/blas.jl:392; dot(x::SubArray{Float...
#     ╎    ╎    ╎     4     ...a/src/blas.jl:393; dot(x::SubArray{Float...
#     ╎    ╎    ╎    ╎ 4     ...tractarray.jl:308; length
#     ╎    ╎    ╎    ╎  4     ...e/subarray.jl:63; size
#     ╎    ╎    ╎    ╎   4     .../subarray.jl:455; axes
#     ╎    ╎    ╎    ╎    4     ...subarray.jl:460; _indices_sub
#     ╎    ╎    ╎    ╎     4     @Base/range.jl:696; axes
#     ╎    ╎    ╎    ╎    ╎ 2     @Base/range.jl:748; length
#     ╎    ╎    ╎    ╎    ╎  2     ...e/range.jl:824; first
#    2╎    ╎    ╎    ╎    ╎   2     @Base/Base.jl:37; getproperty
#     ╎    ╎    ╎    ╎    ╎ 2     @Base/range.jl:459; oneto
#     ╎    ╎    ╎    ╎    ╎  2     ...e/range.jl:457; OneTo
#     ╎    ╎    ╎    ╎    ╎   2     ...e/range.jl:444; OneTo
#     ╎    ╎    ╎    ╎    ╎    2     ...motion.jl:510; max
#    2╎    ╎    ╎    ╎    ╎     2     ...ntials.jl:575; ifelse
#     ╎    ╎    ╎     2     ...a/src/blas.jl:395; dot(x::SubArray{Float...
#    2╎    ╎    ╎    ╎ 2     ...a/src/blas.jl:345; dot
#     ╎    ╎    ╎  39    @Base/timing.jl:394; macro expansion
#   39╎    ╎    ╎   39    @Base/Base.jl:94; time_ns
#     ╎    ╎    ╎ 10    ...rogressMeter.jl:729; iterate(wrap::ProgressMe...
#     ╎    ╎    ╎  10    ...ogressMeter.jl:470; next!
#     ╎    ╎    ╎   10    ...ogressMeter.jl:471; #next!#14
#     ╎    ╎    ╎    10    ...gressMeter.jl:457; lock_if_threading
#     ╎    ╎    ╎     10    ...gressMeter.jl:473; #15
#     ╎    ╎    ╎    ╎ 10    ...gressMeter.jl:208; updateProgress!
#     ╎    ╎    ╎    ╎  2     ...ressMeter.jl:257; updateProgress!(p::P...
#    2╎    ╎    ╎    ╎   2     ...ressMeter.jl:204; calc_check_iteratio...
#     ╎    ╎    ╎    ╎  6     ...ressMeter.jl:280; updateProgress!(p::P...
#     ╎    ╎    ╎    ╎   6     ...ressMeter.jl:604; printover(io::IJuli...
#     ╎    ╎    ╎    ╎    6     ...rings/io.jl:246; print
#     ╎    ╎    ╎    ╎     6     ...rings/io.jl:244; write
#     ╎    ╎    ╎    ╎    ╎ 6     @Base/io.jl:430; unsafe_write
#     ╎    ╎    ╎    ╎    ╎  6     .../stream.jl:1120; unsafe_write(s::...
#     ╎    ╎    ╎    ╎    ╎   2     ...stream.jl:1039; uv_write(s::Base...
#     ╎    ╎    ╎    ╎    ╎    2     ...e/libuv.jl:57; preserve_handle(...
#    2╎    ╎    ╎    ╎    ╎     2     ...iddict.jl:102; get
#     ╎    ╎    ╎    ╎    ╎   4     ...stream.jl:1048; uv_write(s::Base...
#     ╎    ╎    ╎    ╎    ╎    2     ...e/task.jl:983; wait()
#    2╎    ╎    ╎    ╎    ╎     2     ...e/task.jl:974; poptask(W::Base...
#     ╎    ╎    ╎    ╎    ╎    2     ...e/task.jl:985; wait()
#    2╎    ╎    ╎    ╎    ╎     2     .../libuv.jl:107; process_events
#     ╎    ╎    ╎    ╎  2     ...ressMeter.jl:283; updateProgress!(p::P...
#     ╎    ╎    ╎    ╎   2     ...src/stdio.jl:276; flush(io::IJulia.IJ...
#     ╎    ╎    ╎    ╎    2     ...rc/stdio.jl:270; oslibuv_flush
#     ╎    ╎    ╎    ╎     2     @Base/task.jl:864; yield()
#     ╎    ╎    ╎    ╎    ╎ 2     @Base/task.jl:985; wait()
#    2╎    ╎    ╎    ╎    ╎  2     ...e/libuv.jl:107; process_events
#    4╎    ╎    4     ...longitudinal.jl:221; calculate_Qi(qc_model::GL...
#    2╎    ╎    2     ...longitudinal.jl:418; get_Hβγ_i!(W::SubArray{Fl...
#    2╎    ╎    2     ...longitudinal.jl:358; get_neg_Hθγ_i!(W::SubArra...
#    2╎    ╎    2     ...longitudinal.jl:252; get_∇resβ!(∇resβ::SubArra...
#    6╎    ╎    6     ...longitudinal.jl:235; get_∇resγ!(∇resγ::SubArra...
#     ╎2     @Base/task.jl:134; (::Base.var"#702#703"{typeof(I...
#     ╎ 2     @Base/asyncevent.jl:281; macro expansion
#     ╎  2     @IJulia/src/stdio.jl:124; send_stdout
#     ╎   2     @IJulia/src/stdio.jl:121; send_stdio(name::String)
#     ╎    2     @IJulia/src/stdio.jl:142; send_stream(name::String)
#     ╎     2     @Base/dict.jl:483; getindex
#     ╎    ╎ 2     @Base/dict.jl:266; ht_keyindex(h::Dict{String,...
#     ╎    ╎  2     @Base/dict.jl:157; hashindex
#     ╎    ╎   2     @Base/hashing.jl:28; hash
#    2╎    ╎    2     @Base/hashing.jl:115; hash
#     ╎17    ...eadingconstructs.jl:108; (::Base.Threads.var"#1#2"{Quas...
#     ╎ 17    ...eadingconstructs.jl:130; #135#threadsfor_fun
#     ╎  17    ...adingconstructs.jl:163; (::QuasiCopula.var"#135#threa...
#    2╎   17    ...timation/GLM_VC.jl:265; macro expansion
#     ╎    15    ...imation/GLM_VC.jl:167; loglikelihood!
#     ╎     2     ...imation/GLM_VC.jl:182; loglikelihood!(gc::GLMCopul...
#     ╎    ╎ 2     ..._and_residuals.jl:65; update_res!(gc::GLMCopulaVC...
#     ╎    ╎  2     @Base/logging.jl:381; macro expansion
#     ╎    ╎   2     @Base/essentials.jl:813; invokelatest
#    2╎    ╎    2     ...e/essentials.jl:816; #invokelatest#2
#     ╎     2     ...imation/GLM_VC.jl:186; loglikelihood!(gc::GLMCopul...
#     ╎    ╎ 2     @Base/array.jl:349; fill!
#    2╎    ╎  2     @Base/array.jl:969; setindex!
#     ╎     5     ...imation/GLM_VC.jl:187; loglikelihood!(gc::GLMCopul...
#     ╎    ╎ 5     ...adient_hessian.jl:66; std_res_differential!(gc::G...
#    2╎    ╎  5     ...truct_loopset.jl:1107; _turbo_!(::Val{(false, 0,...
#     ╎    ╎   3     ...ruct_loopset.jl:1107; macro expansion
#     ╎    ╎    1     ...idedpointers.jl:148; _vstore!
#     ╎    ╎     1     .../memory_addr.jl:1482; __vstore!
#    1╎    ╎    ╎ 1     ...memory_addr.jl:1482; macro expansion
#     ╎    ╎    2     ...idedpointers.jl:162; _vstore!
#     ╎    ╎     2     .../memory_addr.jl:1667; __vstore!
#    2╎    ╎    ╎ 2     ...memory_addr.jl:1667; macro expansion
#     ╎     4     ...imation/GLM_VC.jl:198; loglikelihood!(gc::GLMCopul...
#     ╎    ╎ 4     ..._loglikelihood.jl:25; component_loglikelihood(gc:...
#     ╎    ╎  4     ..._loglikelihood.jl:8; loglik_obs
#     ╎    ╎   4     ...ete/bernoulli.jl:89; logpdf
#     ╎    ╎    4     .../special/log.jl:267; log
#    2╎    ╎     2     .../special/log.jl:0; _log(x::Float64, base::V...
#     ╎    ╎     2     .../special/log.jl:277; _log(x::Float64, base::V...
#     ╎    ╎    ╎ 2     .../special/log.jl:215; log_proc2
#     ╎    ╎    ╎  2     .../floatfuncs.jl:426; fma
#    2╎    ╎    ╎   2     ...e/floatfuncs.jl:0; fma_emulated(a::Float64,...
#     ╎     2     ...imation/GLM_VC.jl:230; loglikelihood!(gc::GLMCopul...
#     ╎    ╎ 2     @Base/broadcast.jl:881; materialize!
#     ╎    ╎  2     @Base/broadcast.jl:884; materialize!
#     ╎    ╎   2     @Base/broadcast.jl:926; copyto!
#     ╎    ╎    2     @Base/broadcast.jl:973; copyto!
#     ╎    ╎     2     @Base/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎ 2     @Base/broadcast.jl:974; macro expansion
#     ╎    ╎    ╎  2     ...dimensional.jl:670; setindex!
#    2╎    ╎    ╎   2     @Base/array.jl:971; setindex!
#    2╎2     ...c/gwas/utilities.jl:142; dβdβ_res_ij(dist::Bernoulli{Fl...
#   10╎10    ...c/gwas/utilities.jl:198; dγdβresβ_ij!(result_final::Sub...
#   12╎12    ...c/gwas/utilities.jl:82; ∇²μ_j!(storage::Vector{Float64...
#   12╎12    ...c/gwas/utilities.jl:14; ∇²σ²_j(d::Bernoulli{Float64}, ...
#    4╎4     ...c/gwas/utilities.jl:40; ∇²σ²_j!(storage::Vector{Float6...
# 5120╎5121  ...ia/src/heartbeat.jl:22; heartbeat_thread(sock::Ptr{Not...
#   32╎32    ...Algebra/src/blas.jl:513; axpy!(n::Int64, alpha::Float64...
#   18╎18    ...Algebra/src/blas.jl:524; axpy!(alpha::Float64, x::Matri...
#   14╎14    ...Algebra/src/blas.jl:395; dot(x::SubArray{Float64, 1, Ve...
#   14╎14    ...Algebra/src/blas.jl:674; gemv!(trans::Char, alpha::Floa...
#   20╎20    ...gebra/src/matmul.jl:0; gemv!(y::SubArray{Float64, 1, ...
# Total snapshots: 10241. Utilization: 100% across all threads and tasks. Use the `groupby` kwarg to break down by thread and/or task.

# %% [markdown]
# Profile 3/11/2024 (pre-optimized)

# %%
# 3/11/2024 (pre-optimized)
@profile QuasiCopula.GWASCopulaVCModel(qc_model, G, check_grad=false)
Profile.clear()
@profile QuasiCopula.GWASCopulaVCModel(qc_model, G, check_grad=false)
Profile.print()
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:14
# Wtime = 11.272309215999602
# Qtime = 1.5906703360067158
# Rtime = 0.31768871299872736
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:18
# Wtime = 15.354934777010783
# Qtime = 2.0605609100062114
# Rtime = 0.36937975499783227
# Overhead ╎ [+additional indent] Count File:Line; Function
# =========================================================
#     4╎4     ...e/abstractarray.jl:1294; getindex(A::Adjoint{Float64, ...
#     1╎1     ...e/abstractarray.jl:1609; hcat(::Float64, ::Float64)
#    22╎22    @Base/array.jl:0; gemv!(y::Vector{Float64}, tA:...
#    96╎96    @Base/arraymath.jl:21; *(A::Float64, B::Vector{Float...
#    20╎20    @Base/arraymath.jl:24; *(A::Vector{Float64}, B::Floa...
#     5╎5     @Base/arraymath.jl:16; +(::Vector{Float64}, ::Vector...
#    11╎11    @Base/arraymath.jl:8; -(A::Matrix{Float64}, B::Matr...
#    14╎14    @Base/broadcast.jl:811; broadcast(::LinearAlgebra.var...
#     1╎1     @Base/generator.jl:0; collect(itr::Base.Generator{U...
#     9╎9     @Base/indices.jl:169; promote_shape(a::Matrix{Float...
#     7╎7     @Base/reduce.jl:0; _foldl_impl(op::Base.MappingR...
#     2╎2     @Base/reduce.jl:0; _mapreduce(f::typeof(abs2), o...
#      ╎2     @Base/reduce.jl:424; _mapreduce(f::typeof(abs2), o...
#      ╎ 2     @Base/indices.jl:486; LinearIndices
#      ╎  2     ...e/abstractarray.jl:98; axes
#     2╎   2     @Base/array.jl:149; size
#    57╎57    @Base/special/exp.jl:325; exp(x::Float64)
#     1╎1     @Base/strings/io.jl:246; print(io::IOBuffer, s::String)
#      ╎14292 @Base/task.jl:514; (::IJulia.var"#15#18")()
#      ╎ 14292 ...ia/src/eventloop.jl:8; eventloop(socket::ZMQ.Socket)
#      ╎  14292 @Base/essentials.jl:813; invokelatest
#      ╎   14292 @Base/essentials.jl:816; #invokelatest#2
#      ╎    14292 ...xecute_request.jl:67; execute_request(socket::ZMQ....
#      ╎     14292 ...oftGlobalScope.jl:65; softscope_include_string(m:...
#      ╎    ╎ 14292 @Base/loading.jl:1899; include_string(mapexpr::t...
#      ╎    ╎  14292 @Base/boot.jl:370; eval
# WARNING: both Distributions and Convex export "entropy"; uses of it in module QuasiCopula must be qualified
#     5╎    ╎   14292 .../longitudinal.jl:42; kwcall(::NamedTuple{(:che...
#      ╎    ╎    354   ...longitudinal.jl:68; GWASCopulaVCModel(qc_mod...
#      ╎    ╎     322   ...longitudinal.jl:218; get_Pinv(qc_model::GLMCo...
#      ╎    ╎    ╎ 19    ...ongitudinal.jl:387; get_Hββ(qc_model::GLMCo...
#      ╎    ╎    ╎  6     .../arraymath.jl:8; -(A::Matrix{Float64}, ...
#      ╎    ╎    ╎   4     .../broadcast.jl:862; broadcast_preserving_z...
#      ╎    ╎    ╎    4     .../broadcast.jl:873; materialize
#      ╎    ╎    ╎     4     .../broadcast.jl:898; copy
#      ╎    ╎    ╎    ╎ 2     ...broadcast.jl:926; copyto!
#      ╎    ╎    ╎    ╎  2     ...broadcast.jl:973; copyto!
#     2╎    ╎    ╎    ╎   2     .../simdloop.jl:75; macro expansion
#      ╎    ╎    ╎    ╎ 2     ...broadcast.jl:211; similar
#      ╎    ╎    ╎    ╎  2     ...broadcast.jl:212; similar
#      ╎    ╎    ╎    ╎   2     ...actarray.jl:881; similar
#      ╎    ╎    ╎    ╎    2     ...actarray.jl:882; similar
#      ╎    ╎    ╎    ╎     2     @Base/boot.jl:494; Array
#      ╎    ╎    ╎    ╎    ╎ 2     @Base/boot.jl:487; Array
#     2╎    ╎    ╎    ╎    ╎  2     @Base/boot.jl:479; Array
#      ╎    ╎    ╎   2     .../broadcast.jl:863; broadcast_preserving_z...
#      ╎    ╎    ╎    2     .../broadcast.jl:222; axes
#      ╎    ╎    ╎     2     .../broadcast.jl:224; _axes
#      ╎    ╎    ╎    ╎ 2     ...broadcast.jl:512; combine_axes
#      ╎    ╎    ╎    ╎  2     ...broadcast.jl:517; broadcast_shape
#      ╎    ╎    ╎    ╎   2     ...roadcast.jl:523; _bcs
#     2╎    ╎    ╎    ╎    2     ...roadcast.jl:529; _bcs1
#      ╎    ╎    ╎  13    ...src/matmul.jl:1166; *
#      ╎    ╎    ╎   13    ...src/matmul.jl:1170; _tri_matmul
#      ╎    ╎    ╎    13    ...src/matmul.jl:1178; _tri_matmul(A::Transp...
#      ╎    ╎    ╎     6     ...c/diagonal.jl:256; *
#      ╎    ╎    ╎    ╎ 4     ...transpose.jl:210; copy_similar
#      ╎    ╎    ╎    ╎  4     .../adjtrans.jl:335; similar
#      ╎    ╎    ╎    ╎   4     @Base/array.jl:374; similar
#      ╎    ╎    ╎    ╎    4     @Base/boot.jl:487; Array
#     4╎    ╎    ╎    ╎     4     @Base/boot.jl:479; Array
#      ╎    ╎    ╎    ╎ 2     ...transpose.jl:211; copy_similar
#      ╎    ╎    ╎    ╎  2     ...transpose.jl:41; transpose!
#      ╎    ╎    ╎    ╎   2     ...ranspose.jl:104; transpose_f!(f::typ...
#     2╎    ╎    ╎    ╎    2     @Base/array.jl:971; setindex!
#      ╎    ╎    ╎     3     ...c/diagonal.jl:257; *
#      ╎    ╎    ╎    ╎ 3     .../diagonal.jl:252; rmul!(A::Matrix{Floa...
#      ╎    ╎    ╎    ╎  3     ...rc/matmul.jl:276; mul!
#      ╎    ╎    ╎    ╎   3     ...diagonal.jl:374; mul!
#      ╎    ╎    ╎    ╎    3     ...diagonal.jl:348; _muldiag!
#     1╎    ╎    ╎    ╎     1     ...diagonal.jl:297; __muldiag!
#      ╎    ╎    ╎    ╎     2     ...diagonal.jl:302; __muldiag!
#     2╎    ╎    ╎    ╎    ╎ 2     ...e/range.jl:891; iterate
#      ╎    ╎    ╎     4     ...src/matmul.jl:148; *
#      ╎    ╎    ╎    ╎ 4     @Base/array.jl:374; similar
#      ╎    ╎    ╎    ╎  4     @Base/boot.jl:487; Array
#     4╎    ╎    ╎    ╎   4     @Base/boot.jl:479; Array
#      ╎    ╎    ╎ 3     ...ongitudinal.jl:393; get_Hββ(qc_model::GLMCo...
#      ╎    ╎    ╎  3     ...e/broadcast.jl:881; materialize!
#      ╎    ╎    ╎   3     .../broadcast.jl:884; materialize!
#      ╎    ╎    ╎    3     .../broadcast.jl:926; copyto!
#      ╎    ╎    ╎     3     .../broadcast.jl:973; copyto!
#     1╎    ╎    ╎    ╎ 1     ...e/simdloop.jl:75; macro expansion
#      ╎    ╎    ╎    ╎ 2     ...e/simdloop.jl:77; macro expansion
#      ╎    ╎    ╎    ╎  2     ...broadcast.jl:974; macro expansion
#      ╎    ╎    ╎    ╎   2     ...ensional.jl:670; setindex!
#     2╎    ╎    ╎    ╎    2     @Base/array.jl:971; setindex!
#      ╎    ╎    ╎ 12    ...ongitudinal.jl:396; get_Hββ(qc_model::GLMCo...
#      ╎    ╎    ╎  2     .../arraymath.jl:8; -(A::Matrix{Float64}, ...
#      ╎    ╎    ╎   2     .../broadcast.jl:862; broadcast_preserving_z...
#      ╎    ╎    ╎    2     .../broadcast.jl:873; materialize
#      ╎    ╎    ╎     2     .../broadcast.jl:898; copy
#      ╎    ╎    ╎    ╎ 2     ...broadcast.jl:926; copyto!
#      ╎    ╎    ╎    ╎  2     ...broadcast.jl:973; copyto!
#      ╎    ╎    ╎    ╎   2     .../simdloop.jl:77; macro expansion
#      ╎    ╎    ╎    ╎    2     ...roadcast.jl:974; macro expansion
#      ╎    ╎    ╎    ╎     2     ...ensional.jl:670; setindex!
#     2╎    ╎    ╎    ╎    ╎ 2     ...e/array.jl:971; setindex!
#      ╎    ╎    ╎  5     .../arraymath.jl:24; /(A::Matrix{Float64}, ...
#      ╎    ╎    ╎   5     .../broadcast.jl:862; broadcast_preserving_z...
#      ╎    ╎    ╎    5     .../broadcast.jl:873; materialize
#      ╎    ╎    ╎     5     .../broadcast.jl:898; copy
#      ╎    ╎    ╎    ╎ 4     ...broadcast.jl:926; copyto!
#      ╎    ╎    ╎    ╎  4     ...broadcast.jl:973; copyto!
#     2╎    ╎    ╎    ╎   2     .../simdloop.jl:75; macro expansion
#      ╎    ╎    ╎    ╎   2     .../simdloop.jl:77; macro expansion
#      ╎    ╎    ╎    ╎    2     ...roadcast.jl:974; macro expansion
#      ╎    ╎    ╎    ╎     2     ...ensional.jl:670; setindex!
#     2╎    ╎    ╎    ╎    ╎ 2     ...e/array.jl:971; setindex!
#      ╎    ╎    ╎    ╎ 1     ...broadcast.jl:211; similar
#      ╎    ╎    ╎    ╎  1     ...broadcast.jl:212; similar
#      ╎    ╎    ╎    ╎   1     ...actarray.jl:881; similar
#      ╎    ╎    ╎    ╎    1     ...actarray.jl:882; similar
#      ╎    ╎    ╎    ╎     1     @Base/boot.jl:494; Array
#      ╎    ╎    ╎    ╎    ╎ 1     @Base/boot.jl:487; Array
#     1╎    ╎    ╎    ╎    ╎  1     @Base/boot.jl:479; Array
#      ╎    ╎    ╎  2     ...c/adjtrans.jl:439; *
#      ╎    ╎    ╎   2     .../broadcast.jl:811; broadcast(::typeof(*),...
#      ╎    ╎    ╎    2     .../broadcast.jl:873; materialize
#      ╎    ╎    ╎     2     .../broadcast.jl:898; copy
#      ╎    ╎    ╎    ╎ 2     ...broadcast.jl:926; copyto!
#      ╎    ╎    ╎    ╎  2     ...broadcast.jl:973; copyto!
#     1╎    ╎    ╎    ╎   1     .../simdloop.jl:75; macro expansion
#      ╎    ╎    ╎    ╎   1     .../simdloop.jl:77; macro expansion
#      ╎    ╎    ╎    ╎    1     ...roadcast.jl:974; macro expansion
#      ╎    ╎    ╎    ╎     1     ...roadcast.jl:610; getindex
#      ╎    ╎    ╎    ╎    ╎ 1     ...oadcast.jl:655; _broadcast_getindex
#      ╎    ╎    ╎    ╎    ╎  1     ...oadcast.jl:679; _getindex
#      ╎    ╎    ╎    ╎    ╎   1     ...adcast.jl:649; _broadcast_getindex
#      ╎    ╎    ╎    ╎    ╎    1     ...sional.jl:668; getindex
#     1╎    ╎    ╎    ╎    ╎     1     ...ntials.jl:13; getindex
#      ╎    ╎    ╎  3     ...src/matmul.jl:1150; *
#      ╎    ╎    ╎   1     ...src/matmul.jl:52; *
#      ╎    ╎    ╎    1     ...tractarray.jl:838; similar
#      ╎    ╎    ╎     1     @Base/array.jl:374; similar
#      ╎    ╎    ╎    ╎ 1     @Base/boot.jl:486; Array
#     1╎    ╎    ╎    ╎  1     @Base/boot.jl:477; Array
#      ╎    ╎    ╎   2     ...src/matmul.jl:101; *
#      ╎    ╎    ╎    2     ...tractarray.jl:838; similar
#      ╎    ╎    ╎     2     @Base/array.jl:374; similar
#      ╎    ╎    ╎    ╎ 2     @Base/boot.jl:486; Array
#     2╎    ╎    ╎    ╎  2     @Base/boot.jl:477; Array
#      ╎    ╎    ╎ 6     ...ongitudinal.jl:398; get_Hββ(qc_model::GLMCo...
#      ╎    ╎    ╎  5     ...e/arraymath.jl:16; +(A::Matrix{Float64}, B...
#      ╎    ╎    ╎   5     .../broadcast.jl:862; broadcast_preserving_z...
#      ╎    ╎    ╎    5     .../broadcast.jl:873; materialize
#      ╎    ╎    ╎     5     .../broadcast.jl:898; copy
#      ╎    ╎    ╎    ╎ 4     ...broadcast.jl:926; copyto!
#      ╎    ╎    ╎    ╎  4     ...broadcast.jl:973; copyto!
#      ╎    ╎    ╎    ╎   4     .../simdloop.jl:77; macro expansion
#      ╎    ╎    ╎    ╎    4     ...roadcast.jl:974; macro expansion
#      ╎    ╎    ╎    ╎     4     ...ensional.jl:670; setindex!
#     4╎    ╎    ╎    ╎    ╎ 4     ...e/array.jl:971; setindex!
#      ╎    ╎    ╎    ╎ 1     ...broadcast.jl:211; similar
#      ╎    ╎    ╎    ╎  1     ...broadcast.jl:212; similar
#      ╎    ╎    ╎    ╎   1     ...actarray.jl:881; similar
#      ╎    ╎    ╎    ╎    1     ...actarray.jl:882; similar
#      ╎    ╎    ╎    ╎     1     @Base/boot.jl:494; Array
#      ╎    ╎    ╎    ╎    ╎ 1     @Base/boot.jl:487; Array
#     1╎    ╎    ╎    ╎    ╎  1     @Base/boot.jl:479; Array
#      ╎    ╎    ╎  1     ...e/arraymath.jl:24; /(A::Matrix{Float64}, B...
#      ╎    ╎    ╎   1     .../broadcast.jl:862; broadcast_preserving_z...
#      ╎    ╎    ╎    1     .../broadcast.jl:873; materialize
#      ╎    ╎    ╎     1     .../broadcast.jl:898; copy
#      ╎    ╎    ╎    ╎ 1     ...broadcast.jl:926; copyto!
#      ╎    ╎    ╎    ╎  1     ...broadcast.jl:973; copyto!
#     1╎    ╎    ╎    ╎   1     .../simdloop.jl:75; macro expansion
#      ╎    ╎    ╎ 2     ...ongitudinal.jl:408; get_Hββ(qc_model::GLMCo...
#      ╎    ╎    ╎  2     ...tractarray.jl:1294; getindex
#      ╎    ╎    ╎   2     ...imensional.jl:861; _getindex
#      ╎    ╎    ╎    2     ...imensional.jl:873; _unsafe_getindex
#      ╎    ╎    ╎     2     ...tractarray.jl:836; similar
#      ╎    ╎    ╎    ╎ 2     @Base/array.jl:374; similar
#      ╎    ╎    ╎    ╎  2     @Base/boot.jl:486; Array
#     2╎    ╎    ╎    ╎   2     @Base/boot.jl:477; Array
#     2╎    ╎    ╎ 280   ...ongitudinal.jl:411; get_Hββ(qc_model::GLMCo...
#      ╎    ╎    ╎  28    ...e/arraymath.jl:16; +(A::Matrix{Float64}, ...
#      ╎    ╎    ╎   28    .../broadcast.jl:862; broadcast_preserving_z...
#      ╎    ╎    ╎    28    .../broadcast.jl:873; materialize
#      ╎    ╎    ╎     28    .../broadcast.jl:898; copy
#      ╎    ╎    ╎    ╎ 17    ...broadcast.jl:926; copyto!
#      ╎    ╎    ╎    ╎  4     ...broadcast.jl:970; copyto!
#      ╎    ╎    ╎    ╎   4     ...roadcast.jl:953; preprocess
#      ╎    ╎    ╎    ╎    4     ...roadcast.jl:956; preprocess_args
#      ╎    ╎    ╎    ╎     4     ...roadcast.jl:957; preprocess_args
#      ╎    ╎    ╎    ╎    ╎ 4     ...oadcast.jl:954; preprocess
#      ╎    ╎    ╎    ╎    ╎  4     ...oadcast.jl:650; extrude
#      ╎    ╎    ╎    ╎    ╎   4     ...adcast.jl:599; newindexer
#      ╎    ╎    ╎    ╎    ╎    4     ...adcast.jl:600; shapeindexer
#      ╎    ╎    ╎    ╎    ╎     4     ...adcast.jl:604; _newindexer
#      ╎    ╎    ╎    ╎    ╎    ╎ 4     ...adcast.jl:605; _newindexer
#      ╎    ╎    ╎    ╎    ╎    ╎  4     ...rators.jl:269; !=
#     4╎    ╎    ╎    ╎    ╎    ╎   4     ...motion.jl:499; ==
#      ╎    ╎    ╎    ╎  13    ...broadcast.jl:973; copyto!
#     3╎    ╎    ╎    ╎   3     .../simdloop.jl:75; macro expansion
#      ╎    ╎    ╎    ╎   8     .../simdloop.jl:77; macro expansion
#      ╎    ╎    ╎    ╎    8     ...roadcast.jl:974; macro expansion
#      ╎    ╎    ╎    ╎     8     ...ensional.jl:670; setindex!
#     8╎    ╎    ╎    ╎    ╎ 8     ...e/array.jl:971; setindex!
#     2╎    ╎    ╎    ╎   2     .../simdloop.jl:84; macro expansion
#      ╎    ╎    ╎    ╎ 11    ...broadcast.jl:211; similar
#      ╎    ╎    ╎    ╎  11    ...broadcast.jl:212; similar
#      ╎    ╎    ╎    ╎   11    ...actarray.jl:881; similar
#      ╎    ╎    ╎    ╎    11    ...actarray.jl:882; similar
#      ╎    ╎    ╎    ╎     11    @Base/boot.jl:494; Array
#      ╎    ╎    ╎    ╎    ╎ 11    @Base/boot.jl:487; Array
#    11╎    ╎    ╎    ╎    ╎  11    @Base/boot.jl:479; Array
#      ╎    ╎    ╎  32    ...e/arraymath.jl:24; /(A::Matrix{Float64}, ...
#      ╎    ╎    ╎   32    .../broadcast.jl:862; broadcast_preserving_z...
#      ╎    ╎    ╎    32    .../broadcast.jl:873; materialize
#      ╎    ╎    ╎     32    .../broadcast.jl:898; copy
#      ╎    ╎    ╎    ╎ 12    ...broadcast.jl:926; copyto!
#      ╎    ╎    ╎    ╎  3     ...broadcast.jl:970; copyto!
#      ╎    ╎    ╎    ╎   3     ...roadcast.jl:953; preprocess
#      ╎    ╎    ╎    ╎    3     ...roadcast.jl:956; preprocess_args
#      ╎    ╎    ╎    ╎     3     ...roadcast.jl:954; preprocess
#     2╎    ╎    ╎    ╎    ╎ 2     ...oadcast.jl:947; broadcast_unalias
#      ╎    ╎    ╎    ╎    ╎ 1     ...oadcast.jl:650; extrude
#      ╎    ╎    ╎    ╎    ╎  1     ...oadcast.jl:599; newindexer
#      ╎    ╎    ╎    ╎    ╎   1     ...adcast.jl:600; shapeindexer
#      ╎    ╎    ╎    ╎    ╎    1     ...adcast.jl:604; _newindexer
#      ╎    ╎    ╎    ╎    ╎     1     ...adcast.jl:605; _newindexer
#      ╎    ╎    ╎    ╎    ╎    ╎ 1     ...rators.jl:269; !=
#     1╎    ╎    ╎    ╎    ╎    ╎  1     ...motion.jl:499; ==
#      ╎    ╎    ╎    ╎  9     ...broadcast.jl:973; copyto!
#     2╎    ╎    ╎    ╎   2     .../simdloop.jl:75; macro expansion
#      ╎    ╎    ╎    ╎   4     .../simdloop.jl:77; macro expansion
#      ╎    ╎    ╎    ╎    4     ...roadcast.jl:974; macro expansion
#      ╎    ╎    ╎    ╎     4     ...ensional.jl:670; setindex!
#     4╎    ╎    ╎    ╎    ╎ 4     ...e/array.jl:971; setindex!
#     3╎    ╎    ╎    ╎   3     .../simdloop.jl:84; macro expansion
#      ╎    ╎    ╎    ╎ 20    ...broadcast.jl:211; similar
#      ╎    ╎    ╎    ╎  20    ...broadcast.jl:212; similar
#      ╎    ╎    ╎    ╎   20    ...actarray.jl:881; similar
#      ╎    ╎    ╎    ╎    20    ...actarray.jl:882; similar
#      ╎    ╎    ╎    ╎     20    @Base/boot.jl:494; Array
#      ╎    ╎    ╎    ╎    ╎ 20    @Base/boot.jl:487; Array
#    20╎    ╎    ╎    ╎    ╎  20    @Base/boot.jl:479; Array
#      ╎    ╎    ╎  24    ...e/operators.jl:578; *
#      ╎    ╎    ╎   12    .../operators.jl:535; afoldl
#      ╎    ╎    ╎    12    .../arraymath.jl:21; *(A::Float64, B::Matri...
#      ╎    ╎    ╎     12    .../broadcast.jl:862; broadcast_preserving_...
#      ╎    ╎    ╎    ╎ 12    ...broadcast.jl:873; materialize
#      ╎    ╎    ╎    ╎  12    ...broadcast.jl:898; copy
#      ╎    ╎    ╎    ╎   5     ...roadcast.jl:926; copyto!
#      ╎    ╎    ╎    ╎    1     ...roadcast.jl:970; copyto!
#      ╎    ╎    ╎    ╎     1     ...roadcast.jl:953; preprocess
#      ╎    ╎    ╎    ╎    ╎ 1     ...oadcast.jl:956; preprocess_args
#      ╎    ╎    ╎    ╎    ╎  1     ...oadcast.jl:957; preprocess_args
#      ╎    ╎    ╎    ╎    ╎   1     ...adcast.jl:954; preprocess
#      ╎    ╎    ╎    ╎    ╎    1     ...adcast.jl:650; extrude
#      ╎    ╎    ╎    ╎    ╎     1     ...adcast.jl:599; newindexer
#      ╎    ╎    ╎    ╎    ╎    ╎ 1     ...adcast.jl:600; shapeindexer
#      ╎    ╎    ╎    ╎    ╎    ╎  1     ...adcast.jl:604; _newindexer
#      ╎    ╎    ╎    ╎    ╎    ╎   1     ...adcast.jl:605; _newindexer
#      ╎    ╎    ╎    ╎    ╎    ╎    1     ...rators.jl:269; !=
#     1╎    ╎    ╎    ╎    ╎    ╎     1     ...motion.jl:499; ==
#      ╎    ╎    ╎    ╎    4     ...roadcast.jl:973; copyto!
#      ╎    ╎    ╎    ╎     2     ...simdloop.jl:77; macro expansion
#      ╎    ╎    ╎    ╎    ╎ 2     ...oadcast.jl:974; macro expansion
#      ╎    ╎    ╎    ╎    ╎  2     ...nsional.jl:670; setindex!
#     2╎    ╎    ╎    ╎    ╎   2     .../array.jl:971; setindex!
#     2╎    ╎    ╎    ╎     2     ...simdloop.jl:84; macro expansion
#      ╎    ╎    ╎    ╎   7     ...roadcast.jl:211; similar
#      ╎    ╎    ╎    ╎    7     ...roadcast.jl:212; similar
#      ╎    ╎    ╎    ╎     7     ...actarray.jl:881; similar
#      ╎    ╎    ╎    ╎    ╎ 7     ...ctarray.jl:882; similar
#      ╎    ╎    ╎    ╎    ╎  7     @Base/boot.jl:494; Array
#      ╎    ╎    ╎    ╎    ╎   7     ...e/boot.jl:487; Array
#     7╎    ╎    ╎    ╎    ╎    7     ...e/boot.jl:479; Array
#      ╎    ╎    ╎   12    ...src/matmul.jl:119; *
#      ╎    ╎    ╎    12    ...src/matmul.jl:101; *
#      ╎    ╎    ╎     10    ...tractarray.jl:838; similar
#      ╎    ╎    ╎    ╎ 10    @Base/array.jl:374; similar
#      ╎    ╎    ╎    ╎  10    @Base/boot.jl:486; Array
#    10╎    ╎    ╎    ╎   10    @Base/boot.jl:477; Array
#      ╎    ╎    ╎     2     ...src/matmul.jl:276; mul!
#      ╎    ╎    ╎    ╎ 2     ...rc/matmul.jl:109; mul!
#      ╎    ╎    ╎    ╎  2     ...rc/matmul.jl:93; mul!
#      ╎    ╎    ╎    ╎   2     ...c/matmul.jl:503; gemv!(y::Vector{Flo...
#     2╎    ╎    ╎    ╎    2     ...src/blas.jl:667; gemv!(trans::Char,...
#     2╎    ╎    ╎  2     ...s/utilities.jl:73; dβdβ_res_ij(dist::Bern...
#     1╎    ╎    ╎  3     ...s/utilities.jl:75; dβdβ_res_ij(dist::Bern...
#      ╎    ╎    ╎   2     ...e/arraymath.jl:21; *(A::Float64, B::Vecto...
#      ╎    ╎    ╎    2     .../broadcast.jl:862; broadcast_preserving_...
#      ╎    ╎    ╎     2     .../broadcast.jl:873; materialize
#      ╎    ╎    ╎    ╎ 2     ...broadcast.jl:898; copy
#      ╎    ╎    ╎    ╎  2     ...broadcast.jl:211; similar
#      ╎    ╎    ╎    ╎   2     ...roadcast.jl:212; similar
#      ╎    ╎    ╎    ╎    2     ...actarray.jl:881; similar
#      ╎    ╎    ╎    ╎     2     ...actarray.jl:882; similar
#      ╎    ╎    ╎    ╎    ╎ 2     @Base/boot.jl:494; Array
#      ╎    ╎    ╎    ╎    ╎  2     @Base/boot.jl:486; Array
#     2╎    ╎    ╎    ╎    ╎   2     ...e/boot.jl:477; Array
#      ╎    ╎    ╎  1     ...s/utilities.jl:76; dβdβ_res_ij(dist::Bern...
#      ╎    ╎    ╎   1     .../operators.jl:578; *
#      ╎    ╎    ╎    1     .../arraymath.jl:21; *(A::Float64, B::Vecto...
#      ╎    ╎    ╎     1     .../broadcast.jl:862; broadcast_preserving_...
#      ╎    ╎    ╎    ╎ 1     ...broadcast.jl:873; materialize
#      ╎    ╎    ╎    ╎  1     ...broadcast.jl:898; copy
#      ╎    ╎    ╎    ╎   1     ...roadcast.jl:211; similar
#      ╎    ╎    ╎    ╎    1     ...roadcast.jl:212; similar
#      ╎    ╎    ╎    ╎     1     ...actarray.jl:881; similar
#      ╎    ╎    ╎    ╎    ╎ 1     ...ctarray.jl:882; similar
#      ╎    ╎    ╎    ╎    ╎  1     @Base/boot.jl:494; Array
#      ╎    ╎    ╎    ╎    ╎   1     ...e/boot.jl:486; Array
#     1╎    ╎    ╎    ╎    ╎    1     ...e/boot.jl:477; Array
#      ╎    ╎    ╎  21    ...s/utilities.jl:79; dβdβ_res_ij(dist::Bern...
#      ╎    ╎    ╎   12    ...e/arraymath.jl:21; *(A::Float64, B::Matri...
#      ╎    ╎    ╎    12    .../broadcast.jl:862; broadcast_preserving_...
#      ╎    ╎    ╎     12    .../broadcast.jl:873; materialize
#      ╎    ╎    ╎    ╎ 12    ...broadcast.jl:898; copy
#      ╎    ╎    ╎    ╎  12    ...broadcast.jl:926; copyto!
#      ╎    ╎    ╎    ╎   12    ...roadcast.jl:973; copyto!
#     3╎    ╎    ╎    ╎    3     ...simdloop.jl:75; macro expansion
#      ╎    ╎    ╎    ╎    7     ...simdloop.jl:77; macro expansion
#      ╎    ╎    ╎    ╎     7     ...roadcast.jl:974; macro expansion
#      ╎    ╎    ╎    ╎    ╎ 7     ...nsional.jl:670; setindex!
#     7╎    ╎    ╎    ╎    ╎  7     ...e/array.jl:971; setindex!
#      ╎    ╎    ╎    ╎    2     ...simdloop.jl:78; macro expansion
#     2╎    ╎    ╎    ╎     2     @Base/int.jl:87; +
#      ╎    ╎    ╎   9     ...s/utilities.jl:22; ∇²μ_j(l::LogitLink, ηj...
#      ╎    ╎    ╎    9     ...src/matmul.jl:1162; *
#      ╎    ╎    ╎     9     .../broadcast.jl:811; broadcast(::typeof(*)...
#      ╎    ╎    ╎    ╎ 9     ...broadcast.jl:873; materialize
#      ╎    ╎    ╎    ╎  9     ...broadcast.jl:898; copy
#      ╎    ╎    ╎    ╎   7     ...roadcast.jl:926; copyto!
#      ╎    ╎    ╎    ╎    1     ...roadcast.jl:970; copyto!
#      ╎    ╎    ╎    ╎     1     ...roadcast.jl:953; preprocess
#      ╎    ╎    ╎    ╎    ╎ 1     ...oadcast.jl:956; preprocess_args
#      ╎    ╎    ╎    ╎    ╎  1     ...oadcast.jl:956; preprocess_args
#      ╎    ╎    ╎    ╎    ╎   1     ...adcast.jl:954; preprocess
#      ╎    ╎    ╎    ╎    ╎    1     ...adcast.jl:650; extrude
#      ╎    ╎    ╎    ╎    ╎     1     ...adcast.jl:599; newindexer
#      ╎    ╎    ╎    ╎    ╎    ╎ 1     ...adcast.jl:600; shapeindexer
#      ╎    ╎    ╎    ╎    ╎    ╎  1     ...adcast.jl:605; _newindexer
#      ╎    ╎    ╎    ╎    ╎    ╎   1     ...rators.jl:269; !=
#     1╎    ╎    ╎    ╎    ╎    ╎    1     ...motion.jl:499; ==
#      ╎    ╎    ╎    ╎    6     ...roadcast.jl:973; copyto!
#     4╎    ╎    ╎    ╎     4     ...simdloop.jl:75; macro expansion
#      ╎    ╎    ╎    ╎     2     ...simdloop.jl:77; macro expansion
#      ╎    ╎    ╎    ╎    ╎ 2     ...oadcast.jl:974; macro expansion
#      ╎    ╎    ╎    ╎    ╎  2     ...nsional.jl:670; setindex!
#     2╎    ╎    ╎    ╎    ╎   2     .../array.jl:971; setindex!
#      ╎    ╎    ╎    ╎   2     ...roadcast.jl:211; similar
#      ╎    ╎    ╎    ╎    2     ...roadcast.jl:212; similar
#      ╎    ╎    ╎    ╎     2     ...actarray.jl:881; similar
#      ╎    ╎    ╎    ╎    ╎ 2     ...ctarray.jl:882; similar
#      ╎    ╎    ╎    ╎    ╎  2     @Base/boot.jl:494; Array
#      ╎    ╎    ╎    ╎    ╎   2     ...e/boot.jl:487; Array
#     2╎    ╎    ╎    ╎    ╎    2     ...e/boot.jl:479; Array
#      ╎    ╎    ╎  26    ...s/utilities.jl:80; dβdβ_res_ij(dist::Bern...
#      ╎    ╎    ╎   26    ...src/matmul.jl:1162; *
#      ╎    ╎    ╎    26    .../broadcast.jl:811; broadcast(::typeof(*)...
#      ╎    ╎    ╎     26    .../broadcast.jl:873; materialize
#      ╎    ╎    ╎    ╎ 26    ...broadcast.jl:898; copy
#      ╎    ╎    ╎    ╎  10    ...broadcast.jl:926; copyto!
#      ╎    ╎    ╎    ╎   10    ...roadcast.jl:973; copyto!
#     6╎    ╎    ╎    ╎    6     ...simdloop.jl:75; macro expansion
#      ╎    ╎    ╎    ╎    4     ...simdloop.jl:77; macro expansion
#      ╎    ╎    ╎    ╎     4     ...roadcast.jl:974; macro expansion
#      ╎    ╎    ╎    ╎    ╎ 4     ...nsional.jl:670; setindex!
#     4╎    ╎    ╎    ╎    ╎  4     ...e/array.jl:971; setindex!
#      ╎    ╎    ╎    ╎  16    ...broadcast.jl:211; similar
#      ╎    ╎    ╎    ╎   16    ...roadcast.jl:212; similar
#      ╎    ╎    ╎    ╎    16    ...actarray.jl:881; similar
#      ╎    ╎    ╎    ╎     16    ...actarray.jl:882; similar
#      ╎    ╎    ╎    ╎    ╎ 16    @Base/boot.jl:494; Array
#      ╎    ╎    ╎    ╎    ╎  16    @Base/boot.jl:487; Array
#    16╎    ╎    ╎    ╎    ╎   16    ...e/boot.jl:479; Array
#      ╎    ╎    ╎  58    ...s/utilities.jl:81; dβdβ_res_ij(dist::Bern...
#      ╎    ╎    ╎   19    .../operators.jl:578; *
#      ╎    ╎    ╎    19    .../operators.jl:535; afoldl
#      ╎    ╎    ╎     19    .../arraymath.jl:21; *(A::Float64, B::Matr...
#      ╎    ╎    ╎    ╎ 19    ...broadcast.jl:862; broadcast_preserving...
#      ╎    ╎    ╎    ╎  19    ...broadcast.jl:873; materialize
#      ╎    ╎    ╎    ╎   19    ...roadcast.jl:898; copy
#      ╎    ╎    ╎    ╎    7     ...roadcast.jl:926; copyto!
#      ╎    ╎    ╎    ╎     2     ...roadcast.jl:962; copyto!
#      ╎    ╎    ╎    ╎    ╎ 2     ...actarray.jl:98; axes
#     2╎    ╎    ╎    ╎    ╎  2     ...e/array.jl:150; size
#      ╎    ╎    ╎    ╎     5     ...roadcast.jl:973; copyto!
#     2╎    ╎    ╎    ╎    ╎ 2     ...simdloop.jl:75; macro expansion
#      ╎    ╎    ╎    ╎    ╎ 3     ...simdloop.jl:77; macro expansion
#      ╎    ╎    ╎    ╎    ╎  3     ...oadcast.jl:974; macro expansion
#      ╎    ╎    ╎    ╎    ╎   3     ...sional.jl:670; setindex!
#     3╎    ╎    ╎    ╎    ╎    3     .../array.jl:971; setindex!
#      ╎    ╎    ╎    ╎    12    ...roadcast.jl:211; similar
#      ╎    ╎    ╎    ╎     12    ...roadcast.jl:212; similar
#      ╎    ╎    ╎    ╎    ╎ 12    ...ctarray.jl:881; similar
#      ╎    ╎    ╎    ╎    ╎  12    ...ctarray.jl:882; similar
#      ╎    ╎    ╎    ╎    ╎   12    ...e/boot.jl:494; Array
#      ╎    ╎    ╎    ╎    ╎    12    ...e/boot.jl:487; Array
#    12╎    ╎    ╎    ╎    ╎     12    ...e/boot.jl:479; Array
#      ╎    ╎    ╎   3     .../utilities.jl:7; ∇²σ²_j(d::Bernoulli{Fl...
#     2╎    ╎    ╎    2     .../utilities.jl:61; mueta2
#      ╎    ╎    ╎    1     ...c/glmtools.jl:263; mueta
#      ╎    ╎    ╎     1     ...pecial/exp.jl:325; exp(x::Float64)
#      ╎    ╎    ╎    ╎ 1     ...ecial/exp.jl:216; exp_impl
#     1╎    ╎    ╎    ╎  1     @Base/float.jl:408; +
#      ╎    ╎    ╎   36    .../utilities.jl:8; ∇²σ²_j(d::Bernoulli{Fl...
#      ╎    ╎    ╎    36    ...src/matmul.jl:1162; *
#     2╎    ╎    ╎     36    .../broadcast.jl:811; broadcast(::typeof(*)...
#      ╎    ╎    ╎    ╎ 34    ...broadcast.jl:873; materialize
#      ╎    ╎    ╎    ╎  34    ...broadcast.jl:898; copy
#      ╎    ╎    ╎    ╎   14    ...roadcast.jl:926; copyto!
#      ╎    ╎    ╎    ╎    4     ...roadcast.jl:970; copyto!
#      ╎    ╎    ╎    ╎     4     ...roadcast.jl:953; preprocess
#      ╎    ╎    ╎    ╎    ╎ 4     ...oadcast.jl:956; preprocess_args
#      ╎    ╎    ╎    ╎    ╎  4     ...oadcast.jl:956; preprocess_args
#      ╎    ╎    ╎    ╎    ╎   4     ...adcast.jl:954; preprocess
#      ╎    ╎    ╎    ╎    ╎    2     ...adcast.jl:947; broadcast_unalias
#      ╎    ╎    ╎    ╎    ╎     2     ...tarray.jl:1480; unalias
#      ╎    ╎    ╎    ╎    ╎    ╎ 2     ...tarray.jl:1515; mightalias
#      ╎    ╎    ╎    ╎    ╎    ╎  2     ...tarray.jl:1522; _isdisjoint
#      ╎    ╎    ╎    ╎    ╎    ╎   2     ...rators.jl:269; !=
#     2╎    ╎    ╎    ╎    ╎    ╎    2     ...motion.jl:499; ==
#      ╎    ╎    ╎    ╎    ╎    2     ...adcast.jl:650; extrude
#      ╎    ╎    ╎    ╎    ╎     2     ...adcast.jl:599; newindexer
#      ╎    ╎    ╎    ╎    ╎    ╎ 2     ...adcast.jl:600; shapeindexer
#      ╎    ╎    ╎    ╎    ╎    ╎  2     ...adcast.jl:605; _newindexer
#      ╎    ╎    ╎    ╎    ╎    ╎   2     ...rators.jl:269; !=
#     2╎    ╎    ╎    ╎    ╎    ╎    2     ...motion.jl:499; ==
#      ╎    ╎    ╎    ╎    10    ...roadcast.jl:973; copyto!
#     4╎    ╎    ╎    ╎     4     ...simdloop.jl:75; macro expansion
#      ╎    ╎    ╎    ╎     4     ...simdloop.jl:77; macro expansion
#      ╎    ╎    ╎    ╎    ╎ 4     ...oadcast.jl:974; macro expansion
#      ╎    ╎    ╎    ╎    ╎  4     ...nsional.jl:670; setindex!
#     4╎    ╎    ╎    ╎    ╎   4     .../array.jl:971; setindex!
#      ╎    ╎    ╎    ╎     2     ...simdloop.jl:84; macro expansion
#      ╎    ╎    ╎    ╎    ╎ 2     ...nsional.jl:402; iterate
#      ╎    ╎    ╎    ╎    ╎  2     ...nsional.jl:420; __inc
#     2╎    ╎    ╎    ╎    ╎   2     @Base/int.jl:87; +
#      ╎    ╎    ╎    ╎   20    ...roadcast.jl:211; similar
#      ╎    ╎    ╎    ╎    20    ...roadcast.jl:212; similar
#      ╎    ╎    ╎    ╎     20    ...actarray.jl:881; similar
#      ╎    ╎    ╎    ╎    ╎ 20    ...ctarray.jl:882; similar
#      ╎    ╎    ╎    ╎    ╎  20    @Base/boot.jl:494; Array
#      ╎    ╎    ╎    ╎    ╎   20    ...e/boot.jl:487; Array
#    20╎    ╎    ╎    ╎    ╎    20    ...e/boot.jl:479; Array
#      ╎    ╎    ╎  18    ...s/utilities.jl:82; dβdβ_res_ij(dist::Bern...
#      ╎    ╎    ╎   18    ...src/matmul.jl:1162; *
#      ╎    ╎    ╎    18    .../broadcast.jl:811; broadcast(::typeof(*)...
#      ╎    ╎    ╎     18    .../broadcast.jl:873; materialize
#      ╎    ╎    ╎    ╎ 18    ...broadcast.jl:898; copy
#      ╎    ╎    ╎    ╎  6     ...broadcast.jl:926; copyto!
#      ╎    ╎    ╎    ╎   2     ...roadcast.jl:962; copyto!
#      ╎    ╎    ╎    ╎    2     ...actarray.jl:98; axes
#     2╎    ╎    ╎    ╎     2     @Base/array.jl:150; size
#      ╎    ╎    ╎    ╎   4     ...roadcast.jl:973; copyto!
#     2╎    ╎    ╎    ╎    2     ...simdloop.jl:75; macro expansion
#      ╎    ╎    ╎    ╎    1     ...simdloop.jl:78; macro expansion
#     1╎    ╎    ╎    ╎     1     @Base/int.jl:87; +
#      ╎    ╎    ╎    ╎    1     ...simdloop.jl:84; macro expansion
#      ╎    ╎    ╎    ╎     1     ...ensional.jl:402; iterate
#      ╎    ╎    ╎    ╎    ╎ 1     ...nsional.jl:420; __inc
#     1╎    ╎    ╎    ╎    ╎  1     @Base/int.jl:87; +
#      ╎    ╎    ╎    ╎  12    ...broadcast.jl:211; similar
#      ╎    ╎    ╎    ╎   12    ...roadcast.jl:212; similar
#      ╎    ╎    ╎    ╎    12    ...actarray.jl:881; similar
#      ╎    ╎    ╎    ╎     12    ...actarray.jl:882; similar
#      ╎    ╎    ╎    ╎    ╎ 12    @Base/boot.jl:494; Array
#      ╎    ╎    ╎    ╎    ╎  12    @Base/boot.jl:487; Array
#    12╎    ╎    ╎    ╎    ╎   12    ...e/boot.jl:479; Array
#      ╎    ╎    ╎  48    ...s/utilities.jl:83; dβdβ_res_ij(dist::Bern...
#      ╎    ╎    ╎   48    .../operators.jl:578; *
#      ╎    ╎    ╎    32    .../arraymath.jl:21; *(A::Float64, B::Vect...
#      ╎    ╎    ╎     32    .../broadcast.jl:862; broadcast_preserving_...
#      ╎    ╎    ╎    ╎ 32    ...broadcast.jl:873; materialize
#      ╎    ╎    ╎    ╎  32    ...broadcast.jl:898; copy
#      ╎    ╎    ╎    ╎   32    ...roadcast.jl:211; similar
#      ╎    ╎    ╎    ╎    32    ...roadcast.jl:212; similar
#      ╎    ╎    ╎    ╎     32    ...actarray.jl:881; similar
#      ╎    ╎    ╎    ╎    ╎ 32    ...ctarray.jl:882; similar
#      ╎    ╎    ╎    ╎    ╎  32    @Base/boot.jl:494; Array
#      ╎    ╎    ╎    ╎    ╎   32    ...e/boot.jl:486; Array
#    32╎    ╎    ╎    ╎    ╎    32    ...e/boot.jl:477; Array
#      ╎    ╎    ╎    16    .../operators.jl:535; afoldl
#      ╎    ╎    ╎     16    ...c/adjtrans.jl:439; *
#      ╎    ╎    ╎    ╎ 14    ...broadcast.jl:811; broadcast(::typeof(*...
#      ╎    ╎    ╎    ╎  14    ...broadcast.jl:873; materialize
#      ╎    ╎    ╎    ╎   14    ...roadcast.jl:898; copy
#      ╎    ╎    ╎    ╎    10    ...roadcast.jl:926; copyto!
#      ╎    ╎    ╎    ╎     10    ...roadcast.jl:973; copyto!
#     2╎    ╎    ╎    ╎    ╎ 2     ...simdloop.jl:75; macro expansion
#      ╎    ╎    ╎    ╎    ╎ 8     ...simdloop.jl:77; macro expansion
#      ╎    ╎    ╎    ╎    ╎  8     ...oadcast.jl:974; macro expansion
#      ╎    ╎    ╎    ╎    ╎   2     ...adcast.jl:610; getindex
#      ╎    ╎    ╎    ╎    ╎    2     ...adcast.jl:655; _broadcast_geti...
#      ╎    ╎    ╎    ╎    ╎     2     ...adcast.jl:679; _getindex
#      ╎    ╎    ╎    ╎    ╎    ╎ 2     ...adcast.jl:649; _broadcast_geti...
#      ╎    ╎    ╎    ╎    ╎    ╎  2     ...sional.jl:668; getindex
#     2╎    ╎    ╎    ╎    ╎    ╎   2     ...ntials.jl:13; getindex
#      ╎    ╎    ╎    ╎    ╎   6     ...sional.jl:670; setindex!
#     6╎    ╎    ╎    ╎    ╎    6     .../array.jl:971; setindex!
#      ╎    ╎    ╎    ╎    4     ...roadcast.jl:211; similar
#      ╎    ╎    ╎    ╎     4     ...roadcast.jl:212; similar
#      ╎    ╎    ╎    ╎    ╎ 4     ...ctarray.jl:881; similar
#      ╎    ╎    ╎    ╎    ╎  4     ...ctarray.jl:882; similar
#      ╎    ╎    ╎    ╎    ╎   4     ...e/boot.jl:494; Array
#      ╎    ╎    ╎    ╎    ╎    4     ...e/boot.jl:487; Array
#     4╎    ╎    ╎    ╎    ╎     4     ...e/boot.jl:479; Array
#     2╎    ╎    ╎    ╎ 2     .../simdloop.jl:0; broadcast(::typeof(*...
#      ╎    ╎    ╎  17    ...s/utilities.jl:84; dβdβ_res_ij(dist::Bern...
#      ╎    ╎    ╎   17    ...e/arraymath.jl:16; +(::Matrix{Float64}, :...
#      ╎    ╎    ╎    15    .../broadcast.jl:862; broadcast_preserving_...
#      ╎    ╎    ╎     15    .../broadcast.jl:873; materialize
#      ╎    ╎    ╎    ╎ 15    ...broadcast.jl:898; copy
#      ╎    ╎    ╎    ╎  15    ...broadcast.jl:926; copyto!
#      ╎    ╎    ╎    ╎   1     ...roadcast.jl:970; copyto!
#      ╎    ╎    ╎    ╎    1     ...roadcast.jl:953; preprocess
#      ╎    ╎    ╎    ╎     1     ...roadcast.jl:956; preprocess_args
#      ╎    ╎    ╎    ╎    ╎ 1     ...oadcast.jl:956; preprocess_args
#      ╎    ╎    ╎    ╎    ╎  1     ...oadcast.jl:956; preprocess_args
#      ╎    ╎    ╎    ╎    ╎   1     ...adcast.jl:956; preprocess_args
#      ╎    ╎    ╎    ╎    ╎    1     ...adcast.jl:957; preprocess_args
#      ╎    ╎    ╎    ╎    ╎     1     ...adcast.jl:954; preprocess
#      ╎    ╎    ╎    ╎    ╎    ╎ 1     ...adcast.jl:650; extrude
#      ╎    ╎    ╎    ╎    ╎    ╎  1     ...adcast.jl:599; newindexer
#      ╎    ╎    ╎    ╎    ╎    ╎   1     ...adcast.jl:600; shapeindexer
#      ╎    ╎    ╎    ╎    ╎    ╎    1     ...adcast.jl:604; _newindexer
#      ╎    ╎    ╎    ╎    ╎    ╎     1     ...adcast.jl:605; _newindexer
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎ 1     ...rators.jl:269; !=
#     1╎    ╎    ╎    ╎    ╎    ╎    ╎  1     ...motion.jl:499; ==
#      ╎    ╎    ╎    ╎   14    ...roadcast.jl:973; copyto!
#     2╎    ╎    ╎    ╎    2     ...simdloop.jl:75; macro expansion
#      ╎    ╎    ╎    ╎    10    ...simdloop.jl:77; macro expansion
#      ╎    ╎    ╎    ╎     10    ...roadcast.jl:974; macro expansion
#      ╎    ╎    ╎    ╎    ╎ 3     ...oadcast.jl:610; getindex
#      ╎    ╎    ╎    ╎    ╎  3     ...oadcast.jl:656; _broadcast_getindex
#      ╎    ╎    ╎    ╎    ╎   3     ...adcast.jl:683; _broadcast_getin...
#      ╎    ╎    ╎    ╎    ╎    3     ...rators.jl:578; +
#      ╎    ╎    ╎    ╎    ╎     3     ...rators.jl:536; afoldl
#     3╎    ╎    ╎    ╎    ╎    ╎ 3     .../float.jl:408; +
#      ╎    ╎    ╎    ╎    ╎ 7     ...nsional.jl:670; setindex!
#     7╎    ╎    ╎    ╎    ╎  7     ...e/array.jl:971; setindex!
#      ╎    ╎    ╎    ╎    2     ...simdloop.jl:78; macro expansion
#     2╎    ╎    ╎    ╎     2     @Base/int.jl:87; +
#      ╎    ╎    ╎    2     .../broadcast.jl:863; broadcast_preserving_...
#      ╎    ╎    ╎     2     .../broadcast.jl:222; axes
#      ╎    ╎    ╎    ╎ 2     ...broadcast.jl:224; _axes
#      ╎    ╎    ╎    ╎  2     ...broadcast.jl:511; combine_axes
#      ╎    ╎    ╎    ╎   2     ...roadcast.jl:517; broadcast_shape
#      ╎    ╎    ╎    ╎    2     ...roadcast.jl:523; _bcs
#      ╎    ╎    ╎    ╎     2     ...roadcast.jl:523; _bcs
#     2╎    ╎    ╎    ╎    ╎ 2     ...oadcast.jl:529; _bcs1
#      ╎    ╎     8     ...longitudinal.jl:219; get_Pinv(qc_model::GLMCo...
#      ╎    ╎    ╎ 8     ...ongitudinal.jl:241; get_Hθθ
#      ╎    ╎    ╎  8     ...tion/GLM_VC.jl:274; loglikelihood!(gcm::GL...
#      ╎    ╎    ╎   8     .../broadcast.jl:881; materialize!
#      ╎    ╎    ╎    8     .../broadcast.jl:884; materialize!
#      ╎    ╎    ╎     8     .../broadcast.jl:926; copyto!
#      ╎    ╎    ╎    ╎ 2     ...broadcast.jl:970; copyto!
#      ╎    ╎    ╎    ╎  2     ...broadcast.jl:953; preprocess
#      ╎    ╎    ╎    ╎   2     ...roadcast.jl:956; preprocess_args
#      ╎    ╎    ╎    ╎    2     ...roadcast.jl:957; preprocess_args
#      ╎    ╎    ╎    ╎     2     ...roadcast.jl:954; preprocess
#      ╎    ╎    ╎    ╎    ╎ 2     ...oadcast.jl:650; extrude
#      ╎    ╎    ╎    ╎    ╎  2     ...oadcast.jl:599; newindexer
#      ╎    ╎    ╎    ╎    ╎   2     ...adcast.jl:600; shapeindexer
#      ╎    ╎    ╎    ╎    ╎    2     ...adcast.jl:604; _newindexer
#      ╎    ╎    ╎    ╎    ╎     2     ...adcast.jl:605; _newindexer
#      ╎    ╎    ╎    ╎    ╎    ╎ 2     ...rators.jl:269; !=
#     2╎    ╎    ╎    ╎    ╎    ╎  2     ...motion.jl:499; ==
#      ╎    ╎    ╎    ╎ 6     ...broadcast.jl:973; copyto!
#      ╎    ╎    ╎    ╎  6     .../simdloop.jl:77; macro expansion
#      ╎    ╎    ╎    ╎   6     ...roadcast.jl:974; macro expansion
#      ╎    ╎    ╎    ╎    6     ...ensional.jl:670; setindex!
#     6╎    ╎    ╎    ╎     6     @Base/array.jl:971; setindex!
#      ╎    ╎     24    ...longitudinal.jl:220; get_Pinv(qc_model::GLMCo...
#      ╎    ╎    ╎ 5     ...ongitudinal.jl:264; get_Hβθ(qc_model::GLMCo...
#      ╎    ╎    ╎  5     @Base/array.jl:782; collect(itr::Base.Gene...
#      ╎    ╎    ╎   5     ...e/generator.jl:47; iterate
#      ╎    ╎    ╎    2     .../essentials.jl:0; #126
#      ╎    ╎    ╎     2     ...rc/matmul.jl:1152; *(tu::Adjoint{Float6...
#      ╎    ╎    ╎    ╎ 2     ...rc/matmul.jl:119; *
#      ╎    ╎    ╎    ╎  2     ...rc/matmul.jl:101; *
#      ╎    ╎    ╎    ╎   2     ...actarray.jl:838; similar
#      ╎    ╎    ╎    ╎    2     @Base/array.jl:374; similar
#      ╎    ╎    ╎    ╎     2     @Base/boot.jl:486; Array
#     2╎    ╎    ╎    ╎    ╎ 2     @Base/boot.jl:477; Array
#      ╎    ╎    ╎    3     none:0; #126
#      ╎    ╎    ╎     3     .../arraymath.jl:21; *
#      ╎    ╎    ╎    ╎ 3     .../adjtrans.jl:375; broadcast_preserving...
#      ╎    ╎    ╎    ╎  3     ...broadcast.jl:811; broadcast(::LinearA...
#      ╎    ╎    ╎    ╎   3     ...roadcast.jl:873; materialize
#      ╎    ╎    ╎    ╎    3     ...roadcast.jl:898; copy
#      ╎    ╎    ╎    ╎     2     ...roadcast.jl:926; copyto!
#      ╎    ╎    ╎    ╎    ╎ 2     ...oadcast.jl:962; copyto!
#      ╎    ╎    ╎    ╎    ╎  2     ...ctarray.jl:98; axes
#     2╎    ╎    ╎    ╎    ╎   2     .../array.jl:149; size
#      ╎    ╎    ╎    ╎     1     ...roadcast.jl:211; similar
#      ╎    ╎    ╎    ╎    ╎ 1     ...oadcast.jl:212; similar
#      ╎    ╎    ╎    ╎    ╎  1     ...ctarray.jl:881; similar
#      ╎    ╎    ╎    ╎    ╎   1     ...tarray.jl:882; similar
#      ╎    ╎    ╎    ╎    ╎    1     ...e/boot.jl:494; Array
#      ╎    ╎    ╎    ╎    ╎     1     ...e/boot.jl:486; Array
#     1╎    ╎    ╎    ╎    ╎    ╎ 1     ...e/boot.jl:477; Array
#      ╎    ╎    ╎ 4     ...ongitudinal.jl:265; get_Hβθ(qc_model::GLMCo...
#      ╎    ╎    ╎  4     @Base/array.jl:792; collect(itr::Base.Gene...
#      ╎    ╎    ╎   4     @Base/array.jl:818; collect_to_with_first!
#      ╎    ╎    ╎    4     @Base/array.jl:840; collect_to!(dest::Vec...
#      ╎    ╎    ╎     4     .../generator.jl:47; iterate
#      ╎    ╎    ╎    ╎ 4     none:0; #127
#      ╎    ╎    ╎    ╎  4     ...c/matmul.jl:1150; *
#      ╎    ╎    ╎    ╎   2     ...c/matmul.jl:52; *
#      ╎    ╎    ╎    ╎    2     ...actarray.jl:838; similar
#      ╎    ╎    ╎    ╎     2     @Base/array.jl:374; similar
#      ╎    ╎    ╎    ╎    ╎ 2     @Base/boot.jl:486; Array
#     2╎    ╎    ╎    ╎    ╎  2     @Base/boot.jl:477; Array
#      ╎    ╎    ╎    ╎   2     ...c/matmul.jl:101; *
#      ╎    ╎    ╎    ╎    2     ...actarray.jl:838; similar
#      ╎    ╎    ╎    ╎     2     @Base/array.jl:374; similar
#      ╎    ╎    ╎    ╎    ╎ 2     @Base/boot.jl:486; Array
#     2╎    ╎    ╎    ╎    ╎  2     @Base/boot.jl:477; Array
#     6╎    ╎    ╎ 15    ...ongitudinal.jl:266; get_Hβθ(qc_model::GLMCo...
#      ╎    ╎    ╎  2     .../arraymath.jl:8; -(A::Matrix{Float64}, ...
#      ╎    ╎    ╎   2     .../broadcast.jl:862; broadcast_preserving_z...
#      ╎    ╎    ╎    2     .../broadcast.jl:873; materialize
#      ╎    ╎    ╎     2     .../broadcast.jl:898; copy
#      ╎    ╎    ╎    ╎ 2     ...broadcast.jl:926; copyto!
#      ╎    ╎    ╎    ╎  2     ...broadcast.jl:973; copyto!
#     2╎    ╎    ╎    ╎   2     .../simdloop.jl:75; macro expansion
#      ╎    ╎    ╎  2     .../broadcast.jl:1317; broadcasted
#     2╎    ╎    ╎   2     .../broadcast.jl:1319; broadcasted
#      ╎    ╎    ╎  2     .../broadcast.jl:1317; broadcasted(::Function...
#     2╎    ╎    ╎   2     .../broadcast.jl:1319; broadcasted
#      ╎    ╎    ╎  3     .../broadcast.jl:873; materialize(bc::Base.B...
#      ╎    ╎    ╎   3     .../broadcast.jl:898; copy
#      ╎    ╎    ╎    3     .../broadcast.jl:926; copyto!
#      ╎    ╎    ╎     3     .../broadcast.jl:973; copyto!
#     2╎    ╎    ╎    ╎ 2     ...e/simdloop.jl:75; macro expansion
#      ╎    ╎    ╎    ╎ 1     ...e/simdloop.jl:77; macro expansion
#      ╎    ╎    ╎    ╎  1     ...broadcast.jl:974; macro expansion
#      ╎    ╎    ╎    ╎   1     ...ensional.jl:670; setindex!
#     1╎    ╎    ╎    ╎    1     @Base/array.jl:971; setindex!
#      ╎    ╎    13921 ...longitudinal.jl:71; GWASCopulaVCModel(qc_mod...
#      ╎    ╎     13921 ...ogressMeter.jl:1010; macro expansion
#     3╎    ╎    ╎ 3     .../essentials.jl:0; macro expansion
#     3╎    ╎    ╎ 3     ...ongitudinal.jl:0; macro expansion
#      ╎    ╎    ╎ 14    ...ongitudinal.jl:73; macro expansion
#      ╎    ╎    ╎  14    ...rc/snparray.jl:327; copyto!
#      ╎    ╎    ╎   11    ...c/snparray.jl:348; copyto!(v::Vector{Floa...
#      ╎    ╎    ╎    2     ...e/simdloop.jl:75; macro expansion
#     2╎    ╎    ╎     2     @Base/int.jl:83; <
#      ╎    ╎    ╎    9     ...e/simdloop.jl:77; macro expansion
#      ╎    ╎    ╎     5     ...c/snparray.jl:349; macro expansion
#      ╎    ╎    ╎    ╎ 1     ...ractarray.jl:1294; getindex
#      ╎    ╎    ╎    ╎  1     ...actarray.jl:1339; _getindex
#      ╎    ╎    ╎    ╎   1     ...subarray.jl:286; getindex
#      ╎    ╎    ╎    ╎    1     ...snparray.jl:132; getindex
#      ╎    ╎    ╎    ╎     1     @Base/int.jl:508; >>
#     1╎    ╎    ╎    ╎    ╎ 1     @Base/int.jl:502; >>
#     4╎    ╎    ╎    ╎ 4     .../snparray.jl:305; convert
#      ╎    ╎    ╎     2     ...c/snparray.jl:350; macro expansion
#     2╎    ╎    ╎    ╎ 2     @Base/array.jl:971; setindex!
#      ╎    ╎    ╎     2     ...c/snparray.jl:351; macro expansion
#      ╎    ╎    ╎    ╎ 2     @Base/float.jl:619; isnan
#     2╎    ╎    ╎    ╎  2     @Base/float.jl:534; !=
#      ╎    ╎    ╎   3     ...c/snparray.jl:356; copyto!(v::Vector{Floa...
#      ╎    ╎    ╎    2     ...e/simdloop.jl:77; macro expansion
#     1╎    ╎    ╎     1     ...c/snparray.jl:0; macro expansion
#     1╎    ╎    ╎     1     ...c/snparray.jl:359; macro expansion
#      ╎    ╎    ╎    1     ...e/simdloop.jl:78; macro expansion
#     1╎    ╎    ╎     1     @Base/int.jl:87; +
#      ╎    ╎    ╎ 1     ...ongitudinal.jl:76; macro expansion
#      ╎    ╎    ╎  1     ...ongitudinal.jl:19; fill!(s::QuasiCopula.St...
#      ╎    ╎    ╎   1     @Base/array.jl:349; fill!
#     1╎    ╎    ╎    1     @Base/array.jl:969; setindex!
#     1╎    ╎    ╎ 106   ...ongitudinal.jl:84; macro expansion
#     2╎    ╎    ╎  2     @Base/math.jl:0; get_∇resγ(qc_model::GL...
#     6╎    ╎    ╎  6     ...ongitudinal.jl:188; get_∇resγ(qc_model::GL...
#      ╎    ╎    ╎  1     ...ongitudinal.jl:189; get_∇resγ(qc_model::GL...
#     1╎    ╎    ╎   1     @Base/Base.jl:37; getproperty
#      ╎    ╎    ╎  1     ...ongitudinal.jl:190; get_∇resγ(qc_model::GL...
#     1╎    ╎    ╎   1     @Base/array.jl:148; size
#      ╎    ╎    ╎  61    ...ongitudinal.jl:192; get_∇resγ(qc_model::GL...
#      ╎    ╎    ╎   61    @Base/array.jl:580; zeros
#      ╎    ╎    ╎    54    @Base/array.jl:584; zeros
#      ╎    ╎    ╎     54    @Base/boot.jl:486; Array
#    54╎    ╎    ╎    ╎ 54    @Base/boot.jl:477; Array
#      ╎    ╎    ╎    7     @Base/array.jl:585; zeros
#      ╎    ╎    ╎     6     @Base/array.jl:348; fill!
#      ╎    ╎    ╎    ╎ 6     ...ractarray.jl:314; eachindex
#      ╎    ╎    ╎    ╎  6     ...ractarray.jl:133; axes1
#      ╎    ╎    ╎    ╎   6     ...ractarray.jl:98; axes
#     6╎    ╎    ╎    ╎    6     @Base/array.jl:149; size
#      ╎    ╎    ╎     1     @Base/array.jl:349; fill!
#     1╎    ╎    ╎    ╎ 1     @Base/array.jl:969; setindex!
#      ╎    ╎    ╎  34    ...ongitudinal.jl:194; get_∇resγ(qc_model::GL...
#    16╎    ╎    ╎   16    @Base/array.jl:969; setindex!
#    16╎    ╎    ╎   16    ...essentials.jl:13; getindex
#      ╎    ╎    ╎   1     ...e/subarray.jl:318; getindex
#     1╎    ╎    ╎    1     ...tractarray.jl:709; checkbounds
#      ╎    ╎    ╎   1     .../utilities.jl:121; update_∇res_ij
#     1╎    ╎    ╎    1     @Base/float.jl:409; -
#      ╎    ╎    ╎ 1     ...ongitudinal.jl:85; macro expansion
#      ╎    ╎    ╎  1     ...ongitudinal.jl:210; get_∇resβ
#     1╎    ╎    ╎   1     .../essentials.jl:13; getindex
#      ╎    ╎    ╎ 304   ...ongitudinal.jl:87; macro expansion
#      ╎    ╎    ╎  304   @Base/array.jl:580; zeros
#      ╎    ╎    ╎   301   @Base/array.jl:584; zeros
#      ╎    ╎    ╎    301   @Base/boot.jl:487; Array
#   301╎    ╎    ╎     301   @Base/boot.jl:479; Array
#      ╎    ╎    ╎   3     @Base/array.jl:585; zeros
#      ╎    ╎    ╎    1     @Base/array.jl:348; fill!
#      ╎    ╎    ╎     1     ...tractarray.jl:371; eachindex
#      ╎    ╎    ╎    ╎ 1     ...ractarray.jl:381; eachindex
#     1╎    ╎    ╎    ╎  1     ...ssentials.jl:10; length
#      ╎    ╎    ╎    2     @Base/array.jl:349; fill!
#     2╎    ╎    ╎     2     @Base/array.jl:969; setindex!
#      ╎    ╎    ╎ 424   ...ongitudinal.jl:89; macro expansion
#      ╎    ╎    ╎  414   ...e/broadcast.jl:881; materialize!
#      ╎    ╎    ╎   414   .../broadcast.jl:884; materialize!
#      ╎    ╎    ╎    409   .../broadcast.jl:926; copyto!
#     8╎    ╎    ╎     8     .../broadcast.jl:0; copyto!
#      ╎    ╎    ╎     66    .../broadcast.jl:970; copyto!
#      ╎    ╎    ╎    ╎ 66    ...broadcast.jl:953; preprocess
#      ╎    ╎    ╎    ╎  66    ...broadcast.jl:956; preprocess_args
#      ╎    ╎    ╎    ╎   66    ...roadcast.jl:957; preprocess_args
#      ╎    ╎    ╎    ╎    66    ...roadcast.jl:953; preprocess
#      ╎    ╎    ╎    ╎     66    ...roadcast.jl:956; preprocess_args
#      ╎    ╎    ╎    ╎    ╎ 66    ...oadcast.jl:957; preprocess_args
#      ╎    ╎    ╎    ╎    ╎  66    ...oadcast.jl:954; preprocess
#     1╎    ╎    ╎    ╎    ╎   1     ...adcast.jl:947; broadcast_unalias
#      ╎    ╎    ╎    ╎    ╎   65    ...adcast.jl:650; extrude
#      ╎    ╎    ╎    ╎    ╎    65    ...adcast.jl:599; newindexer
#      ╎    ╎    ╎    ╎    ╎     65    ...adcast.jl:600; shapeindexer
#      ╎    ╎    ╎    ╎    ╎    ╎ 65    ...adcast.jl:604; _newindexer
#      ╎    ╎    ╎    ╎    ╎    ╎  65    ...adcast.jl:605; _newindexer
#      ╎    ╎    ╎    ╎    ╎    ╎   65    ...rators.jl:269; !=
#    65╎    ╎    ╎    ╎    ╎    ╎    65    ...motion.jl:499; ==
#      ╎    ╎    ╎     334   .../broadcast.jl:973; copyto!
#    13╎    ╎    ╎    ╎ 13    ...e/simdloop.jl:0; macro expansion
#      ╎    ╎    ╎    ╎ 1     ...e/simdloop.jl:70; macro expansion
#      ╎    ╎    ╎    ╎  1     ...mensional.jl:396; iterate
#      ╎    ╎    ╎    ╎   1     @Base/tuple.jl:298; map
#      ╎    ╎    ╎    ╎    1     @Base/range.jl:1413; in
#     1╎    ╎    ╎    ╎     1     @Base/int.jl:488; <=
#    12╎    ╎    ╎    ╎ 12    ...e/simdloop.jl:72; macro expansion
#   163╎    ╎    ╎    ╎ 174   ...e/simdloop.jl:75; macro expansion
#    11╎    ╎    ╎    ╎  11    @Base/int.jl:83; <
#      ╎    ╎    ╎    ╎ 97    ...e/simdloop.jl:77; macro expansion
#      ╎    ╎    ╎    ╎  97    ...broadcast.jl:974; macro expansion
#      ╎    ╎    ╎    ╎   7     ...roadcast.jl:610; getindex
#      ╎    ╎    ╎    ╎    7     ...roadcast.jl:656; _broadcast_getindex
#      ╎    ╎    ╎    ╎     7     ...roadcast.jl:683; _broadcast_getinde...
#     7╎    ╎    ╎    ╎    ╎ 7     ...e/float.jl:408; +
#      ╎    ╎    ╎    ╎   90    ...ensional.jl:670; setindex!
#    90╎    ╎    ╎    ╎    90    @Base/array.jl:971; setindex!
#      ╎    ╎    ╎    ╎ 5     ...e/simdloop.jl:78; macro expansion
#     5╎    ╎    ╎    ╎  5     @Base/int.jl:87; +
#     9╎    ╎    ╎    ╎ 32    ...e/simdloop.jl:84; macro expansion
#      ╎    ╎    ╎    ╎  23    ...mensional.jl:402; iterate
#    23╎    ╎    ╎    ╎   23    ...ensional.jl:421; __inc
#     1╎    ╎    ╎     1     ...e/simdloop.jl:0; copyto!
#      ╎    ╎    ╎    5     .../broadcast.jl:297; instantiate
#      ╎    ╎    ╎     5     .../broadcast.jl:560; check_broadcast_axes
#      ╎    ╎    ╎    ╎ 5     ...broadcast.jl:556; check_broadcast_axes
#      ╎    ╎    ╎    ╎  4     ...broadcast.jl:222; axes
#      ╎    ╎    ╎    ╎   4     ...roadcast.jl:224; _axes
#      ╎    ╎    ╎    ╎    4     ...roadcast.jl:512; combine_axes
#      ╎    ╎    ╎    ╎     4     ...actarray.jl:98; axes
#     4╎    ╎    ╎    ╎    ╎ 4     ...e/array.jl:150; size
#      ╎    ╎    ╎    ╎  1     ...broadcast.jl:554; check_broadcast_shape
#      ╎    ╎    ╎    ╎   1     ...roadcast.jl:553; check_broadcast_shape
#      ╎    ╎    ╎    ╎    1     ...roadcast.jl:531; _bcsm
#      ╎    ╎    ╎    ╎     1     ...e/range.jl:1119; ==
#     1╎    ╎    ╎    ╎    ╎ 1     ...omotion.jl:499; ==
#    10╎    ╎    ╎  10    .../essentials.jl:13; getindex
#      ╎    ╎    ╎ 2     ...ongitudinal.jl:90; macro expansion
#      ╎    ╎    ╎  2     @Base/range.jl:891; iterate
#     2╎    ╎    ╎   2     .../promotion.jl:499; ==
# ...
#      ╎    ╎    ╎    ╎    ╎  5     @Base/task.jl:983; wait()
#     4╎    ╎    ╎    ╎    ╎   5     ...e/task.jl:974; poptask(W::Base....
#      ╎    ╎    ╎    ╎    ╎    1     ...stream.jl:1166; uv_writecb_task...
#      ╎    ╎    ╎    ╎    ╎     1     ...e/task.jl:838; schedule
#      ╎    ╎    ╎    ╎    ╎    ╎ 1     ...e/task.jl:849; schedule(t::Tas...
#      ╎    ╎    ╎    ╎    ╎    ╎  1     ...e/task.jl:783; enq_work(t::Task)
#     1╎    ╎    ╎    ╎    ╎    ╎   1     ...e/task.jl:701; push!(W::Base.I...
#      ╎    ╎    ╎    ╎    ╎  1     @Base/task.jl:984; wait()
#     1╎    ╎    ╎    ╎    ╎   1     ...e/task.jl:909; try_yieldto(undo...
#      ╎    ╎    ╎    ╎    ╎  7     @Base/task.jl:985; wait()
#     7╎    ╎    ╎    ╎    ╎   7     .../libuv.jl:107; process_events
#      ╎    ╎    ╎    ╎   2     ...rc/stdio.jl:276; flush(io::IJulia.IJ...
#      ╎    ╎    ╎    ╎    1     ...rc/stdio.jl:269; oslibuv_flush
#      ╎    ╎    ╎    ╎     1     @Base/task.jl:864; yield()
#      ╎    ╎    ╎    ╎    ╎ 1     @Base/task.jl:985; wait()
#     1╎    ╎    ╎    ╎    ╎  1     ...e/libuv.jl:107; process_events
#      ╎    ╎    ╎    ╎    1     ...rc/stdio.jl:270; oslibuv_flush
#      ╎    ╎    ╎    ╎     1     @Base/task.jl:864; yield()
#      ╎    ╎    ╎    ╎    ╎ 1     @Base/task.jl:985; wait()
#     1╎    ╎    ╎    ╎    ╎  1     ...e/libuv.jl:107; process_events
#      ╎    ╎    ╎    ╎   31    ...rc/stdio.jl:277; flush(io::IJulia.IJ...
#      ╎    ╎    ╎    ╎    31    ...rc/stdio.jl:163; send_stream(name::...
#     1╎    ╎    ╎    ╎     1     @Base/dict.jl:104; Dict
#      ╎    ╎    ╎    ╎     4     .../src/msg.jl:30; msg_pub
#      ╎    ╎    ╎    ╎    ╎ 4     .../src/msg.jl:30; msg_pub(m::IJulia....
#     1╎    ╎    ╎    ╎    ╎  4     ...src/msg.jl:18; msg_header(m::IJu...
#     2╎    ╎    ╎    ╎    ╎   2     ...e/dict.jl:105; Dict(::Pair{Stri...
#      ╎    ╎    ╎    ╎    ╎   1     ...c/init.jl:8; uuid4
#      ╎    ╎    ╎    ╎    ╎    1     ...e/uuid.jl:93; string(u::Base.U...
#      ╎    ╎    ╎    ╎    ╎     1     ...buffer.jl:31; StringVector
#     1╎    ╎    ╎    ╎    ╎    ╎ 1     ...string.jl:100; unsafe_wrap
#      ╎    ╎    ╎    ╎     2     .../src/msg.jl:44; send_ipython(socke...
#      ╎    ╎    ╎    ╎    ╎ 2     @Base/lock.jl:147; lock
#      ╎    ╎    ╎    ╎    ╎  2     @Base/lock.jl:122; trylock
#      ╎    ╎    ╎    ╎    ╎   2     ...e/lock.jl:130; _trylock(rl::Ree...
#     2╎    ╎    ╎    ╎    ╎    2     ...e/Base.jl:54; setproperty!
#      ╎    ╎    ╎    ╎     7     .../src/msg.jl:48; send_ipython(socke...
#      ╎    ╎    ╎    ╎    ╎ 7     ...src/comm.jl:42; send
#      ╎    ╎    ╎    ╎    ╎  7     ...rc/comm.jl:45; send(socket::ZMQ....
#      ╎    ╎    ╎    ╎    ╎   7     ...rc/comm.jl:13; _send(socket::ZM...
#     7╎    ╎    ╎    ╎    ╎    7     ...rc/comm.jl:6; msg_send
#      ╎    ╎    ╎    ╎     4     .../src/msg.jl:51; send_ipython(socke...
#      ╎    ╎    ╎    ╎    ╎ 4     .../Writer.jl:399; json(a::Dict{Stri...
#      ╎    ╎    ╎    ╎    ╎  4     ...ings/io.jl:107; sprint
#      ╎    ╎    ╎    ╎    ╎   4     ...ngs/io.jl:114; sprint(f::Functi...
#      ╎    ╎    ╎    ╎    ╎    4     ...Writer.jl:383; print(io::IOBuf...
#      ╎    ╎    ╎    ╎    ╎     4     ...Writer.jl:357; show_json
#      ╎    ╎    ╎    ╎    ╎    ╎ 4     ...Writer.jl:359; #show_json#9
#      ╎    ╎    ╎    ╎    ╎    ╎  4     ...Writer.jl:297; show_json
#      ╎    ╎    ╎    ╎    ╎    ╎   4     ...Writer.jl:291; recursive_cycle...
#      ╎    ╎    ╎    ╎    ╎    ╎    4     ...Writer.jl:300; (::JSON.Writer....
#      ╎    ╎    ╎    ╎    ╎    ╎     4     ...Writer.jl:259; show_pair(io::J...
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎ 4     ...Writer.jl:257; show_pair(io::J...
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎  4     ...Writer.jl:267; show_json
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎   4     ...Writer.jl:214; show_string(io:...
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎    4     ...src/io.jl:709; print(io::JSON....
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎     4     ...src/io.jl:662; format(dt::Date...
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ 4     ...src/io.jl:650; format(io::IOBu...
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  4     ...src/io.jl:655; macro expansion
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎   3     ...src/io.jl:81; format
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎    3     ...src/io.jl:166; format(io::IOBu...
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎     3     ...essors.jl:57; month
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +1 3     ...essors.jl:21; month(days::Int64)
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +2 2     @Base/div.jl:319; fld
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +3 2     @Base/div.jl:354; div
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +4 2     ...rators.jl:269; !=
#     2╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +5 2     ...motion.jl:499; ==
#     1╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +2 1     @Base/int.jl:87; +
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎   1     ...src/io.jl:257; format
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎    1     ...e/char.jl:252; print
#     1╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎     1     @Base/io.jl:735; write(io::IOBuf...
#      ╎    ╎    ╎    ╎     2     .../src/msg.jl:54; send_ipython(socke...
#      ╎    ╎    ╎    ╎    ╎ 2     .../Writer.jl:399; json(a::Dict{Stri...
#      ╎    ╎    ╎    ╎    ╎  2     ...ings/io.jl:107; sprint
#      ╎    ╎    ╎    ╎    ╎   2     ...ngs/io.jl:114; sprint(f::Functi...
#      ╎    ╎    ╎    ╎    ╎    2     ...Writer.jl:383; print(io::IOBuf...
#      ╎    ╎    ╎    ╎    ╎     2     ...Writer.jl:357; show_json
#      ╎    ╎    ╎    ╎    ╎    ╎ 2     ...Writer.jl:359; #show_json#9
#      ╎    ╎    ╎    ╎    ╎    ╎  2     ...Writer.jl:297; show_json
#      ╎    ╎    ╎    ╎    ╎    ╎   2     ...Writer.jl:291; recursive_cycle...
#      ╎    ╎    ╎    ╎    ╎    ╎    2     ...Writer.jl:300; (::JSON.Writer....
#      ╎    ╎    ╎    ╎    ╎    ╎     2     ...Writer.jl:259; show_pair
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎ 2     ...Writer.jl:257; show_pair
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎  2     ...Writer.jl:267; show_json
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎   2     ...Writer.jl:214; show_string(io:...
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎    2     ...ngs/io.jl:246; print
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎     2     ...ngs/io.jl:244; write
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ 2     @Base/io.jl:305; unsafe_write(s:...
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  2     ...Writer.jl:139; write
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎   2     @Base/io.jl:708; write
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎    1     ...tarray.jl:1240; pointer
#     1╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎     1     ...ointer.jl:65; unsafe_convert
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎    1     @Base/io.jl:685; unsafe_write
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎     1     @Base/io.jl:305; unsafe_write(s:...
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +1 1     ...Writer.jl:138; write
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +2 1     ...buffer.jl:443; write
#      ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +3 1     ...buffer.jl:330; ensureroom
#     1╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +4 1     .../array.jl:1014; _growend!
#      ╎    ╎    ╎    ╎     7     .../src/msg.jl:55; send_ipython(socke...
#      ╎    ╎    ╎    ╎    ╎ 3     ...src/hmac.jl:8; hmac(s1::String, s...
#      ╎    ╎    ╎    ╎    ╎  3     .../src/md.jl:165; reset!
#     3╎    ╎    ╎    ╎    ╎   3     ...c/error.jl:3; macro expansion
#     1╎    ╎    ╎    ╎    ╎ 4     ...src/hmac.jl:10; hmac(s1::String, s...
#      ╎    ╎    ╎    ╎    ╎  3     ...ings/io.jl:244; write(io::MbedTL...
#      ╎    ╎    ╎    ╎    ╎   3     @Base/io.jl:305; unsafe_write
#      ╎    ╎    ╎    ╎    ╎    3     ...src/md.jl:143; write
#      ╎    ╎    ╎    ╎    ╎     3     ...src/md.jl:128; _write
#     3╎    ╎    ╎    ╎    ╎    ╎ 3     .../error.jl:3; macro expansion
#      ╎    ╎    ╎    ╎     1     .../src/msg.jl:57; send_ipython(socke...
#      ╎    ╎    ╎    ╎    ╎ 1     ...src/comm.jl:42; send
#     1╎    ╎    ╎    ╎    ╎  1     ...rc/comm.jl:45; send(socket::ZMQ....
#      ╎    ╎    ╎    ╎     3     .../src/msg.jl:59; send_ipython(socke...
#      ╎    ╎    ╎    ╎    ╎ 3     ...src/comm.jl:42; send
#      ╎    ╎    ╎    ╎    ╎  3     ...rc/comm.jl:45; send(socket::ZMQ....
#      ╎    ╎    ╎    ╎    ╎   3     ...rc/comm.jl:13; _send(socket::ZM...
#     3╎    ╎    ╎    ╎    ╎    3     ...rc/comm.jl:6; msg_send
#      ╎    ╎    2     ...longitudinal.jl:106; GWASCopulaVCModel(qc_mod...
#      ╎    ╎     2     ...e/strings/io.jl:282; repr
#      ╎    ╎    ╎ 2     .../strings/io.jl:282; #repr#487
#      ╎    ╎    ╎  2     .../strings/io.jl:107; sprint
#      ╎    ╎    ╎   2     ...strings/io.jl:114; sprint(f::Function, ar...
#      ╎    ╎    ╎    2     @Base/ryu/Ryu.jl:112; show(io::IOBuffer, x:...
#      ╎    ╎    ╎     2     @Base/ryu/Ryu.jl:115; show(io::IOBuffer, x:...
#      ╎    ╎    ╎    ╎ 2     .../shortest.jl:313; writeshortest(buf::V...
#      ╎    ╎    ╎    ╎  2     .../shortest.jl:163; reduce_shortest
#     2╎    ╎    ╎    ╎   2     ...romotion.jl:499; ==
#     2╎    ╎    2     ...longitudinal.jl:185; calculate_Qi(qc_model::G...
#     7╎    ╎    7     ...longitudinal.jl:196; get_∇resγ(qc_model::GLMC...
#     1╎    ╎    1     ...longitudinal.jl:125; update_W!(W::Vector{Floa...
#      ╎4     @Base/task.jl:514; (::IJulia.var"#23#25")()
#      ╎ 4     @IJulia/src/stdio.jl:84; watch_stream(rd::Base.PipeEndp...
#      ╎  4     @Base/stream.jl:106; eof(s::Base.PipeEndpoint)
#      ╎   3     @Base/stream.jl:406; wait_readnb(x::Base.PipeEndp...
#     2╎    2     @Base/libuv.jl:55; preserve_handle(x::Base.Pipe...
#      ╎    1     @Base/libuv.jl:57; preserve_handle(x::Base.Pipe...
#     1╎     1     @Base/iddict.jl:103; get
#      ╎   1     @Base/stream.jl:416; wait_readnb(x::Base.PipeEndp...
#      ╎    1     @Base/condition.jl:125; wait
#      ╎     1     @Base/condition.jl:130; wait(c::Base.GenericConditi...
#      ╎    ╎ 1     @Base/task.jl:985; wait()
#     1╎    ╎  1     @Base/libuv.jl:107; process_events
#      ╎12    @Base/task.jl:134; (::Base.var"#702#703"{typeof(...
#      ╎ 12    @Base/asyncevent.jl:279; macro expansion
#      ╎  12    @Base/asyncevent.jl:138; _trywait(t::Timer)
#      ╎   12    @Base/condition.jl:125; wait
#      ╎    12    @Base/condition.jl:130; wait(c::Base.GenericConditi...
#      ╎     12    @Base/task.jl:985; wait()
#    12╎    ╎ 12    @Base/libuv.jl:107; process_events
#      ╎27    ...adingconstructs.jl:108; (::Base.Threads.var"#1#2"{Qua...
#      ╎ 27    ...adingconstructs.jl:130; #135#threadsfor_fun
#      ╎  27    ...adingconstructs.jl:163; (::QuasiCopula.var"#135#thre...
#      ╎   27    ...imation/GLM_VC.jl:265; macro expansion
#      ╎    27    ...imation/GLM_VC.jl:167; loglikelihood!
#      ╎     4     ...imation/GLM_VC.jl:182; loglikelihood!(gc::GLMCopul...
#      ╎    ╎ 2     ..._and_residuals.jl:64; update_res!(gc::GLMCopulaVC...
#      ╎    ╎  2     ...ra/src/matmul.jl:276; mul!
#      ╎    ╎   2     ...ra/src/matmul.jl:65; mul!
#      ╎    ╎    2     ...a/src/matmul.jl:503; gemv!(y::Vector{Float64}...
#     2╎    ╎     2     ...bra/src/blas.jl:667; gemv!(trans::Char, alpha...
#      ╎    ╎ 2     ..._and_residuals.jl:66; update_res!(gc::GLMCopulaVC...
#      ╎    ╎  2     .../src/glmtools.jl:261; linkinv
#      ╎    ╎   2     ...rc/basicfuns.jl:107; logistic
#      ╎    ╎    2     .../special/exp.jl:325; exp(x::Float64)
#      ╎    ╎     2     .../special/exp.jl:211; exp_impl
#     2╎    ╎    ╎ 2     @Base/float.jl:409; -
#      ╎     4     ...imation/GLM_VC.jl:187; loglikelihood!(gc::GLMCopul...
#      ╎    ╎ 4     ...adient_hessian.jl:66; std_res_differential!(gc::G...
#      ╎    ╎  4     ...ruct_loopset.jl:1107; _turbo_!(::Val{(false, 0,...
#      ╎    ╎   4     ...ruct_loopset.jl:1107; macro expansion
#      ╎    ╎    2     ...idedpointers.jl:56; _vload
#      ╎    ╎     2     .../memory_addr.jl:987; __vload
#     2╎    ╎    ╎ 2     ...memory_addr.jl:987; macro expansion
#      ╎    ╎    2     ...idedpointers.jl:162; _vstore!
#      ╎    ╎     2     ...memory_addr.jl:1667; __vstore!
#     2╎    ╎    ╎ 2     ...memory_addr.jl:1667; macro expansion
#      ╎     2     ...imation/GLM_VC.jl:198; loglikelihood!(gc::GLMCopul...
#      ╎    ╎ 2     ..._loglikelihood.jl:25; component_loglikelihood(gc:...
#      ╎    ╎  2     ..._loglikelihood.jl:8; loglik_obs
#      ╎    ╎   2     ...ete/bernoulli.jl:89; logpdf
#      ╎    ╎    2     .../special/log.jl:267; log
#     2╎    ╎     2     .../special/log.jl:0; _log(x::Float64, base::Va...
#      ╎     2     ...imation/GLM_VC.jl:221; loglikelihood!(gc::GLMCopul...
#      ╎    ╎ 2     ...ra/src/matmul.jl:474; copytri!
#      ╎    ╎  2     ...ra/src/matmul.jl:482; copytri!
#     2╎    ╎   2     @Base/array.jl:971; setindex!
#      ╎     4     ...imation/GLM_VC.jl:226; loglikelihood!(gc::GLMCopul...
#     2╎    ╎ 2     @Base/essentials.jl:13; getindex
#      ╎    ╎ 2     ...ra/src/matmul.jl:276; mul!
#      ╎    ╎  2     ...ra/src/matmul.jl:161; mul!
#      ╎    ╎   2     ...a/src/matmul.jl:674; gemm_wrapper!(C::Matrix{F...
#     2╎    ╎    2     ...bra/src/blas.jl:1524; gemm!(transA::Char, tran...
#      ╎     2     ...imation/GLM_VC.jl:230; loglikelihood!(gc::GLMCopul...
#      ╎    ╎ 2     @Base/broadcast.jl:881; materialize!
#      ╎    ╎  2     @Base/broadcast.jl:884; materialize!
#      ╎    ╎   2     @Base/broadcast.jl:926; copyto!
#      ╎    ╎    2     @Base/broadcast.jl:973; copyto!
#      ╎    ╎     2     @Base/simdloop.jl:77; macro expansion
#      ╎    ╎    ╎ 2     ...e/broadcast.jl:974; macro expansion
#      ╎    ╎    ╎  2     ...dimensional.jl:670; setindex!
#     2╎    ╎    ╎   2     @Base/array.jl:971; setindex!
#      ╎     5     ...imation/GLM_VC.jl:231; loglikelihood!(gc::GLMCopul...
#      ╎    ╎ 2     @Base/Base.jl:40; dotgetproperty
#     2╎    ╎  2     @Base/Base.jl:37; getproperty
#      ╎    ╎ 1     @Base/broadcast.jl:881; materialize!
#      ╎    ╎  1     @Base/broadcast.jl:884; materialize!
#      ╎    ╎   1     @Base/broadcast.jl:926; copyto!
#      ╎    ╎    1     @Base/broadcast.jl:973; copyto!
#     1╎    ╎     1     @Base/simdloop.jl:0; macro expansion
#      ╎    ╎ 2     ...dient_hessian.jl:91; glm_hessian(gc::GLMCopulaV...
#      ╎    ╎  2     ...ra/src/matmul.jl:276; mul!
#      ╎    ╎   2     ...src/diagonal.jl:367; mul!
#      ╎    ╎    2     ...src/diagonal.jl:348; _muldiag!
#      ╎    ╎     2     ...src/diagonal.jl:276; __muldiag!
#      ╎    ╎    ╎ 2     @Base/simdloop.jl:77; macro expansion
#      ╎    ╎    ╎  2     ...rc/diagonal.jl:277; macro expansion
#     2╎    ╎    ╎   2     @Base/array.jl:971; setindex!
#      ╎     2     ...imation/GLM_VC.jl:234; loglikelihood!(gc::GLMCopul...
#     2╎    ╎ 2     ...ebra/src/blas.jl:1441; syr!(uplo::Char, α::Float...
#      ╎     2     ...imation/GLM_VC.jl:242; loglikelihood!(gc::GLMCopul...
#      ╎    ╎ 2     ...adient_hessian.jl:81; glm_gradient(gc::GLMCopulaV...
#      ╎    ╎  2     ...ra/src/matmul.jl:276; mul!
#      ╎    ╎   2     ...ra/src/matmul.jl:93; mul!
#      ╎    ╎    2     ...a/src/matmul.jl:503; gemv!(y::Vector{Float64}...
#     2╎    ╎     2     ...bra/src/blas.jl:667; gemv!(trans::Char, alpha...
#     5╎5     ...as/longitudinal.jl:295; get_neg_Hθγ_i(gc::GLMCopulaVC...
#     7╎7     .../gwas/utilities.jl:86; dβdβ_res_ij(dist::Bernoulli{F...
#     6╎6     .../gwas/utilities.jl:110; dγdβresβ_ij(dist::Bernoulli{F...
#     3╎3     .../gwas/utilities.jl:26; ∇²μ_j(l::LogitLink, ηj::Float...
#    12╎12    .../gwas/utilities.jl:8; ∇²σ²_j(d::Bernoulli{Float64},...
#     4╎4     .../gwas/utilities.jl:12; ∇²σ²_j(d::Bernoulli{Float64},...
# 23561╎23561 ...a/src/heartbeat.jl:22; heartbeat_thread(sock::Ptr{No...
#    46╎46    ...lgebra/src/blas.jl:674; gemv!(trans::Char, alpha::Flo...
#     4╎4     ...ra/src/diagonal.jl:0; _mapreduce_prod(f::typeof(*),...
#     6╎6     ...bra/src/generic.jl:1147; /(A::Vector{Float64}, B::Vect...
#     6╎6     ...bra/src/generic.jl:1062; _vectorpinv(dualfn::typeof(tr...
#    15╎15    ...ebra/src/matmul.jl:1152; *(tu::Adjoint{Float64, Vector...
#     1╎1     ...ebra/src/matmul.jl:490; gemv!(y::Vector{Float64}, tA:...
#    19╎19    ...a/src/transpose.jl:111; transpose_f!(f::typeof(adjoin...
# Total snapshots: 47122. Utilization: 100% across all threads and tasks. Use the `groupby` kwarg to break down by thread and/or task.
